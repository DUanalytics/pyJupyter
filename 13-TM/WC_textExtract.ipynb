# %%
# Managing Strings / Words for TM

# %%
#Join and Split
str1 = 'Dhiraj Upadhyaya Data Scientist Data Analyst Data Engineer Director,EDA'
print(type(str1), '\n', str1)
# Out:
# <class 'str'>
#  Dhiraj Upadhyaya Data Scientist Data Analyst Data Engineer Director,EDA

# %%
print(str1.split(" "))  #split each word with separated by space
print(str1.split(","))  #split each word with separated by comma
# Out:
# ['Dhiraj', 'Upadhyaya', 'Data', 'Scientist', 'Data', 'Analyst', 'Data', 'Engineer', 'Director,EDA']
# ['Dhiraj Upadhyaya Data Scientist Data Analyst Data Engineer Director', 'EDA']

# %%
# split by multiple delimeters
import re
re.split('; |,|\*|\n|\s', str1)
# Out:
# ['Dhiraj',
#  'Upadhyaya',
#  'Data',
#  'Scientist',
#  'Data',
#  'Analyst',
#  'Data',
#  'Engineer',
#  'Director',
#  'EDA']

# %%
listStr2 = ['Dhiraj', 'Upadhyaya' , 'Data', 'Scientist', 'Data', 'Analyst' , 'Data', 'Engineer']
print(type(listStr2),  '\n', listStr2)
# Out:
# <class 'list'>
#  ['Dhiraj', 'Upadhyaya', 'Data', 'Scientist', 'Data', 'Analyst', 'Data', 'Engineer']

# %%
# print the string after split method

print("-".join(s.split())) # sep as -
print(" ".join(s.split())) # sep as space
DUtext = " ".join(x.split()[1] for x in s)
print(DUtext)

# %% [markdown]
# ## Text from wiki

# %%
#### Import packages
import wikipedia
import re
#https://pypi.org/project/wikipedia/

# %%
# Specify the title of the Wikipedia page
#wiki = wikipedia.page('Web Scraping')
#https://en.wikipedia.org/wiki/Web_scraping
wiki = wikipedia.page('DataMining')
# Extract the plain text content of the page
text = wiki.content
type(text)
# Out:
# str

# %%
print(text)
# Out:
# Data mining is the process of extracting and discovering patterns in large data sets involving methods at the intersection of machine learning, statistics, and database systems. Data mining is an interdisciplinary subfield of computer science and statistics with an overall goal of extracting information (with intelligent methods) from a data set and transforming the information into a comprehensible structure for further use. Data mining is the analysis step of the "knowledge discovery in databases" process, or KDD. Aside from the raw analysis step, it also involves database and data management aspects, data pre-processing, model and inference considerations, interestingness metrics, complexity considerations, post-processing of discovered structures, visualization, and online updating.The term "data mining" is a misnomer because the goal is the extraction of patterns and knowledge from large amounts of data, not the extraction (mining) of data itself. It also is a buzzword and is fr
# ...

# %%
# Clean text
#https://www.educative.io/answers/what-is-the-resub-function-in-python
#https://docs.python.org/3/library/re.html
text1 = re.sub("\W", ' ', text)
#text1 = re.sub(r'==.*?==+', '', text)
text1 = text1.replace('\n', '')
print(text1)
# Out:
# Data mining is the process of extracting and discovering patterns in large data sets involving methods at the intersection of machine learning  statistics  and database systems  Data mining is an interdisciplinary subfield of computer science and statistics with an overall goal of extracting information  with intelligent methods  from a data set and transforming the information into a comprehensible structure for further use  Data mining is the analysis step of the  knowledge discovery in databases  process  or KDD  Aside from the raw analysis step  it also involves database and data management aspects  data pre processing  model and inference considerations  interestingness metrics  complexity considerations  post processing of discovered structures  visualization  and online updating The term  data mining  is a misnomer because the goal is the extraction of patterns and knowledge from large amounts of data  not the extraction  mining  of data itself  It also is a buzzword and is fr
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
wc1 = WordCloud().generate(text)

# %%
plt.imshow(wc1)
