# %% [markdown]
# # Word Cloud
# https://www.analyticsvidhya.com/blog/2021/05/how-to-build-word-cloud-in-python/
# https://towardsdatascience.com/how-to-make-word-clouds-in-python-that-dont-suck-86518cdcb61f
# https://www.datacamp.com/tutorial/wordcloud-python

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# %%
# Data
url = 'https://raw.githubusercontent.com/DUanalytics/datasets/master/csv/android-games.csv'
df = pd.read_csv(url)
df.head(3)
# Out:
#    rank                           title  total ratings installs  \
# 0     1  Garena Free Fire- World Series       86273129  500.0 M
# 1     2          PUBG MOBILE - Traverse       37276732  500.0 M
# 2     3       Mobile Legends: Bang Bang       26663595  100.0 M
#
#    average rating  growth (30 days)  growth (60 days)  price     category  \
# 0               4               2.1               6.9    0.0  GAME ACTION
# 1               4               1.8               3.6    0.0  GAME ACTION
# 2               4               1.5               3.2    0.0  GAME ACTION
#
#    5 star ratings  4 star ratings  3 star ratings  2 star ratings  \
# 0        63546766         4949507         3158756         2122183
# 1        28339753         2164478         1253185          809821
# 2        18777988         1812094         1050600          713912
#
#    1 star ratings   paid
# 0        12495915  False
# 1         4709492  False
# 2         4308998  False

# %%
# Missing values
df.isna().sum()
#Removing NaN Values if present : #df.dropna(inplace = True)
# Out:
# rank                0
# title               0
# total ratings       0
# installs            0
# average rating      0
# growth (30 days)    0
# growth (60 days)    0
# price               0
# category            0
# 5 star ratings      0
# 4 star ratings      0
# 3 star ratings      0
# 2 star ratings      0
# 1 star ratings      0
# paid                0
# dtype: int64

# %%
df['category'].head()
# Out:
# 0    GAME ACTION
# 1    GAME ACTION
# 2    GAME ACTION
# 3    GAME ACTION
# 4    GAME ACTION
# Name: category, dtype: object

# %%
#Join and Split
s = 'Dhiraj Upadhyaya Data Scientist Data Analyst Data Engineer'
# print the string after split method
print(s.split(" "))  #split each word with separated by space
print("-".join(s.split())) # sep as -
print(" ".join(s.split())) # sep as space
DUtext = " ".join(x.split()[1] for x in s)
print(DUtext)
# Out:
# ['Dhiraj', 'Upadhyaya', 'Data', 'Scientist', 'Data', 'Analyst', 'Data', 'Engineer']
# Dhiraj-Upadhyaya-Data-Scientist-Data-Analyst-Data-Engineer
# Dhiraj Upadhyaya Data Scientist Data Analyst Data Engineer
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11352\3213019103.py in <module>
#       5 print("-".join(s.split())) # sep as -
#       6 print(" ".join(s.split())) # sep as space
# ----> 7 DUtext = " ".join(x.split()[1] for x in s)
#       8 print(DUtext)
#
# ~\AppData\Local\Temp\ipykernel_11352\3213019103.py in <genexpr>(.0)
#       5 print("-".join(s.split())) # sep as -
#       6 print(" ".join(s.split())) # sep as space
# ----> 7 DUtext = " ".join(x.split()[1] for x in s)
#       8 print(DUtext)
#
# IndexError: list index out of range

# %%
x ="Dhiraj Upadhyaya"
" ".join(cat.split() for cat in x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11352\2028177127.py in <module>
#       1 x ="Dhiraj Upadhyaya"
# ----> 2 " ".join(cat.split() for cat in x)
#
# TypeError: sequence item 0: expected str instance, list found

# %%
text = " ".join(cat.split()[1] for cat in df.category)
#text[0:10]
type(text)
# Out:
# str

# %%
#from collections import Counter
#Counter(text)
count = pd.Series(text).value_counts()
count
# Out:
# ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ACTION ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTURE ADVENTUR
# ...

# %%
# Creating word_cloud with text as argument in .generate() method
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text)

# %%
# Display the generated Word Cloud
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show();

# %%
# 2nd eg

# %%
df = pd.read_csv(url, encoding ="latin-1")
df.head(3)
# Out:
#    rank                           title  total ratings installs  \
# 0     1  Garena Free Fire- World Series       86273129  500.0 M
# 1     2          PUBG MOBILE - Traverse       37276732  500.0 M
# 2     3       Mobile Legends: Bang Bang       26663595  100.0 M
#
#    average rating  growth (30 days)  growth (60 days)  price     category  \
# 0               4               2.1               6.9    0.0  GAME ACTION
# 1               4               1.8               3.6    0.0  GAME ACTION
# 2               4               1.5               3.2    0.0  GAME ACTION
#
#    5 star ratings  4 star ratings  3 star ratings  2 star ratings  \
# 0        63546766         4949507         3158756         2122183
# 1        28339753         2164478         1253185          809821
# 2        18777988         1812094         1050600          713912
#
#    1 star ratings   paid
# 0        12495915  False
# 1         4709492  False
# 2         4308998  False

# %%
comment_words = ''
stopwords = set(STOPWORDS)

# %%
# iterate through the csv file
for val in df.category:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "

# %%
#pd.Series(comment_words).value_counts()
comment_words[1:10]
# Out:
# 'ame actio'

# %%
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
wordcloud

# %%
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
wc = WordCloud(stopwords = STOPWORDS, mask = mask, background_color = "white",
               max_words = 2000, max_font_size = 500,
               random_state = 42, width = mask.shape[1],
               height = mask.shape[0])

# %%
#!pip install wikipedia
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11680 sha256=5d166ffda476a37a1875c4fbe591b3452d88418082e8522b59e66c8ddf14454c
#   Stored in directory: c:\users\du\appdata\local\pip\cache\wheels\c2\46\f4\caa1bee71096d7b0cdca2f2a2af45cacf35c5760bee8f00948
# Successfully built wikipedia
# ...

# %%
import wikipedia
result= wikipedia.summary("MachineLearning", sentences=5)
print(result)
# Out:
# Machine learning (ML) is a field of inquiry devoted to understanding and building methods that 'learn', that is, methods that leverage data to improve performance on some set of tasks. It is seen as a part of artificial intelligence. Machine learning algorithms build a model based on sample data, known as training data, in order to make predictions or decisions without being explicitly programmed to do so. Machine learning algorithms are used in a wide variety of applications, such as in medicine, email filtering, speech recognition, agriculture, and computer vision, where it is difficult or unfeasible to develop conventional algorithms to perform the needed tasks.
# A subset of machine learning is closely related to computational statistics, which focuses on making predictions using computers, but not all machine learning is statistical learning.

# %%
#from wordcloud import WordCloud, StopWords
from wordcloud import WordCloud, STOPWORDS
#import matplotlib.pyplot as plt 
def plot_cloud(wordcloud):
    plt.figure(figsize=(10, 10))
    plt.imshow(wordcloud) 
    plt.axis("off");

# %%
wordcloud = WordCloud(width = 500, height = 500, background_color='pink', random_state=10).generate(result)

# %%
plot_cloud(wordcloud)

# %%
wordcloud = WordCloud(width = 500, height = 500, background_color='#40E0D0', colormap="ocean",  random_state=10).generate(result)
plot_cloud(wordcloud)

# %% [markdown]
# ## Links
# https://www.datacamp.com/tutorial/wordcloud-python
# https://towardsdatascience.com/how-to-make-word-clouds-in-python-that-dont-suck-86518cdcb61f
# https://www.datacamp.com/tutorial/wordcloud-python
