# %%
# Beautiful Soup Library

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup("<p>Some<b>bad<i>HTML")
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    Some
#    <b>
#     bad
#     <i>
#      HTML
#     </i>
#    </b>
#   </p>
#  </body>
# </html>

# %%
#HTML

# %%
html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
soup = BeautifulSoup(html_doc, 'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
soup.title
# <title>The Dormouse's story</title>
# Out:
# <title>The Dormouse's story</title>

# %%
soup.title.name
# u'title'
# Out:
# 'title'

# %%
soup.title.string
# u'The Dormouse's story'
# Out:
# "The Dormouse's story"

# %%
soup.title.parent.name
# u'head'
# Out:
# 'head'

# %%
soup.p
# <p class="title"><b>The Dormouse's story</b></p>
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
soup.p['class']
# u'title'
# Out:
# ['title']

# %%
soup.a
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.find_all('a')
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find(id="link3")
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
#One common task is extracting all the URLs found within a page’s <a> tags:
for link in soup.find_all('a'):
    print(link.get('href'))
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
#Another common task is extracting all the text from a page:
print(soup.get_text())
# Out:
# The Dormouse's story
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %% [markdown]
# ## Table
# https://www.projectpro.io/recipes/scrape-table-from-webpage-beautiful-soup

# %%
# load the projectpro webpage content 
import requests
from bs4 import BeautifulSoup as bs 
r = requests.get('https://www.projectpro.io/recipes') 
# convert to beautiful soup 
soup = bs(r.content) 
# printing our web page 
print(soup.prettify()) 
#Scrapping the table:-
import pandas as pd 
table = soup.select('table#dataTablesFaculties')[0] 
columns = table.find('thead').find_all('th') 
print(columns)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <!-- HEAD SECTION -->
#   <!-- IE Edge Meta Tag -->
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <!-- Viewport -->
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="ixp5hs2fzkudi7mavl63rbd2wnwt1i" name="facebook-domain-verification"/>
#   <title>
#    Machine Learning and Data Science Code Examples | ProjectPro
#   </title>
#   <meta content="Machine Learning and Data Science Code Examples | ProjectPro" name="title"/>
#   <meta content="Short code snippets in Machine Learning and Data Science - Get ready to use code snippets for solving real-world business problems" name="description"/>
#   <meta content="Data Science recipes, Data Science code snippets, Machine learning recipes, machine learning code snippets" name="keywords"/>
#   <meta content="Machine Learning and Data Science Code Examples | ProjectPro" property="og:title"/>
#   <meta content="ProjectPro" property="og:site_name"/>
#   <meta content="https://dezyre.gumlet.io/files.dezyre.com/images/projectpro-recipes.webp" property="og:image"/>
#   <!-- Initializing preconnects -->
#   <link crossorigin="" href="https://fonts.gstatic.com/" rel="preconnect"/>
#   <link crossorigin="" href="https://daxg39y63pxwu.cloudfront.net/" rel="preconnect"/>
#   <link crossorigin="" href="https://cdnjs.cloudflare.com/" rel="preconnect"/>
#   <link crossorigin="" href="https://maxcdn.bootstrapcdn.com/" rel="preconnect"/>
#   <link href="//www.google-analytics.com" rel="dns-prefetch"/>
#   <link href="//v2.zopim.com" rel="dns-prefetch"/>
#   <link href="//my.hellobar.com" rel="dns-prefetch"/>
#   <link href="//app.satismeter.com" rel="dns-prefetch"/>
#   <!--
# 	<script>
# 	  (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 	  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	  })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 	  ga('create', 'UA-41699664-1', 'dezyre.com');
# 	  ga('send', 'pageview');
#
# 	</script>
# 	 -->
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-41699664-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-41699664-1');
#   </script>
#   <!-- Google Analytics https://developers.google.com/analytics/devguides/collection/analyticsjs -->
#   <!--  https://philipwalton.com/articles/the-google-analytics-setup-i-use-on-every-site-i-build/ -->
#   <!-- <script>
# 		window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;
# 		ga('create', 'UA-41699664-1', 'dezyre.com');
# 		ga('set', 'transport', 'beacon');
# 		ga('send', 'pageview');
# 	</script>
# 	<script async src='https://www.google-analytics.com/analytics.js'></script>  -->
#   <!-- End Google Analytics -->
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 	new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 	j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 	'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 	})(window,document,'script','dataLayer','GTM-PM3NN4G');
#   </script>
#   <!-- End Google Tag Manager -->
#   <link href="https://www.projectpro.io/recipes" rel="canonical"/>
#   <link href="https://www.projectpro.io/recipes" hreflang="x-default" rel="alternate"/>
#   <!--
# 	<link rel="canonical" href="https://www.projectpro.io/https://www.projectpro.io/recipes" />
# 	<link rel="alternate" href="https://www.projectpro.io/https://www.projectpro.io/recipes" hreflang="x-default" />
# 	 -->
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <link href="https://plus.google.com/112833548823362671038" rel="publisher"/>
#   <!--
# 	<link rel="icon" href="//daxg39y63pxwu.cloudfront.net/dezyre/images/favicon.ico" type="image/x-icon" />
# 	<link rel="shortcut icon" href="//daxg39y63pxwu.cloudfront.net/dezyre/images/favicon.ico" type="image/x-icon"/>
# 	 -->
#   <link href="//daxg39y63pxwu.cloudfront.net/dezyre/images/favicon_io/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="https://daxg39y63pxwu.cloudfront.net/dezyre/images/favicon_io/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="https://daxg39y63pxwu.cloudfront.net/dezyre/images/favicon_io/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link crossorigin="use-credentials" href="https://s3.amazonaws.com/files.dezyre.com/dezyre/images/favicon_io/site.webmanifest" rel="manifest"/>
#   <!-- Font Awesome -->
#   <!--   	<link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.11.2/css/all.css"> -->
#   <!-- 	<link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.5.0/css/bootstrap.min.css"> -->
#   <!-- 	critical bootstrap css -->
#   <style>
#    :root{--blue:#007bff;--indigo:#6610f2;--purple:#6f42c1;--pink:#e83e8c;--red:#dc3545;--orange:#fd7e14;--yellow:#ffc107;--green:#28a745;--teal:#20c997;--cyan:#17a2b8;--white:#fff;--gray:#6c757d;--gray-dark:#343a40;--primary:#007bff;--secondary:#6c757d;--success:#28a745;--info:#17a2b8;--warning:#ffc107;--danger:#dc3545;--light:#f8f9fa;--dark:#343a40;--breakpoint-xs:0;--breakpoint-sm:576px;--breakpoint-md:768px;--breakpoint-lg:992px;--breakpoint-xl:1200px;--font-family-sans-serif:-apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,"Helvetica Neue",Arial,"Noto Sans",sans-serif,"Apple Color Emoji","Segoe UI Emoji","Segoe UI Symbol","Noto Color Emoji";--font-family-monospace:SFMono-Regular,Menlo,Monaco,Consolas,"Liberation Mono","Courier New",monospace}*,::after,::before{box-sizing:border-box}html{font-family:sans-serif;line-height:1.15;-webkit-text-size-adjust:100%;-webkit-tap-highlight-color:transparent}article,aside,figcaption,figure,footer,header,hgroup,main,nav,section{display:block}body{margin:0;font-family:-apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,"Helvetica Neue",Arial,"Noto Sans",sans-serif,"Apple Color Emoji","Segoe UI Emoji","Segoe UI Symbol","Noto Color Emoji";font-size:1rem;font-weight:400;line-height:1.5;color:#212529;text-align:left;background-color:#fff}hr{box-sizing:content-box;height:0;margin-top:1rem;border:0;border-top:1px solid rgba(0,0,0,.1)}dl,h1,h2,h3,h4,h5,h6,ol,p,ul{margin-top:0}dl,hr,ol,p,ul{margin-bottom:1rem}b,strong{font-weight:bolder}a{color:#007bff;text-decoration:none;background-color:transparent}a:hover{color:#0056b3;text-decoration:underline}code,kbd,pre,samp{font-family:SFMono-Regular,Menlo,Monaco,Consolas,"Liberation Mono","Courier New",monospace}kbd,pre,samp{font-size:1em}img,svg{vertical-align:middle}img{border-style:none}svg{overflow:hidden}table{border-collapse:collapse}th{text-align:inherit}label{display:inline-block;margin-bottom:.5rem}button{border-radius:0}button,input,optgroup,select,textarea{margin:0;font-family:inherit;font-size:inherit;line-height:inherit}button,hr,input{overflow:visible}button,select{text-transform:none}[role=button]{cursor:pointer}select{word-wrap:normal}[type=button],[type=reset],[type=submit],button{-webkit-appearance:button}.btn:not(:disabled):not(.disabled),[type=button]:not(:disabled),[type=reset]:not(:disabled),[type=submit]:not(:disabled),button:not(:disabled){cursor:pointer}[type=search]{outline-offset:-2px;-webkit-appearance:none}.h1,.h2,.h3,.h4,.h5,.h6,h1,h2,h3,h4,h5,h6{margin-bottom:.5rem;font-weight:500;line-height:1.2}.h1,h1{font-size:2.5rem}.h2,h2{font-size:2rem}.h3,h3{font-size:1.75rem}.h4,h4{font-size:1.5rem}.h5,h5{font-size:1.25rem}.h6,h6{font-size:1rem}.display-1,.display-4{font-size:6rem;font-weight:300;line-height:1.2}.display-4{font-size:3.5rem}.small,small{font-size:80%;font-weight:400}.list-unstyled{padding-left:0;list-style:none}.img-fluid{max-width:100%;height:auto}code{font-size:87.5%;color:#e83e8c;word-wrap:break-word}.container{width:100%;padding-right:15px;padding-left:15px;margin-right:auto;margin-left:auto}@media (min-width:576px){.container{max-width:540px}}@media (min-width:768px){.container{max-width:720px}}@media (min-width:992px){.container{max-width:960px}}@media (min-width:1200px){.container{max-width:1140px}}.container-fluid,.container-lg,.container-md,.container-sm,.container-xl{width:100%;padding-right:15px;padding-left:15px;margin-right:auto;margin-left:auto}@media (min-width:576px){.container,.container-sm{max-width:540px}}@media (min-width:768px){.container,.container-md,.container-sm{max-width:720px}}@media (min-width:992px){.container,.container-lg,.container-md,.container-sm{max-width:960px}}@media (min-width:1200px){.container,.container-lg,.container-md,.container-sm,.container-xl{max-width:1140px}}.row{display:-ms-flexbox;display:flex;-ms-flex-wrap:wrap;flex-wrap:wrap;margin-right:-15px;margin-left:-15px}.col,.col-1,.col-10,.col-11,.col-12,.col-2,.col-3,.col-4,.col-5,.col-6,.col-7,.col-8,.col-9,.col-auto,.c ...
#   </style>
#   <script defer="" src="https://ajax.googleapis.com/ajax/libs/jquery/3.5.1/jquery.min.js">
#   </script>
#   <script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.16.0/umd/popper.min.js">
#   </script>
#   <script defer="" src="https://maxcdn.bootstrapcdn.com/bootstrap/4.5.0/js/bootstrap.min.js">
#   </script>
#   <!--   	<link rel="stylesheet" href="https://cdn.datatables.net/1.10.21/css/dataTables.bootstrap4.min.css" /> -->
#   <!--   	<link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/open-iconic/1.1.1/font/css/open-iconic-bootstrap.min.css" /> -->
#   <!--   	<link rel="stylesheet" href="/css/recipe/jupyter.css?v=1" /> -->
#   <!--   	<link rel="stylesheet" href="/css/mdb.css"> -->
#   <!-- inline Datatables CSS -->
#   <style>
#    table.dataTable{clear:both;margin-top:6px!important;margin-bottom:6px!important;max-width:none!important;border-collapse:separate!important;border-spacing:0}table.dataTable td,table.dataTable th{-webkit-box-sizing:content-box;box-sizing:content-box}div.dataTables_wrapper div.dataTables_filter{text-align:right}div.dataTables_wrapper div.dataTables_filter label{font-weight:400;white-space:nowrap;text-align:left}div.dataTables_wrapper div.dataTables_filter input{margin-left:.5em;display:inline-block;width:auto}div.dataTables_wrapper div.dataTables_info{padding-top:.85em;white-space:nowrap}div.dataTables_wrapper div.dataTables_paginate{margin:0;white-space:nowrap;text-align:right}div.dataTables_wrapper div.dataTables_paginate ul.pagination{margin:2px 0;white-space:nowrap;justify-content:flex-end}table.dataTable thead>tr>td.sorting,table.dataTable thead>tr>td.sorting_asc,table.dataTable thead>tr>td.sorting_desc,table.dataTable thead>tr>th.sorting,table.dataTable thead>tr>th.sorting_asc,table.dataTable thead>tr>th.sorting_desc{padding-right:30px}table.dataTable thead .sorting,table.dataTable thead .sorting_asc,table.dataTable thead .sorting_asc_disabled,table.dataTable thead .sorting_desc,table.dataTable thead .sorting_desc_disabled{cursor:pointer;position:relative}table.dataTable thead .sorting:after,table.dataTable thead .sorting:before,table.dataTable thead .sorting_asc:after,table.dataTable thead .sorting_asc:before,table.dataTable thead .sorting_asc_disabled:after,table.dataTable thead .sorting_asc_disabled:before,table.dataTable thead .sorting_desc:after,table.dataTable thead .sorting_desc:before,table.dataTable thead .sorting_desc_disabled:after,table.dataTable thead .sorting_desc_disabled:before{position:absolute;bottom:.9em;display:block;opacity:.3}table.dataTable thead .sorting:before,table.dataTable thead .sorting_asc:before,table.dataTable thead .sorting_asc_disabled:before,table.dataTable thead .sorting_desc:before,table.dataTable thead .sorting_desc_disabled:before{right:1em;content:"\2191"}table.dataTable thead .sorting:after,table.dataTable thead .sorting_asc:after,table.dataTable thead .sorting_asc_disabled:after,table.dataTable thead .sorting_desc:after,table.dataTable thead .sorting_desc_disabled:after{right:.5em;content:"\2193"}@media screen and (max-width:767px){div.dataTables_wrapper div.dataTables_filter,div.dataTables_wrapper div.dataTables_info,div.dataTables_wrapper div.dataTables_length,div.dataTables_wrapper div.dataTables_paginate{text-align:center}div.dataTables_wrapper div.dataTables_paginate ul.pagination{justify-content:center!important}}table.table-bordered.dataTable{border-right-width:0}table.table-bordered.dataTable td,table.table-bordered.dataTable th{border-left-width:0}table.table-bordered.dataTable td:last-child,table.table-bordered.dataTable th:last-child{border-right-width:1px}table.table-bordered.dataTable tbody td,table.table-bordered.dataTable tbody th{border-bottom-width:0}
#   </style>
#   <!-- inline MDB CSS -->
#   <style>
#    @keyframes fadeInDown{0%{opacity:0;-webkit-transform:translate3d(0,-100%,0);transform:translate3d(0,-100%,0)}to{opacity:1;-webkit-transform:translate3d(0,0,0);transform:translate3d(0,0,0)}}.bg-light{background-color:#e0e0e0}.text-dark{color:#212121!important}.waves-effect{position:relative;overflow:hidden;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-tap-highlight-color:transparent}.waves-effect .waves-ripple{position:absolute;width:100px;height:100px;margin-top:-50px;margin-left:-50px;pointer-events:none;background:rgba(0,0,0,.2);background:radial-gradient(rgba(0,0,0,.2) 0,rgba(0,0,0,.3) 40%,rgba(0,0,0,.4) 50%,rgba(0,0,0,.5) 60%,rgba(255,255,255,0) 70%);border-radius:50%;opacity:0;-webkit-transition-property:opacity,-webkit-transform;transition-property:transform,opacity;transition-property:transform,opacity,-webkit-transform;-webkit-transition:all .5s ease-out;transition:all .5s ease-out;-webkit-transform:scale(0) translate(0,0);transform:scale(0) translate(0,0)}.waves-effect.waves-light .waves-ripple{background:rgba(255,255,255,.4);background:radial-gradient(rgba(255,255,255,.2) 0,rgba(255,255,255,.3) 40%,rgba(255,255,255,.4) 50%,rgba(255,255,255,.5) 60%,rgba(255,255,255,0) 70%)}a.waves-effect,a.waves-light{display:inline-block}.animated{-webkit-animation-duration:1s;animation-duration:1s;-webkit-animation-fill-mode:both;animation-fill-mode:both}.fadeInDown{-webkit-animation-name:fadeInDown;animation-name:fadeInDown}.btn{margin:.375rem;color:inherit;text-transform:uppercase;word-wrap:break-word;white-space:normal;cursor:pointer;border:0;border-radius:.125rem;-webkit-box-shadow:0 2px 5px 0 rgba(0,0,0,.16),0 2px 10px 0 rgba(0,0,0,.12);box-shadow:0 2px 5px 0 rgba(0,0,0,.16),0 2px 10px 0 rgba(0,0,0,.12);-webkit-transition:color .15s ease-in-out,background-color .15s ease-in-out,border-color .15s ease-in-out,-webkit-box-shadow .15s ease-in-out;transition:color .15s ease-in-out,background-color .15s ease-in-out,border-color .15s ease-in-out,box-shadow .15s ease-in-out;transition:color .15s ease-in-out,background-color .15s ease-in-out,border-color .15s ease-in-out,box-shadow .15s ease-in-out,-webkit-box-shadow .15s ease-in-out;padding:.84rem 2.14rem;font-size:1.01rem}.btn:active,.btn:focus,.btn:hover{outline:0;-webkit-box-shadow:0 5px 11px 0 rgba(0,0,0,.18),0 4px 15px 0 rgba(0,0,0,.15);box-shadow:0 5px 11px 0 rgba(0,0,0,.18),0 4px 15px 0 rgba(0,0,0,.15)}.btn-default{color:#fff;background-color:#2bbbad!important}.btn-default:hover{color:#fff;background-color:#30cfc0}.btn-default.focus,.btn-default:focus{-webkit-box-shadow:0 5px 11px 0 rgba(0,0,0,.18),0 4px 15px 0 rgba(0,0,0,.15);box-shadow:0 5px 11px 0 rgba(0,0,0,.18),0 4px 15px 0 rgba(0,0,0,.15)}.btn-default.active,.btn-default:active,.btn-default:focus{background-color:#186860}.btn-default:not([disabled]):not(.disabled).active,.btn-default:not([disabled]):not(.disabled):active,.show>.btn-default.dropdown-toggle{background-color:#186860!important;-webkit-box-shadow:0 5px 11px 0 rgba(0,0,0,.18),0 4px 15px 0 rgba(0,0,0,.15);box-shadow:0 5px 11px 0 rgba(0,0,0,.18),0 4px 15px 0 rgba(0,0,0,.15)}.btn-default:not([disabled]):not(.disabled).active:focus,.btn-default:not([disabled]):not(.disabled):active:focus,.show>.btn-default.dropdown-toggle:focus{-webkit-box-shadow:0 5px 11px 0 rgba(0,0,0,.18),0 4px 15px 0 rgba(0,0,0,.15);box-shadow:0 5px 11px 0 rgba(0,0,0,.18),0 4px 15px 0 rgba(0,0,0,.15)}.navbar{font-weight:400;-webkit-box-shadow:0 2px 5px 0 rgba(0,0,0,.16),0 2px 10px 0 rgba(0,0,0,.12);box-shadow:0 2px 5px 0 rgba(0,0,0,.16),0 2px 10px 0 rgba(0,0,0,.12)}.navbar .navbar-toggler{border-width:0;outline:0}.navbar .nav-item .nav-link{display:block}@media (max-width:992px){.navbar .nav-item .nav-link{padding-right:6px;padding-left:6px}}.navbar.navbar-light .navbar-toggler-icon{cursor:pointer;background-image:url("data:image/svg+xml;charset=utf8,%3Csvg viewBox='0 0 32 32' xmlns='http://www.w3.org/2000/svg'%3E%3Cpath stroke='rg ...
#   </style>
#   <style>
#    .emailinput {
# 	line-height: 1.25;
# 	letter-spacing: normal;
# 	border: 1px solid #bbc0c4;
# 	border-radius: 4px;
# 	background:#fff;
# 	font-size:1.25em;
# 	width:55%;
# 	height:3em;
# 	padding: 1.15rem 1rem;
# }
#
# .subbutton {
#   background-color: #ffc844;
#   border-radius: 4px;
#   width:180px;
#   border: none;
#   color: #000;
#   padding: 13px 20px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 18px;
#   font-weight:normal;
#   margin: 5px 7px;
#   cursor: pointer;
#   -webkit-transition-duration: 0.4s; /* Safari */
#   transition-duration: 0.4s;
# }
#
# .subbutton1 {
#   box-shadow: 0 8px 16px 0 rgba(0,0,0,0.2), 0 6px 20px 0 rgba(0,0,0,0.19);
# }
#
# .subbutton2:hover {
#   box-shadow: 0 12px 16px 0 rgba(0,0,0,0.24),0 17px 50px 0 rgba(0,0,0,0.19);
# }
#
# .sprite {
#     background: url(//daxg39y63pxwu.cloudfront.net/dezyre/sprite-images/mini-project-ideogram-50.png) no-repeat top left;
#     width: 50px;
#     height: 50px;
# }
#   </style>
#   <style>
#    .header_top_dc {
# 				background: #05192d!important;  /* fallback for old browsers */
# 				background: -webkit-linear-gradient(268deg, #05192d, #05192d)!important;  /* Chrome 10-25, Safari 5.1-6 */
# 				background: linear-gradient(268deg,#05192d , #05192d)!important;
# 				box-shadow:none!important;
# 			}
#
#
# 			.header_bg {
# 				color:#fff !important;
# 				padding-top:10px;
# 				padding-bottom:60px!important;
# 				max-width: 100%;
# 				background: #05192d;  /* fallback for old browsers */
# 				background: -webkit-linear-gradient(268deg, #05192d, #05192d);  /* Chrome 10-25, Safari 5.1-6 */
# 				background: linear-gradient(268deg, #05192d, #05192d);
# 			}
#
# 			.button2 {
# 				color:#fff!important;
# 				border:1px solid white;padding:1px 17px;border-radius:4px;
# 				display: inline-block;
# 				line-height:32px;
# 			}
#
# 			.header_link {
# 				color:#fff!important;
# 				padding:1px 17px;
# 				display: inline-block;
# 				line-height:32px;
# 			}
#
#
#
# 			@media (max-width: 479px) {
# 				.logo {
# 				    height: 36px;
# 				    margin-right: 5px;
# 				}
# 			}
#   </style>
#   <style>
#    code {
#   display: block;
#   white-space: pre-wrap
# }
#
# .h1, .h2, .h3, .h4, .h5, .h6, h1, h2, h3, h4, h5, h6 {
#     font-family: "Work sans", "Helvetica Neue", Helvetica, Arial, sans-serif !important;
#     color: #3d4251;
#
# }
# h1, h2, h3 {
#     font-weight: 400;
#     line-height: 46px;
#
# }
# h1, .h1 {
#     font-size: 28px;
#     color:#3d4251;
#     letter-spacing:0px;
# }
#
# h2, .h2 {
#     font-size: 26px;
#     color:#3d4251;
#     font-weight:400;
#     line-height: 40px;
# }
#
# h4, .h4 {
#     font-size: 22px;
# 	color: #3d4251 !important;
# 	line-height: 33px;
# }
#
# h3 {
# 	font-size: 24px;
#     color:#fff;
# }
#
# /*
# h5, .h5 {
#     font-size: 20px;
# 	color: #2595FF !important;
# 	line-height: 33px;
# 	letter-spacing:1px;
# 	font-weight: 400;
# }
# */
# h5, .h5 {
#     font-size: 20px;
# 	color: #000;
# 	line-height: 33px;
# 	letter-spacing:1px;
# 	font-weight: 400;
# }
# .pr-3,.px-3{padding-right:1rem!important}
#
# .tag {
# 	border-radius: 4px;
#
#     letter-spacing: 0.2px;
#
#     font-family: 'Lato',sans-serif;
#     padding:8px;
#     font-size: 13px;
#     margin-right: 2px;
#     text-decoration:none!important;
#     color: #39739d;
#     background-color: #E1ECF4;
#     border: 1px solid #e1e1e1;
#     line-height:35px;
# }
#
# .tag:hover {
#   background-color: #1c3050;
#   color:#fff;
# }
#
# .mbtn-large {
#     font-size: 18px;
#     line-height: 27px;
#     border-radius: 4.8px;
# }
#
#
# .mbtn-primary {
#     color: #000;
#     background-color: #ffc844;
#     border-color: #ffc844;
# }
#
# .mbtn {
#     display: inline-block;
#     font-weight: 500;
#     text-align: center;
#     white-space: nowrap;
#     vertical-align: middle;
#     font-family: "Work sans", "Helvetica Neue", Helvetica, Arial, sans-serif !important;
#
#
#     user-select: none;
#     border: 1px solid transparent;
#     padding: 12px 35px 12px 35px;
#     font-size: 15px;
#     line-height: 20px;
#     border-radius: 4.8px;
#     transition: color 0.15s ease-in-out, background-color 0.15s ease-in-out, border-color 0.15s ease-in-out, box-shadow 0.15s ease-in-out;
# }
#
# .card {
# 	border: 1px solid #ebf4f7;
# 	color: #4d5356;
# 	font-weight:400;
# 	padding:0px;
# 	font-size:15px;
# 	line-height:28px;
# }
#
# .card-header {
# 	text-align:center;
# 	background-color:#fff;
# 	border-bottom:0px;
# }
#
# .card-body {
# 	background-color:#fff;
# }
#
# .card-footer {
# 	text-align:center;
# 	background-color:#ebf4f7;
# 	border-top:0px;
# }
#
#
# .course-block__technology {
#     background-position: 0 0;
#     background-repeat: no-repeat;
#     background-size: 45px 42px;
#     display: block;
#     height: 42px;
#     margin-left: auto;
#     margin-right: auto;
#     margin-top: -18px;
#     width: 45px;
# }
#
# .display-1 {
# 	font-size:3.0rem;
# 	line-height:1.4;
# }
#
# .display-2 {
# 	font-size:2.3rem;
# 	font-weight:400;
# 	line-height:1.4;
# }
#
# .display-4 {
# 	font-size:1.5rem;
# 	font-weight:400;
# }
#
# .dropdown-item {
# 	line-height:30px;
# }
#
# .dropdown-menu {
# 	min-width: 200px;
# 	line-height:30px;
# 	left:-700px;
# 	max-height:500px;
#     overflow-y: scroll;
# }
#
# .recipe-menu {
# 	min-width: 200px;
# 	line-height:30px;
# 	left:-50px;
# 	max-height:500px;
#     overflow-y: scroll;
# }
#
# .dropdown-menu.columns-2 {
# 	min-width: 600px;
# }
# .dropdown-menu.columns-3 {
# 	min-width: 900px;
# }
#
# .dropdown-menu.columns-4 {
# 	min-width: 1200px;
# }
#
# .dropdown-menu a:hover {
# 	text-decoration: none;
# 	background-color: #ebf4f7;
# }
# .learning-path-dropdown{
# 	position: absolute;
# 	left:0;
# }
# #dropdownLearningPath{
# 	padding-left:0px;
# }
# .recipe-navbar{
# 	justify-content:flex-end;
# 	flex-wrap: nowrap;
# }
# @media (max-width: 992px) {
# 	.recipe-navbar{
# 		align-items: flex-start;
# 	}
# 	.recipe-navbar > li{
# 		padding-top:15px;
# 	}
# }
# @media (max-width: 767px) {
# 	.dropdown-menu.multi-column {
# 		min-width: 240px !important;
# 		overflow-x: hidden;
# 	}
# 	#recipeMenuLink{
# 		padding-left:0px;
# 	}
# }
#
# :target::before {
#   content: "";
#   display: block;
#   height: 80px; /* fixed header height*/
#   margin-top: -50px; /* negative fixed header height */
# }
#
# a:focus {
#     outline:none;
# }
#
# @media (max-width: 600px) {
#   .topbutton {
#     background-color: #ffc844;
#     border-radius: 4px;
# 	  width:102px;
# 	  border: none;
# 	  color: #000;
# 	  padding: 6px 8px;
# 	  text-align: center;
# 	  text-decoration: none;
# 	  display: inline-block;
# 	  font-size: 12px;
# 	  margin: 4px 2px;
# 	  cursor: pointer;
# 	  -webkit-transition-duration: 0.4s; /* Safari */
# 	  transition-duration: 0.4s;
#   }
# }
# @media (min-width: 600px) {
#   .topbutton {
#     background-color: #ffc844;
#
#     border-radius: 4px;
# 	  width:150px;
# 	  border: none;
# 	  color: #000;
# 	  padding: 6px 8px;
# 	  text-align: center;
# 	  text-decoration: none;
# 	  display: inline-block;
# 	  font-size: 16px;
# 	  font-weight:450;
#
# 	  cursor: pointer;
# 	  -webkit-transition-duration: 0.4s; /* Safari */
# 	  transition-duration: 0.4s;
#   }
# }
#
# .modal-sm {
#     max-width: 50%!important;
# }
#
# #dataTablesFaculties tbody tr.odd {
# 	background-color: #ebf4f7;
# }
#
# #dataTablesFaculties tbody tr.even {
# 	background-color: #fff;
# }
#   </style>
#   <!-- START Rakuten Marketing Tracking -->
#   <script type="text/javascript">
#    (function (url) {
#       /*Tracking Bootstrap Set Up DataLayer objects/properties here*/
#       if(!window.DataLayer){
#         window.DataLayer = {};
#       }
#       if(!DataLayer.events){
#         DataLayer.events = {};
#       }
#       DataLayer.events.SPIVersion = DataLayer.events.SPIVersion || "3.4.1";
#       DataLayer.events.SiteSection = "1";
#
#       var loc, ct = document.createElement("script");
#       ct.type = "text/javascript";
#       ct.async = true; ct.src = url; loc = document.getElementsByTagName('script')[0];
#       loc.parentNode.insertBefore(ct, loc);
#       }(document.location.protocol + "//tag.rmp.rakuten.com/124265.ct.js"));
#   </script>
#   <!-- END Rakuten Marketing Tracking -->
#  </head>
#  <body>
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PM3NN4G" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <nav class="ml-auto navbar navbar-expand-lg header_top_dc navbar-light px-md-5 py-md-3">
#    <a class="navbar-brand" href="/">
#     <img alt="DeZyre" class="logo" height="36" src="https://daxg39y63pxwu.cloudfront.net/dezyre2.0/images/project_pro_logo_white.png" width="180"/>
#    </a>
#    <button aria-label="navbar toggler" class="navbar-light navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" type="button">
#     <span style="opacity:0.70;">
#      <svg class="feather feather-menu" fill="none" height="28" stroke="#fff" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24" width="28" xmlns="http://www.w3.org/2000/svg">
#       <line x1="3" x2="21" y1="12" y2="12">
#       </line>
#       <line x1="3" x2="21" y1="6" y2="6">
#       </line>
#       <line x1="3" x2="21" y1="18" y2="18">
#       </line>
#      </svg>
#     </span>
#    </button>
#    <ul class="navbar navbar-nav recipe-navbar collapse navbar-collapse" id="navbarSupportedContent">
#     <li class="mx-2 nav-item">
#      <a class="nav-link header_link" href="/projects" onclick="gtag('event', 'click', {'event_category' : 'recipe-layout', 'event_label' : 'solved-projects'});">
#       Solved Projects
#      </a>
#     </li>
#     <li class="mx-2 nav-item">
#      <a class="nav-link header_link" href="/dezyre-projectpro-reviews">
#       Customer Reviews
#      </a>
#     </li>
#     <li class="mt-3 mx-2 nav-item mt-sm-0">
#      <a class="position-relative nav-link header_link text-nowrap" href="/industry-experts">
#       Experts
#       <span class="badge badge-primary new-badge" style="position:absolute; top:-10px;font-size:0.68rem; right:-10px;">
#        New
#       </span>
#      </a>
#     </li>
#     <li class="mx-2 nav-item dropdown">
#      <a class="nav-link header_link position-relative text-nowrap dropdown-toggle" data-toggle="dropdown" href="#" id="dropdownLearningPath" role="button">
#       Project Path
#      </a>
#      <div aria-labelledby="dropdownLearningPath" class="dropdown-menu learning-path-dropdown">
#       <a class="dropdown-item" href="/user/customised-learning-path">
#        Data Science Project Path
#       </a>
#       <a class="dropdown-item" href="/user/customised-bd-learning-path">
#        Big Data Project Path
#       </a>
#      </div>
#     </li>
#     <li class="ml-2 mr-4 nav-item dropdown">
#      <a aria-expanded="false" aria-haspopup="true" class="nav-link header_link dropdown-toggle" data-toggle="dropdown" href="#" id="recipeMenuLink">
#       Recipes
#      </a>
#      <div aria-labelledby="recipeMenuLink" class="dropdown-menu recipe-menu">
#       <a class="dropdown-item" href="/recipes">
#        All Recipes
#       </a>
#       <a class="dropdown-item" href="/tags">
#        Recipes By Tag
#       </a>
#       <a class="dropdown-item" href="/companies">
#        Recipes By Company
#       </a>
#       <!-- <a class="dropdown-item" href="/project/upcoming-recipes">Upcoming Recipes</a>  -->
#      </div>
#     </li>
#     <li class="mr-4 nav-item">
#      <a class="nav-link header_link" href="/user/login">
#       Sign In
#      </a>
#     </li>
#     <li class="nav-item">
#      <button class="topbutton subbutton1 pull-right" data-target="#recipeTopStartLearning" data-toggle="modal" onclick="gtag('event', 'click', {'event_category' : 'top menu', 'event_label' : 'RecipePage'});" type="button">
#       Start Learning
#      </button>
#     </li>
#    </ul>
#   </nav>
#   <div class="p-2 pt-3 px-sm-5 bg-light recipe-parent-bg-div">
#    <style>
#     @media (max-width:500px){
# 	#recipelist_email{
# 		width:100%!important;
# 	}
# }
#
# .progress {height: 8px;}
# #add {
#   display: inline-block;
#   /*padding-left: 140px;*/
#   float: left;
# }
# #dataTablesFaculties_length {
# 	float: left;
# }
#
# /*
# input {
#   width: 100%;
#   background: #f5f5f5;
#   border-radius: 4px;
#   border: solid 2px #e6e6e6;
#   height: 3em;
# }
# */
#
#
# @media only screen and (max-width: 768px) {
#   /* For mobile phones: */
#   #add {width: 100%;}
#   .recipe-title{ font-size: 28px; }
# }
#
# /* calc([min] + (max - min) * ((100vw - min viewport) / ([max viewport] - [min viewport]))); */
# .recipe-title{ /* responsive title */
# 	font-size: calc(40px + (48 - 40) * ((100vw - 300px) / (1600 - 300)));
# 	line-height:1.5;
# }
#    </style>
#    <div class="container-fluid px-4">
#     <div class="row">
#      <div class="col-lg-12 mt-3">
#       <div class="col-lg-12 text-center mt-5">
#        <h1 class="display-1 recipe-title">
#         Release your
#         <span class="shadow-sm" style="white-space:nowrap;background-color:#f0f4f7;padding:2px 10px;border:1px solid #dde6ed;border-radius:4px;color:#000">
#          Data Science
#         </span>
#         projects faster
#        </h1>
#       </div>
#       <!--
# 		    <div class="col-lg-12 text-center mt-5 d-none d-sm-block">
# 		    	<h1 class="display-1">
# 		    	Release your <span style="background-color:#f0f4f7;padding:2px 10px;border:1px solid #dde6ed;border-radius:4px;color:#000">Data Science</span> projects faster
# 		    	</h1>
# 		    </div>
# 		    <div class="col-lg-12 text-center mt-5 d-block d-sm-none">
# 		    	<h1>
# 		    	Release your <br/>
# 		    	<span style="background-color:#f0f4f7;padding:2px 10px;border:1px solid #dde6ed;border-radius:4px;color:#000">Data Science</span><br/>
# 		    	projects faster
# 		    	</h1>
# 		    </div>
# 		     -->
#       <div class="col-lg-12 text-center mt-4">
#        <h3 class="text-dark">
#         Get ready to use code snippets for solving real-world business problems
#        </h3>
#       </div>
#       <div class="col-lg-12 text-center mt-5">
#        <span>
#         <span>
#          <input class="emailinput" data-email-validation="true" id="recipelist_email" name="recipelist_email" placeholder="Your email address" spellcheck="false" type="email"/>
#         </span>
#         <span>
#          <button class="recipelist_subscription subbutton subbutton1" data-button="recipeSubscribe" id="email1-button" onclick="gtag('event', 'click', {'event_category' : 'signupbutton', 'event_label' : 'activate-recipetop'});" type="button">
#           TRY FOR FREE
#          </button>
#         </span>
#        </span>
#        <div class="col-lg-12" style="margin-left:170px;margin-top:5px;text-align:left;margin-bottom:20px">
#         <span id="recipelist_email-help-text" style="color:red">
#         </span>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="mt-5 px-4">
#     <div class="card-deck p-1">
#      <div class="card shadow">
#       <div class="card-body text-center p-4">
#        <div>
#         <img alt="python notebook image" height="48" src="https://daxg39y63pxwu.cloudfront.net/dezyre/images/recipes/ipython_notebook.png" width="48"/>
#        </div>
#        <div class="mt-3">
#         <h4>
#          iPython Notebook
#         </h4>
#        </div>
#        <p class="card-text">
#         Download the iPython notebook for 100+ code snippets.
#        </p>
#       </div>
#      </div>
#      <div class="card shadow">
#       <div class="card-body text-center">
#        <div>
#         <img alt="explanation image" height="48" src="https://daxg39y63pxwu.cloudfront.net/dezyre/images/recipes/explanation.png" width="48"/>
#        </div>
#        <div class="mt-3">
#         <h4>
#          Explanations
#         </h4>
#        </div>
#        <p class="card-text">
#         Code snippets include helpful explanations to understand the code logic.
#        </p>
#       </div>
#      </div>
#      <div class="card shadow">
#       <div class="card-body text-center">
#        <div>
#         <img alt="python image" height="48" src="https://daxg39y63pxwu.cloudfront.net/dezyre/images/recipes/python.png" width="48"/>
#        </div>
#        <div class="mt-3">
#         <h4>
#          Detailed Coverage
#         </h4>
#        </div>
#        <p class="card-text">
#         Deep coverage of various data science topics needed for real industry projects.
#        </p>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="mt-5 px-4 recipe_list_login_layout">
#     <div class="container-fluid">
#      <div class="row">
#       <div class="col-lg-9">
#        <div class="panel panel-default">
#         <div id="extraDiv">
#          <select class="form-control input-sm" id="table-filter">
#           <option value="">
#            All Categories
#           </option>
#           <option>
#            Apache Hadoop Projects
#           </option>
#           <option>
#            Apache Hive Projects
#           </option>
#           <option>
#            Hadoop HDFS Projects
#           </option>
#           <option>
#            Apache Sqoop Projects
#           </option>
#           <option>
#            Spark SQL Projects
#           </option>
#           <option>
#            Spark Streaming Projects
#           </option>
#           <option>
#            Apache Spark Projects
#           </option>
#           <option>
#            PySpark Projects
#           </option>
#           <option>
#            Apache Zepellin Projects
#           </option>
#           <option>
#            Apache Kafka Projects
#           </option>
#           <option>
#            Data Science Projects in Python
#           </option>
#           <option>
#            Data Science Projects in R
#           </option>
#           <option>
#            Machine Learning Projects in Python
#           </option>
#           <option>
#            Machine Learning Projects in R
#           </option>
#           <option>
#            Deep Learning Projects
#           </option>
#           <option>
#            Neural Network Projects
#           </option>
#           <option>
#            NLP Projects
#           </option>
#           <option>
#            Data Munging
#           </option>
#           <option>
#            Pandas
#           </option>
#           <option>
#            Pandas dataframe
#           </option>
#           <option>
#            Pandas cheatsheet
#           </option>
#           <option>
#            Categorical variable examples
#           </option>
#           <option>
#            Python Matrix
#           </option>
#           <option>
#            Python regression
#           </option>
#           <option>
#            Data cleaning python
#           </option>
#           <option>
#            Regression examples
#           </option>
#           <option>
#            Machine Learning Recipes
#           </option>
#           <option>
#            Data visualization
#           </option>
#           <option>
#            Feature extraction
#           </option>
#           <option>
#            Hyperparameter tuning
#           </option>
#           <option>
#            Model selection
#           </option>
#           <option>
#            Model accuracy
#           </option>
#           <option>
#            Big Data Recipes
#           </option>
#           <option>
#            AWS Projects
#           </option>
#          </select>
#         </div>
#         <div class="panel-body">
#          <div class="dataTable_wrapper table-responsive">
#           <table class="responsive table table-striped table-bordered dt-responsive table-hover" id="dataTablesFaculties" style="width:100%;">
#            <thead>
#             <tr>
#              <th class="col-lg-0">
#              </th>
#              <th class="col-lg-8" style="font-size:10px">
#               CODE SNIPPET
#              </th>
#              <th class="col-lg-0" style="font-size:10px">
#               CATEGORY
#              </th>
#             </tr>
#            </thead>
#            <tbody>
#             <tr>
#              <td>
#              </td>
#              <td style="line-height:3.2em;font-size:15px">
#               <a href="/recipes/connect-ec2-instance-windows-server" target="_blank">
#                How to connect EC2 instance to windows server?
#               </a>
#              </td>
#              <td>
#               Big Data Recipes,How does Amazon EC2 Work,What’s An AMI,Steps To Connect Amazon Windows EC2 Instance,Big Data,How does Amazon EC2 Work,What’s An AMI,Steps To Connect Amazon Windows EC2 Instance
#              </td>
#             </tr>
#             <tr>
#              <td>
#              </td>
#              <td style="line-height:3.2em;font-size:15px">
#               <a href="/recipes/explain-auto-scaling-and-its-components" target="_blank">
#                Explain Auto scaling and its components
#               </a>
#              </td>
#              <td>
#               Big Data Recipes,what is auto scaling aws,How does Autoscaling work in AWS,Autoscaling Components,Big Data,what is auto scaling aws,How does Autoscaling work in AWS,Autoscaling Components
#              </td>
#             </tr>
#             <tr>
#              <td>
#              </td>
#              <td style="line-height:3.2em;font-size:15px">
#               <a href="/recipes/what-is-emr-elastic-map-reduced-aws" target="_blank">
#                What is EMR (Elastic Map Reduced) in AWS
#               </a>
#              </td>
#              <td>
#               Big Data Recipes,what is aws elastic mapreduce,what is amazon elastic mapreduce,aws emr elastic mapreduce,Big Data,what is aws elastic mapreduce,what is amazon elastic mapreduce,aws emr elastic mapreduce
#              </td>
#             </tr>
#             <tr>
#              <td>
#              </td>
#              <td style="line-height:3.2em;font-size:15px">
#               <a href="/recipes/what-are-various-routing-policies-route53" target="_blank">
#                What are the various Routing Policies in route53
#               </a>
#              </td>
#              <td>
#               Big Data Recipes,routing policies aws,routing policy route53,What is Amazon Route 53,How does Route 53 work,Big Data,routing policies aws,routing policy route53,What is Amazon Route 53,How does Route 53 work
#              </td>
#             </tr>
#             <tr>
#              <td>
#              </td>
#              <td style="line-height:3.2em;font-size:15px">
#               <a href="/recipes/what-are-database-types-rds" target="_blank">
#                What are the database types in RDS
#               </a>
#              </td>
#              <td>
#               Big Data Recipes,How does Amazon RDS work,what are the different database types,different types of rds,Big Data,How does Amazon RDS work,what are the different database types,different types of rds
#              </td>
#             </tr>
#             <tr>
#              <td>
#              </td>
#              <td style="line-height:3.2em;font-size:15px">
#               <a href="/recipes/explain-different-types-of-storage-gateways" target="_blank">
#                Explain different types of storage gateways
#               </a>
#              </td>
#              <td>
#               Big Data Recipes,types of storage gateway,types of storage gateway,different types of storage gateway aws,what are the different types of storage gateway in aws,Big Data,types of storage gateway,types of storage gateway,different types of storage gateway aws,what are the different types of storage gateway in aws
#              </td>
#             </tr>
#             <tr>
#              <td>
#              </td>
#              <td style="line-height:3.2em;font-size:15px">
#               <a href="/recipes/what-is-cloud-front" target="_blank">
#                What is cloud front?
#               </a>
#              </td>
#              <td>
#               Big Data Recipes,what's cloudfront,cloudfront what is it,aws what is cloudfront,Key Benefits of CloudFront,Big Data,what's cloudfront,cloudfront what is it,aws what is cloudfront,Key Benefits of CloudFront
#              </td>
#             </tr>
#             <tr>
#              <td>
#              </td>
#              <td style="line-height:3.2em;font-size:15px">
#               <a href="/recipes/different-types-of-storages-s3" target="_blank">
#                Different types of storages in s3
#               </a>
#              </td>
#              <td>
#               Big Data,types of s3 storage in aws,how many types of storage are there in aws,s3 storage type
#              </td>
#             </tr>
#             <tr>
#              <td>
#              </td>
#              <td style="line-height:3.2em;font-size:15px">
#               <a href="/recipes/what-is-load-balancer-aws" target="_blank">
#                What is  load balancer in AWS?
#               </a>
#              </td>
#              <td>
#               Big Data Recipes,what is load balancing in aws,AWS Load Balancer Types,AWS Load Balancer Latency,Big Data,what is load balancing in aws,AWS Load Balancer Types,AWS Load Balancer Latency
#              </td>
#             </tr>
#             <tr>
#              <td>
#              </td>
#              <td style="line-height:3.2em;font-size:15px">
#               <a href="/recipes/what-is-elastic-block-storage-ebs-" target="_blank">
#                What is Elastic Block Storage (EBS)
#               </a>
#              </td>
#              <td>
#               Big Data Recipes,Features of EBS,Types of EBS Volumes,Big Data,Features of EBS,Types of EBS Volumes
#              </td>
#             </tr>
#             <tr>
#              <td>
#              </td>
#              <td style="line-height:3.2em;font-size:15px">
#               <a href="/recipes/what-is-amazon-cloud-watch" target="_blank">
#                What is Amazon Cloud watch
#               </a>
#              </td>
#              <td>
#               Big Data Recipes,amazon cloudwatch,what is amazon cloudwatch,Cloud Watch features,Big Data,amazon cloudwatch,what is amazon cloudwatch,Cloud Watch features
#              </td>
#             </tr>
#             <tr>
#              <td>
#              </td>
#              <td style="line-height:3.2em;font-size:15px">
#               <a href="/recipes/what-are-different-types-of-ec2-instances-based-on-their-costs" target="_blank">
#                What are  different types of EC2 instances based on their costs
#               </a>
#              </td>
#              <td>
#               Big Data Recipes,What Is A Spot Instance,What Are On-Demand Instances,What Is a Reserved Instance in AWS?,Big Data,What Is A Spot Instance,What Are On-Demand Instances,What Is a Reserved Instance in AWS?
#              </td>
#             </tr>
#             <tr>
#              <td>
#              </td>
#              <td style="line-height:3.2em;font-size:15px">
#               <a href="/recipes/what-is-ec2-instance" target="_blank">
#                What is EC2 instance?
#               </a>
#              </td>
#              <td>
#               Big Data Recipes,what is ec2 instance in aws,what is ec2 instance in aws,how to create ec2 instance,Big Data,what is ec2 instance in aws,what is ec2 instance in aws,how to create ec2 instance
#              </td>
#             </tr>
#             <tr>
#              <td>
#              </td>
#              <td style="line-height:3.2em;font-size:15px">
#               <a href="/recipes/what-is-iam-user-and-its-features" target="_blank">
#                what is IAM user and its features
#               </a>
#              </td>
#              <td>
#               Big Data Recipes,AWS IAM — Key Features,what is iam users,what is iam user in AWS,Big Data,AWS IAM — Key Features,what is iam users,what is iam user in AWS
#              </td>
#             </tr>
#             <tr>
#              <td>
#              </td>
#              <td style="line-height:3.2em;font-size:15px">
#               <a href="/recipes/what-is-aws-snow-familly-and-its-use-cases" target="_blank">
#                What is aws snow familly and its use cases
#               </a>
#              </td>
#              <td>
#               Big Data Recipes,what is aws snow family,Benefits of aws snow family,Members of AWS Snow Family,Big Data,what is aws snow family,Benefits of aws snow family,Members of AWS Snow Family
#              </td>
#             </tr>
#             <tr>
#              <td>
#              </td>
#              <td style="line-height:3.2em;font-size:15px">
#               <a href="/recipes/what-is-aws-snowmobile" target="_blank">
#                What is aws snowmobile
#               </a>
#              </td>
#              <td>
#               Big Data Recipes,What is aws snowmobile , benefits of Snowmobile in AWS,,Big Data,What is aws snowmobile , benefits of Snowmobile in AWS,
#              </td>
#             </tr>
#             <tr>
#              <td>
#              </td>
#              <td style="line-height:3.2em;font-size:15px">
#               <a href="/recipes/what-is-snowcone-and-its-uses" target="_blank">
#                What is snowcone and its uses
#               </a>
#              </td>
#              <td>
#               Big Data Recipes,what is snow cone,flavours of Snowcone,How AWS Snowcone Works,Big Data,what is snow cone,flavours of Snowcone,How AWS Snowcone Works
#              </td>
#             </tr>
#             <tr>
#              <td>
#              </td>
#              <td style="line-height:3.2em;font-size:15px">
#               <a href="/recipes/what-is-availability-zone-and-region" target="_blank">
#                What is the Availability Zone and Region
#               </a>
#              </td>
#              <td>
#               Big Data Recipes,availability zone,what is an availability zone in aws,EC2 instance,,Big Data,availability zone,what is an availability zone in aws,EC2 instance,
#              </td>
#             </tr>
#             <tr>
#              <td>
#              </td>
#              <td style="line-height:3.2em;font-size:15px">
#               <a href="/recipes/what-are-consistency-model-for-modern-dbs-offered-by-aws" target="_blank">
#                What are consistency model for modern DBs offered by AWS
#               </a>
#              </td>
#              <td>
#               Big Data Recipes,dbs in aws,aws dynamodb consistency model,aws consistency model,Big Data,dbs in aws,aws dynamodb consistency model,aws consistency model
#              </td>
#             </tr>
#             <tr>
#              <td>
#              </td>
#              <td style="line-height:3.2em;font-size:15px">
#               <a href="/recipes/what-is-elastic-transcoder" target="_blank">
#                What is Elastic Transcoder
#               </a>
#              </td>
#              <td>
#               Big Data Recipes,elastic transcoder in aws, elastic transcoder features,components of elastic transcoder,Big Data,elastic transcoder in aws, elastic transcoder features,components of elastic transcoder
#              </td>
#             </tr>
#             <tr>
#              <td>
#              </td>
#              <td style="line-height:3.2em;font-size:15px">
#               <a href="/recipes/what-is-vpc-and-why-we-use-this" target="_blank">
#                What is VPC and why we use this
#               </a>
#              </td>
#              <td>
#               Big Data Recipes,what does virtual private network mean,virtual private network benifits ,virtual private network features,Big Data,what does virtual private network mean,virtual private network benifits ,virtual private network features
#              </td>
#             </tr>
#             <tr>
#              <td>
#              </td>
#              <td style="line-height:3.2em;font-size:15px">
#               <a href="/recipes/introduction-snowflake-and-its-use-cases" target="_blank">
#                Introduction to Snowflake and its use cases
#               </a>
#              </td>
#              <td>
#               Big Data Recipes,snowflake arizona, snowflake eel, snowflake login, snowflake tutorial,Big Data,snowflake arizona, snowflake eel, snowflake login, snowflake tutorial
#              </td>
#             </tr>
#             <tr>
#              <td>
#              </td>
#              <td style="line-height:3.2em;font-size:15px">
#               <a href="/recipes/machine-learning-interview-questions-for-fresher" target="_blank">
#                Machine Learning Interview Questions
# ...
#          <li>
#           <a href="/recipes/find-optimal-parameters-using-randomizedsearchcv-for-regression" title="RandomizedSearchCV">
#            RandomizedSearchCV
#           </a>
#          </li>
#          <li>
#           <a href="/recipes/optimize-hyper-parameters-of-decisiontree-model-using-grid-search-in-python" title="Grid Search Decision Tree">
#            Grid Search Decision Tree
#           </a>
#          </li>
#          <li>
#           <a href="/recipes/find-optimal-parameters-for-catboost-using-gridsearchcv-for-classification" title="Catboost Hyperparameter Tuning">
#            Catboost Hyperparameter Tuning
#           </a>
#          </li>
#          <li>
#           <a href="/recipes/normalise-pandas-dataframe-column" title="Pandas Normalize Column">
#            Pandas Normalize Column
#           </a>
#          </li>
#          <li class="show-less-footer-link">
#           Show less
#          </li>
#         </div>
#        </ul>
#       </div>
#       <div class="mx-3 my-4 my-sm-0 footer-contact wow" style="visibility: visible; ">
#        <p class="text-white footer_header">
#         Trending Tutorials
#        </p>
#        <ul class="list-unstyled footer-list">
#         <li>
#          <a href="/data-science-in-python-tutorial/principal-component-analysis-tutorial" title="PCA in Machine Learning Tutorial">
#           PCA in Machine Learning Tutorial
#          </a>
#         </li>
#         <li>
#          <a href="/apache-spark-tutorial/pyspark-tutorial" title="PySpark Tutorial">
#           PySpark Tutorial
#          </a>
#         </li>
#         <li>
#          <a href="/hadoop-tutorial/hive-commands" title="Hive Commands Tutorial">
#           Hive Commands Tutorial
#          </a>
#         </li>
#         <li>
#          <a href="/hadoop-tutorial/hadoop-mapreduce-wordcount-tutorial" title="MapReduce in Hadoop Tutorial">
#           MapReduce in Hadoop Tutorial
#          </a>
#         </li>
#         <li>
#          <a href="/hadoop-tutorial/apache-hive-tutorial-tables" title="Apache Hive Tutorial -Tables">
#           Apache Hive Tutorial -Tables
#          </a>
#         </li>
#         <li>
#          <a href="/data-science-in-r-programming-tutorial/linear-regression-tutorial" title="Linear Regression Tutorial">
#           Linear Regression Tutorial
#          </a>
#         </li>
#         <li class="show-more-footer-items">
#          Show more
#         </li>
#         <div class="hidden-footer-links">
#          <li>
#           <a href="/apache-spark-tutorial/spark-tutorial" title="Apache Spark Tutorial">
#            Apache Spark Tutorial
#           </a>
#          </li>
#          <li>
#           <a href="/data-science-in-python-tutorial/performance-metrics-for-machine-learning-algorithm" title="Evaluate Performance Metrics for Machine Learning Models">
#            Evaluate Performance Metrics for Machine Learning Models
#           </a>
#          </li>
#          <li>
#           <a href="/data-science-in-r-programming-tutorial/k-means-clustering-techniques-tutorial" title="K-Means Clustering Tutorial">
#            K-Means Clustering Tutorial
#           </a>
#          </li>
#          <li>
#           <a href="/hadoop-tutorial/hadoop-sqoop-tutorial" title="Sqoop Tutorial">
#            Sqoop Tutorial
#           </a>
#          </li>
#          <li>
#           <a href="/data-science-in-r-programming-tutorial/r-tutorial-importing-data-from-web" title="R Import Data From Website">
#            R Import Data From Website
#           </a>
#          </li>
#          <li>
#           <a href="/apache-spark-tutorial/apache-spark-installation-tutorial" title="Install Spark on Linux">
#            Install Spark on Linux
#           </a>
#          </li>
#          <li>
#           <a href="/data-science-in-r-programming-tutorial/r-data-table-tutorial" title="Data.Table Packages in R">
#            Data.Table Packages in R
#           </a>
#          </li>
#          <li>
#           <a href="/hadoop-tutorial/zookeeper-tutorial" title="Apache ZooKeeper Hadoop Tutorial">
#            Apache ZooKeeper Hadoop Tutorial
#           </a>
#          </li>
#          <li>
#           <a href="/hadoop-tutorial/big-data-hadoop-tutorial" title="Hadoop Tutorial">
#            Hadoop Tutorial
#           </a>
#          </li>
#          <li class="show-less-footer-link">
#           Show less
#          </li>
#         </div>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="footer-bottom ml-sm-5">
#     <div class="mx-2" style="margin-top: 2%;">
#      <div class="text-white row">
#       <h4 class="text-left footer_header col-md-3">
#        <b class="text-white">
#         ProjectPro
#        </b>
#       </h4>
#       <div class="second-block-links col-md-9">
#        <p class="mx-2">
#         © 2022 Iconiq Inc.
#        </p>
#        <p>
#         <a class="mx-2 ml-md-5 blue-links" href="/about-us">
#          About us
#         </a>
#        </p>
#        <p>
#         <a class="mx-2 blue-links" href="/contact-us">
#          Contact us
#         </a>
#        </p>
#        <p>
#         <a class="mx-2 blue-links" href="/privacy-policy">
#          Privacy policy
#         </a>
#        </p>
#        <p>
#         <a class="mx-2 blue-links" href="/user-policy">
#          User policy
#         </a>
#        </p>
#        <p>
#         <a class="mx-2 blue-links" href="/write-for-projectpro">
#          Write for ProjectPro
#         </a>
#        </p>
#       </div>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <script>
#    for(var b=document.querySelectorAll(".hidden-footer-links"),c=document.querySelectorAll(".show-less-footer-link"),d=document.querySelectorAll(".show-more-footer-items"),e=!1,f=0;f<=b.length-1;f++)b[f].style.display="none";
# 		for(var g=0;g<=c.length-1;g++)c[g].style.display="none",c[g].addEventListener("click",function(){if(e){for(var a=0;a<=b.length-1;a++)b[a].style.display="none",d[a].style.display="block";e=!1}else{for(a=0;a<=b.length-1;a++)b[a].style.display="block",c[a].style.display="block",d[a].style.display="none";e=!0}});
# 		for(var h=0;h<=d.length-1;h++)d[h].addEventListener("click",function(){if(e){for(var a=0;a<=b.length-1;a++)b[a].style.display="none",d[a].innerHTML="Show more";e=!1}else{for(a=0;a<=b.length-1;a++)b[a].style.display="block",c[a].style.display="block",d[a].style.display="none";e=!0}});
#   </script>
#   <!--
#         <script src="https://www.dwin1.com/19038.js" type="text/javascript" defer="defer"></script>
#          -->
#   <!--
#         <script type="text/javascript">
# _linkedin_partner_id = "2907076";
# window._linkedin_data_partner_ids = window._linkedin_data_partner_ids || [];
# window._linkedin_data_partner_ids.push(_linkedin_partner_id);
# </script><script type="text/javascript">
# (function(){var s = document.getElementsByTagName("script")[0];
# var b = document.createElement("script");
# b.type = "text/javascript";b.async = true;
# b.src = "https://snap.licdn.com/li.lms-analytics/insight.min.js";
# s.parentNode.insertBefore(b, s);})();
# </script>
# <noscript>
# <img height="1" width="1" style="display:none;" alt="" src="https://px.ads.linkedin.com/collect/?pid=2907076&fmt=gif" />
# </noscript>
#  -->
#   <!--  push notification code from subscriber -->
#   <!--
# <script type="text/javascript">var subscribersSiteId='295c9ea4-c7f6-42ac-a89a-1f892ebadb31';</script><script type="text/javascript" src="https://cdn.subscribers.com/assets/subscribers.js"></script>
#  -->
#   <!--  	<script src="https://my.hellobar.com/ac4e38aef266bceec9777ebfc01087bd97ace101.js" type="text/javascript" charset="utf-8" async="async"></script>  -->
#   <script>
#    window.onload = function(){
#
#
# 	$(".recipelist_subscription").click(function(e) {
#
# 		var email = $("#recipelist_email").val();
# 		var type = $(this).attr("data-button");
# 		var page_url = $(location).attr('href');
#
# 	    if(email.length == 0){
# 			$("#recipelist_email").focus();
# 			$("#recipelist_email").css("has-error");
# 			$("#recipelist_email-help-text").html("Please enter you email address.");
# 			return false;
# 		}
# 		if(!(validateEmail(email))){
# 			$("#recipelist_email").focus();
# 			$("#recipelist_email").addClass("has-error");
# 			$("#recipelist_email-help-text").html("Please enter a valid email address.");
# 			return false;
# 		}
#
# 		$.ajax({
# 	        type: "POST",
# 	        url: "/project/get-email",
#
# 	        data: {
# 	            email: email,
# 	            type:type,
# 	            page_url: page_url
# 	        },
# 	        dataType: 'json',
# 	        success: function(data) {
# 	        	$("#recipelist_email-help-text").html(data.message);
# 	        	setTimeout(function(){
# 	        		window.location.reload();
# 	        	}, 2000);
# 	        },
#
# 	        error: function(result) {
# 	        	//console.log(result);
# 	        	$( "div.modal-body" ).text( "An error occurred - Please contact care@projectpro.io" );
# 	        }
# 	    });
#
#
# 	});
#
#
# 	// code from recipe-list for data-tables (pagination)
#
# 	var table = $('#dataTablesFaculties').DataTable({
# 		"pagingType": "numbers", //https://stackoverflow.com/questions/15438307/datatables-bootstrap-pagination-only-show-previous-next
# 		responsive: {
#             details: {
#                 type: 'column'
#             }
#         },
# 		"aLengthMenu": [[25, 50, 75, -1], [25, 50, 75, "All"]],
#         "iDisplayLength": 10,
#         "bLengthChange": false,
#
# 		"columnDefs": [
# 		{
# 		    "targets": [ 2 ],
# 		    "visible": false,
# 		    "searchable": true
# 		},
# 		{
# 		    "targets": [ 0 ],
# 		    "visible": false,
# 		    "searchable": false
# 		},
#         {
#             className: 'control',
#             orderable: false,
#             targets:   0
#         }
#     	],
#
#     	dom : 'l<"#add">frtip'
#
# 	});
#
# 	//$("#add").css("padding-left","10px");
# 	//$("#table-filter").css("width","100px");
# 	$("#add").html($("#extraDiv"));
# 	$("#add").addClass('dataTables_filter');
# 	//$("#add").css("width","100%");
# 	$('.dataTables_filter input[type="search"]').css(
# 		     {'width':'220px','display':'inline-block','height':'37px','font-size':'1rem','padding':'6px 12px'}
# 		  );
#
# 	$(".dataTables_filter").css("margin-bottom","20px");
# 	//$(".dataTables_filter").css("padding","5px");
#
# 	$('#table-filter').on('change', function(){
# 		   table.search(this.value).draw();
# 		});
#
#
# 	/*
# 		[SCRIPT FOR LOGIN PAGE] - as window.onload is covered in this page
# 		Below Script is For Amplitude    (loggedIn event)
# 		// -----------------
# 		// Commented for now login - flow as new login flow implemented with curl
# 	*/
# 	/*
# 	let loginForm = document.querySelector('.loginForm');
# 	if(loginForm){
# 		let uemail = document.getElementById('email')?.value;
# 		let emailRegex = new RegExp('[a-z0-9]+@[a-z]+\.[a-z]{2,3}');
#
# 		if(document.querySelector('#response-error').innerText.length > 5 && emailRegex.test(uemail)){
# 			try{
# 				sendLoggedInEvent('login_event_error',uemail) // send login failed error event
# 			}catch(err){
# 				// console.log('no amplitude')
# 			}
# 		}
# 		loginForm.addEventListener('submit',function(e){
# 			if(emailRegex.test(document.getElementById('email').value)){
# 				try{
# 					sendLoggedInEvent('login_event',document.getElementById('email').value)  // send logged in button click event
# 				}catch(err){
# 					// console.log('no amplitude')
# 				}
# 			}
# 		})
# 	}
# 	*/
#
#
#
# };
#   </script>
#   <!--  below	new script for zopim - live chat only activates on user interaction with screen  -->
#   <script>
#    var ua = navigator.userAgent.toLowerCase(), platform = navigator.platform.toLowerCase();
# 	platformName = ua.match(/ip(?:ad|od|hone)/) ? 'ios' : (ua.match(/(?:webos|android)/) || platform.match(/mac|win|linux/) || ['other'])[0],
# 	isMobile = /ios|android|webos/.test(platformName);
#
# 	if (!isMobile) {
#
#         document.addEventListener('scroll', zopimlaunch);
#         document.addEventListener('mousedown', zopimlaunch);
#         document.addEventListener('mousemove', zopimlaunch);
#         document.addEventListener('touchstart', zopimlaunch);
#         document.addEventListener('keydown', zopimlaunch);
#
#         function zopimlaunch () {
#             window.$zopim||(function(d,s){var z=$zopim=function(c){z._.push(c)},$=z.s=d.createElement(s),e=d.getElementsByTagName(s)[0];z.set=function(o){z.set._.push(o)};z._=[];z.set._=[];$.async=!0;$.setAttribute('charset','utf-8');
#             $.src='//v2.zopim.com/?dhdFs6MCD07fnrlHhjeO8kjolQy1Yn9u';z.t=+new Date;$.type='text/javascript';e.parentNode.insertBefore($,e)})(document,'script');
#
#             document.removeEventListener('scroll', zopimlaunch);
#             document.removeEventListener('mousedown', zopimlaunch);
#             document.removeEventListener('mousemove', zopimlaunch);
#             document.removeEventListener('touchstart', zopimlaunch);
#             document.removeEventListener('keydown', zopimlaunch);
#         }
#
#
#         var hellobarScript = document.createElement("script");
# 		hellobarScript.async = "async";
# 		hellobarScript.src = "https://my.hellobar.com/ac4e38aef266bceec9777ebfc01087bd97ace101.js";
# 		document.body.appendChild(hellobarScript);
#
#
# 	}else{
#
# //     	hellobar smart script
#     	/*
#         document.addEventListener('scroll', hellobarlaunch);
#         document.addEventListener('mousedown', hellobarlaunch);
#         document.addEventListener('mousemove', hellobarlaunch);
#         document.addEventListener('touchstart', hellobarlaunch);
#         document.addEventListener('keydown', hellobarlaunch);
#
#         function hellobarlaunch () {
#             window.$zopim1||(function(d,s){var z1=$zopim1=function(c){z1._.push(c)},$=z1.s=d.createElement(s),e=d.getElementsByTagName(s)[0];z1.set=function(o){z1.set._.push(o)};z1._=[];z1.set._=[];$.async=!0;$.setAttribute('charset','utf-8');
#             $.src='https://my.hellobar.com/ac4e38aef266bceec9777ebfc01087bd97ace101.js';z1.t=+new Date;$.type='text/javascript';e.parentNode.insertBefore($,e)})(document,'script');
#
#             document.removeEventListener('scroll', hellobarlaunch);
#             document.removeEventListener('mousedown', hellobarlaunch);
#             document.removeEventListener('mousemove', hellobarlaunch);
#             document.removeEventListener('touchstart', hellobarlaunch);
#             document.removeEventListener('keydown', hellobarlaunch);
#         }
#         */
#
# 	}
#   </script>
#   <script>
#    //define function to load css
# var loadCss = function(){
# 	var cssLink = document.createElement('link');cssLink.rel = 'stylesheet';
#     cssLink.href = 'https://maxcdn.bootstrapcdn.com/bootstrap/4.5.0/css/bootstrap.min.css';
#     var head = document.getElementsByTagName('head')[0];
#     head.parentNode.insertBefore(cssLink, head);
#
# //     setTimeout(initGTM, 3500);
# };
# // setTimeout(loadCss,2000)
# window.addEventListener('DOMContentLoaded', loadCss);
#   </script>
#   <script defer="" src="https://cdn.datatables.net/1.10.21/js/jquery.dataTables.min.js">
#   </script>
#   <script defer="" src="https://cdn.datatables.net/1.10.21/js/dataTables.bootstrap4.min.js">
#   </script>
#   <!-- 	<script defer type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/mdbootstrap/4.19.1/js/mdb.min.js"></script> -->
#   <script defer="" src="/js/getemail.js?v=0.04" type="text/javascript">
#   </script>
#   <script>
#    /*
# 	document.addEventListener('scroll', initGTMOnEvent);
# 	document.addEventListener('mousemove', initGTMOnEvent);
# 	document.addEventListener('touchstart', initGTMOnEvent);
#
# 	function initGTMOnEvent (event) {
# 		initGTM();
# 		event.currentTarget.removeEventListener(event.type, initGTMOnEvent); // remove the event listener that got triggered
# 	}
#
# 	function initGTM () {
# 		if (window.gtmDidInit) {
# 			return false;
# 		}
# 		window.gtmDidInit = true; // flag to ensure script does not get added to DOM more than once.
# 		const script = document.createElement('script');
# 		script.type = 'text/javascript';
# 		script.async = true;
# 		script.onload = () => { dataLayer.push({ event: 'gtm.js', 'gtm.start': (new Date()).getTime(), 'gtm.uniqueEventId': 0 }); } // this part ensures PageViews is always tracked
# 		script.src = 'https://www.googletagmanager.com/gtm.js?id=GTM-PM3NN4G';
#
# 		document.head.appendChild(script);
# 	}*/
#   </script>
#  </body>
# </html>
# [<th class="col-lg-0"></th>, <th class="col-lg-8" style="font-size:10px">CODE SNIPPET</th>, <th class="col-lg-0" style="font-size:10px">CATEGORY</th>]

# %%
#dataframe:-
table_df = pd.read_html(str(table))[0] 
table_df
# Out:
#       Unnamed: 0                                       CODE SNIPPET  \
# 0            NaN     How to connect EC2 instance to windows server?
# 1            NaN            Explain Auto scaling and its components
# 2            NaN           What is EMR (Elastic Map Reduced) in AWS
# 3            NaN   What are the various Routing Policies in route53
# 4            NaN                 What are the database types in RDS
# ...          ...                                                ...
# 2948         NaN  How to find correlations among feature variabl...
# 2949         NaN         How to visualise regression analysis in R?
# 2950         NaN  How to use auto encoder for unsupervised learn...
# 2951         NaN        How to run a basic RNN model using Pytorch?
# 2952         NaN  How to save and reload a deep learning model i...
#
#                                                CATEGORY
# 0     Big Data Recipes,How does Amazon EC2 Work,What...
# 1     Big Data Recipes,what is auto scaling aws,How ...
# 2     Big Data Recipes,what is aws elastic mapreduce...
# 3     Big Data Recipes,routing policies aws,routing ...
# 4     Big Data Recipes,How does Amazon RDS work,what...
# ...                                                 ...
# 2948  Machine Learning Recipes,correlations,feature ...
# 2949  Machine Learning Recipes,visualise, regression...
# 2950  Machine Learning Recipes,auto encoder, unsuper...
# 2951  Machine Learning Recipes,run basic RNN, RNN, R...
# 2952  Machine Learning Recipes,Pytorch, Deep Learnin...
#
# [2953 rows x 3 columns]
