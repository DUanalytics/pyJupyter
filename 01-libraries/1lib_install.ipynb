# %% [markdown]
# # Install Necessary Libraries which are not available by default
# https://note.nkmk.me/en/python-package-version/

# %%
# know if a package is installed, you can check it in your terminal 
#pip list | grep <module_name_you_want_to_check>
# !pip list # this will list all available libraries
#https://note.nkmk.me/en/python-package-version/

# %%
! pip freeze

# %%
# from python
# !python -m pandas
# !python -m pydataset

# %%
# Data sets
# !pip install pydataset

# %% [markdown]
# ## Check version

# %%
import pandas as pd
print(pd.__version__)

# %% [markdown]
# ## Check through sys library

# %%
# Ch
import sys
print('numpy' in sys.modules)
print('pydataset' in sys.modules)

# %%
# show
! pip show pandas

# %%
! pip show pydataset

# %%
# Install libraries in bulk
# wordcloud
# !pip install wordcloud

# %%
# Beautiful Soup
#https://pypi.org/project/beautifulsoup4/
# !pip install beautifulsoup4

# %%
# Association rule 
# mlextend, apriori, efficient_apriori
import sys
try:
  import mlxtend
except:
  # !pip install mlxtend
  import mlxtend
#! pip install mlxtend
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
'mlxtend' in sys.modules

# %%
! pip install apyori
from apyori import apriori
print('apyori' in sys.modules)

# %%
! pip install efficient_apriori
from efficient_apriori import apriori
print('efficient_apriori' in sys.modules)

# %% [markdown]
# ## pycaret
# https://pycaret.gitbook.io/docs/

# %%
#!pip install pycaret
#https://pycaret.gitbook.io/docs/get-started/installation
#pip install pycaret[full]
# !pip install git+https://github.com/pycaret/pycaret.git#egg=pycaret
# Out:
# ...
#   Cloning https://github.com/pycaret/pycaret.git to c:\users\du\appdata\local\temp\pip-install-ht0jr254\pycaret_e1790d50277f4e4a8a1dfdd40c239ea9
#   Resolved https://github.com/pycaret/pycaret.git to commit e30be155dac7e799616bdf9ff6ce1a20355b1f5a
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      -------------------------------------- 298.0/298.0 kB 2.3 MB/s eta 0:00:00
# ...
#      -------------------------------------- 141.3/141.3 kB 1.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      -------------------------------------- 199.3/199.3 kB 3.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 72.4/72.4 kB 141.9 kB/s eta 0:00:00
# ...
#   Using cached lightgbm-3.3.3-py3-none-win_amd64.whl (1.0 MB)
# ...
#   Using cached scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# ...
#      -------------------------------------- 282.6/282.6 kB 3.5 MB/s eta 0:00:00
# ...

# %%
from pycaret.datasets import get_data
data = get_data('diabetes')
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %%
data.head()
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...
