# %% [markdown]
# Library pycaret
#
# # Install
# pip install git+https://github.com/pycaret/pycaret.git#egg=pycaret
#
# https://github.com/pycaret/pycaret-docs
# https://pycaret.gitbook.io/docs/learn-pycaret/cheat-sheet
# https://pycaret.gitbook.io/docs/
# https://1927305171-files.gitbook.io/~/files/v0/b/gitbook-x-prod.appspot.com/o/spaces%2FFLpROzBBqocwXBoemLJC%2Fuploads%2FeMyRK7tGcEqvRgkKRDL2%2FPyCaret_2-3-10_cheat_sheet.pdf?alt=media&token=a442e0de-af54-4bc0-974b-b73ca1e5963d

# %% [markdown]
# # datasets

# %%
from pycaret.datasets import get_data
diabetes = get_data('diabetes')
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
#    2-Hour serum insulin (mu U/ml)  \
# 0                               0
# 1                               0
# 2                               0
# 3                              94
# 4                             168
#
#    Body mass index (weight in kg/(height in m)^2)  Diabetes pedigree function  \
# 0                                            33.6                       0.627
# 1                                            26.6                       0.351
# 2                                            23.3                       0.672
# 3                                            28.1                       0.167
# 4                                            43.1                       2.288
#
#    Age (years)  Class variable
# 0           50               1
# 1           31               0
# 2           32               1
# 3           21               0
# 4           33               1

# %%
diabetes.head()
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
#    2-Hour serum insulin (mu U/ml)  \
# 0                               0
# 1                               0
# 2                               0
# 3                              94
# 4                             168
#
#    Body mass index (weight in kg/(height in m)^2)  Diabetes pedigree function  \
# 0                                            33.6                       0.627
# 1                                            26.6                       0.351
# 2                                            23.3                       0.672
# 3                                            28.1                       0.167
# 4                                            43.1                       2.288
#
#    Age (years)  Class variable
# 0           50               1
# 1           31               0
# 2           32               1
# 3           21               0
# 4           33               1

# %%
diabetes.columns
# Out:
# Index(['Number of times pregnant',
#        'Plasma glucose concentration a 2 hours in an oral glucose tolerance test',
#        'Diastolic blood pressure (mm Hg)', 'Triceps skin fold thickness (mm)',
#        '2-Hour serum insulin (mu U/ml)',
#        'Body mass index (weight in kg/(height in m)^2)',
#        'Diabetes pedigree function', 'Age (years)', 'Class variable'],
#       dtype='object')

# %% [markdown]
# # Modeling

# %% [markdown]
# ## classification
# https://pycaret.gitbook.io/docs/get-started/quickstart

# %%
from pycaret.classification import *
s = setup(diabetes, target = 'Class variable')
# Out:
# <style type="text/css">
# #T_edd75_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_edd75">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_edd75_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_edd75_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_edd75_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_edd75_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_edd75_row0_col1" class="data row0 col1" >8116</td>
#     </tr>
#     <tr>
#       <th id="T_edd75_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_edd75_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_edd75_row1_col1" class="data row1 col1" >Class variable</td>
#     </tr>
#     <tr>
#       <th id="T_edd75_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_edd75_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_edd75_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_edd75_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_edd75_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_edd75_row3_col1" class="data row3 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_edd75_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_edd75_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_edd75_row4_col1" class="data row4 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_edd75_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_edd75_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_edd75_row5_col1" class="data row5 col1" >(537, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_edd75_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_edd75_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_edd75_row6_col1" class="data row6 col1" >(231, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_edd75_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_edd75_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_edd75_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_edd75_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_edd75_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_edd75_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_edd75_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_edd75_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_edd75_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_edd75_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_edd75_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_edd75_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_edd75_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_edd75_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_edd75_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_edd75_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_edd75_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_edd75_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_edd75_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_edd75_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_edd75_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_edd75_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_edd75_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_edd75_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_edd75_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_edd75_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_edd75_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_edd75_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_edd75_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_edd75_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_edd75_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_edd75_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_edd75_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_edd75_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_edd75_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_edd75_row18_col1" class="data row18 col1" >3cc3</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_4bfa7 th {
#   text-align: left;
# }
# #T_4bfa7_row0_col0, #T_4bfa7_row0_col3, #T_4bfa7_row0_col4, #T_4bfa7_row1_col0, #T_4bfa7_row1_col1, #T_4bfa7_row1_col2, #T_4bfa7_row1_col3, #T_4bfa7_row1_col5, #T_4bfa7_row1_col6, #T_4bfa7_row1_col7, #T_4bfa7_row2_col0, #T_4bfa7_row2_col1, #T_4bfa7_row2_col2, #T_4bfa7_row2_col3, #T_4bfa7_row2_col4, #T_4bfa7_row2_col5, #T_4bfa7_row2_col6, #T_4bfa7_row2_col7, #T_4bfa7_row3_col0, #T_4bfa7_row3_col1, #T_4bfa7_row3_col2, #T_4bfa7_row3_col3, #T_4bfa7_row3_col4, #T_4bfa7_row3_col5, #T_4bfa7_row3_col6, #T_4bfa7_row3_col7, #T_4bfa7_row4_col0, #T_4bfa7_row4_col1, #T_4bfa7_row4_col2, #T_4bfa7_row4_col3, #T_4bfa7_row4_col4, #T_4bfa7_row4_col5, #T_4bfa7_row4_col6, #T_4bfa7_row4_col7, #T_4bfa7_row5_col0, #T_4bfa7_row5_col1, #T_4bfa7_row5_col2, #T_4bfa7_row5_col3, #T_4bfa7_row5_col4, #T_4bfa7_row5_col5, #T_4bfa7_row5_col6, #T_4bfa7_row5_col7, #T_4bfa7_row6_col0, #T_4bfa7_row6_col1, #T_4bfa7_row6_col2, #T_4bfa7_row6_col3, #T_4bfa7_row6_col4, #T_4bfa7_row6_col5, #T_4bfa7_row6_col6, #T_4bfa7_row6_col7, #T_4bfa7_row7_col0, #T_4bfa7_row7_col1, #T_4bfa7_row7_col2, #T_4bfa7_row7_col3, #T_4bfa7_row7_col4, #T_4bfa7_row7_col5, #T_4bfa7_row7_col6, #T_4bfa7_row7_col7, #T_4bfa7_row8_col0, #T_4bfa7_row8_col1, #T_4bfa7_row8_col2, #T_4bfa7_row8_col3, #T_4bfa7_row8_col4, #T_4bfa7_row8_col5, #T_4bfa7_row8_col6, #T_4bfa7_row8_col7, #T_4bfa7_row9_col0, #T_4bfa7_row9_col1, #T_4bfa7_row9_col2, #T_4bfa7_row9_col4, #T_4bfa7_row9_col5, #T_4bfa7_row9_col6, #T_4bfa7_row9_col7, #T_4bfa7_row10_col0, #T_4bfa7_row10_col1, #T_4bfa7_row10_col2, #T_4bfa7_row10_col3, #T_4bfa7_row10_col4, #T_4bfa7_row10_col5, #T_4bfa7_row10_col6, #T_4bfa7_row10_col7, #T_4bfa7_row11_col0, #T_4bfa7_row11_col1, #T_4bfa7_row11_col2, #T_4bfa7_row11_col3, #T_4bfa7_row11_col4, #T_4bfa7_row11_col5, #T_4bfa7_row11_col6, #T_4bfa7_row11_col7, #T_4bfa7_row12_col0, #T_4bfa7_row12_col1, #T_4bfa7_row12_col2, #T_4bfa7_row12_col3, #T_4bfa7_row12_col4, #T_4bfa7_row12_col5, #T_4bfa7_row12_col6, #T_4bfa7_row12_col7, #T_4bfa7_row13_col0, #T_4bfa7_row13_col1, #T_4bfa7_row13_col2, #T_4bfa7_row13_col3, #T_4bfa7_row13_col4, #T_4bfa7_row13_col5, #T_4bfa7_row13_col6, #T_4bfa7_row13_col7 {
#   text-align: left;
# }
# #T_4bfa7_row0_col1, #T_4bfa7_row0_col2, #T_4bfa7_row0_col5, #T_4bfa7_row0_col6, #T_4bfa7_row0_col7, #T_4bfa7_row1_col4, #T_4bfa7_row9_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_4bfa7_row0_col8, #T_4bfa7_row1_col8, #T_4bfa7_row2_col8, #T_4bfa7_row3_col8, #T_4bfa7_row4_col8, #T_4bfa7_row5_col8, #T_4bfa7_row6_col8, #T_4bfa7_row7_col8, #T_4bfa7_row8_col8, #T_4bfa7_row9_col8, #T_4bfa7_row10_col8, #T_4bfa7_row11_col8, #T_4bfa7_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_4bfa7_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_4bfa7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4bfa7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4bfa7_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_4bfa7_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_4bfa7_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_4bfa7_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_4bfa7_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_4bfa7_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_4bfa7_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_4bfa7_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4bfa7_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_4bfa7_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_4bfa7_row0_col1" class="data row0 col1" >0.7818</td>
#       <td id="T_4bfa7_row0_col2" class="data row0 col2" >0.8273</td>
#       <td id="T_4bfa7_row0_col3" class="data row0 col3" >0.5763</td>
#       <td id="T_4bfa7_row0_col4" class="data row0 col4" >0.7543</td>
#       <td id="T_4bfa7_row0_col5" class="data row0 col5" >0.6484</td>
#       <td id="T_4bfa7_row0_col6" class="data row0 col6" >0.4944</td>
#       <td id="T_4bfa7_row0_col7" class="data row0 col7" >0.5076</td>
#       <td id="T_4bfa7_row0_col8" class="data row0 col8" >1.6600</td>
#     </tr>
#     <tr>
#       <th id="T_4bfa7_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_4bfa7_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_4bfa7_row1_col1" class="data row1 col1" >0.7799</td>
#       <td id="T_4bfa7_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_4bfa7_row1_col3" class="data row1 col3" >0.5661</td>
#       <td id="T_4bfa7_row1_col4" class="data row1 col4" >0.7614</td>
#       <td id="T_4bfa7_row1_col5" class="data row1 col5" >0.6444</td>
#       <td id="T_4bfa7_row1_col6" class="data row1 col6" >0.4895</td>
#       <td id="T_4bfa7_row1_col7" class="data row1 col7" >0.5048</td>
#       <td id="T_4bfa7_row1_col8" class="data row1 col8" >0.1390</td>
#     </tr>
#     <tr>
#       <th id="T_4bfa7_level0_row2" class="row_heading level0 row2" >lda</th>
#       <td id="T_4bfa7_row2_col0" class="data row2 col0" >Linear Discriminant Analysis</td>
#       <td id="T_4bfa7_row2_col1" class="data row2 col1" >0.7799</td>
#       <td id="T_4bfa7_row2_col2" class="data row2 col2" >0.8258</td>
#       <td id="T_4bfa7_row2_col3" class="data row2 col3" >0.5713</td>
#       <td id="T_4bfa7_row2_col4" class="data row2 col4" >0.7572</td>
#       <td id="T_4bfa7_row2_col5" class="data row2 col5" >0.6460</td>
#       <td id="T_4bfa7_row2_col6" class="data row2 col6" >0.4905</td>
#       <td id="T_4bfa7_row2_col7" class="data row2 col7" >0.5049</td>
#       <td id="T_4bfa7_row2_col8" class="data row2 col8" >0.0480</td>
#     </tr>
#     <tr>
#       <th id="T_4bfa7_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_4bfa7_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_4bfa7_row3_col1" class="data row3 col1" >0.7633</td>
#       <td id="T_4bfa7_row3_col2" class="data row3 col2" >0.8154</td>
#       <td id="T_4bfa7_row3_col3" class="data row3 col3" >0.5874</td>
#       <td id="T_4bfa7_row3_col4" class="data row3 col4" >0.6950</td>
#       <td id="T_4bfa7_row3_col5" class="data row3 col5" >0.6327</td>
#       <td id="T_4bfa7_row3_col6" class="data row3 col6" >0.4604</td>
#       <td id="T_4bfa7_row3_col7" class="data row3 col7" >0.4668</td>
#       <td id="T_4bfa7_row3_col8" class="data row3 col8" >0.3620</td>
#     </tr>
#     <tr>
#       <th id="T_4bfa7_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_4bfa7_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_4bfa7_row4_col1" class="data row4 col1" >0.7559</td>
#       <td id="T_4bfa7_row4_col2" class="data row4 col2" >0.8231</td>
#       <td id="T_4bfa7_row4_col3" class="data row4 col3" >0.5550</td>
#       <td id="T_4bfa7_row4_col4" class="data row4 col4" >0.6958</td>
#       <td id="T_4bfa7_row4_col5" class="data row4 col5" >0.6132</td>
#       <td id="T_4bfa7_row4_col6" class="data row4 col6" >0.4383</td>
#       <td id="T_4bfa7_row4_col7" class="data row4 col7" >0.4473</td>
#       <td id="T_4bfa7_row4_col8" class="data row4 col8" >0.2360</td>
#     </tr>
#     <tr>
#       <th id="T_4bfa7_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_4bfa7_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_4bfa7_row5_col1" class="data row5 col1" >0.7557</td>
#       <td id="T_4bfa7_row5_col2" class="data row5 col2" >0.8091</td>
#       <td id="T_4bfa7_row5_col3" class="data row5 col3" >0.5655</td>
#       <td id="T_4bfa7_row5_col4" class="data row5 col4" >0.6947</td>
#       <td id="T_4bfa7_row5_col5" class="data row5 col5" >0.6189</td>
#       <td id="T_4bfa7_row5_col6" class="data row5 col6" >0.4420</td>
#       <td id="T_4bfa7_row5_col7" class="data row5 col7" >0.4506</td>
#       <t
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]

# %%
print(best)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=8116, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
plot_model(best, plot = 'auc')

# %%
plot_model(best, plot = 'confusion_matrix')

# %%
predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b1d47">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1d47_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b1d47_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_b1d47_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_b1d47_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_b1d47_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_b1d47_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_b1d47_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_b1d47_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1d47_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b1d47_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_b1d47_row0_col1" class="data row0 col1" >0.7446</td>
#       <td id="T_b1d47_row0_col2" class="data row0 col2" >0.8314</td>
#       <td id="T_b1d47_row0_col3" class="data row0 col3" >0.5556</td>
#       <td id="T_b1d47_row0_col4" class="data row0 col4" >0.6618</td>
#       <td id="T_b1d47_row0_col5" class="data row0 col5" >0.6040</td>
#       <td id="T_b1d47_row0_col6" class="data row0 col6" >0.4176</td>
#       <td id="T_b1d47_row0_col7" class="data row0 col7" >0.4211</td>
#     </tr>
#   </tbody>
# </table>
#      Number of times pregnant  \
# 537                       0.0
# 538                       1.0
# 539                       0.0
# 540                       5.0
# 541                       0.0
# ..                        ...
# 763                       4.0
# 764                       4.0
# 765                       3.0
# 766                       5.0
# 767                       0.0
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 537                                              135.0
# 538                                              100.0
# 539                                              102.0
# 540                                              106.0
# 541                                              117.0
# ..                                                 ...
# 763                                               90.0
# 764                                              141.0
# 765                                              169.0
# 766                                              114.0
# 767                                              146.0
#
#      Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 537                              68.0                              42.0
# 538                              72.0                              12.0
# 539                              78.0                              40.0
# 540                              82.0                              30.0
# 541                              80.0                              31.0
# ..                                ...                               ...
# 763                               0.0                               0.0
# 764                              74.0                               0.0
# 765                              74.0                              19.0
# 766                              74.0                               0.0
# 767                              70.0                               0.0
#
#      2-Hour serum insulin (mu U/ml)  \
# 537                           250.0
# 538                            70.0
# 539                            90.0
# 540                             0.0
# 541                            53.0
# ..                              ...
# 763                             0.0
# 764                             0.0
# 765                           125.0
# 766                             0.0
# 767                             0.0
#
#      Body mass index (weight in kg/(height in m)^2)  \
# 537                                       42.299999
# 538                                       25.299999
# 539                                       34.500000
# 540                                       39.500000
# 541                                       45.200001
# ..                                              ...
# 763                                       28.000000
# 764                                       27.600000
# 765                                       29.900000
# 766                                       24.900000
# 767                                       37.900002
#
#      Diabetes pedigree function  Age (years)  Class variable  \
# 537                       0.365         24.0               1
# 538                       0.658         28.0               0
# 539                       0.238         24.0               0
# 540                       0.286         38.0               0
# 541                       0.089         24.0               0
# ..                          ...          ...             ...
# 763                       0.610         31.0               0
# 764                       0.244         40.0               0
# 765                       0.268         31.0               1
# 766                       0.744         57.0               0
# 767                       0.334         28.0               1
#
#      prediction_label  prediction_score
# 537                 0            0.6321
# 538                 0            0.9212
# 539                 0            0.9245
# 540                 0            0.7228
# 541                 0            0.7496
# ..                ...               ...
# 763                 0            0.7832
# 764                 0            0.5853
# 765                 1            0.6251
# 766                 0            0.7165
# 767                 1            0.5447
#
# [231 rows x 11 columns]

# %%
predictions = predict_model(best, data=diabetes)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_c24a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c24a7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c24a7_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_c24a7_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_c24a7_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_c24a7_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_c24a7_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_c24a7_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_c24a7_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c24a7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c24a7_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_c24a7_row0_col1" class="data row0 col1" >0.7734</td>
#       <td id="T_c24a7_row0_col2" class="data row0 col2" >0.8385</td>
#       <td id="T_c24a7_row0_col3" class="data row0 col3" >0.5746</td>
#       <td id="T_c24a7_row0_col4" class="data row0 col4" >0.7196</td>
#       <td id="T_c24a7_row0_col5" class="data row0 col5" >0.6390</td>
#       <td id="T_c24a7_row0_col6" class="data row0 col6" >0.4769</td>
#       <td id="T_c24a7_row0_col7" class="data row0 col7" >0.4833</td>
#     </tr>
#   </tbody>
# </table>
#    Number of times pregnant  \
# 0                       6.0
# 1                       1.0
# 2                       8.0
# 3                       1.0
# 4                       0.0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                              148.0
# 1                                               85.0
# 2                                              183.0
# 3                                               89.0
# 4                                              137.0
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                              72.0                              35.0
# 1                              66.0                              29.0
# 2                              64.0                               0.0
# 3                              66.0                              23.0
# 4                              40.0                              35.0
#
#    2-Hour serum insulin (mu U/ml)  \
# 0                             0.0
# 1                             0.0
# 2                             0.0
# 3                            94.0
# 4                           168.0
#
#    Body mass index (weight in kg/(height in m)^2)  Diabetes pedigree function  \
# 0                                       33.599998                       0.627
# 1                                       26.600000                       0.351
# 2                                       23.299999                       0.672
# 3                                       28.100000                       0.167
# 4                                       43.099998                       2.288
#
#    Age (years)  Class variable  prediction_label  prediction_score
# 0         50.0               1                 1            0.7195
# 1         31.0               0                 0            0.9607
# 2         32.0               1                 1            0.8898
# 3         21.0               0                 0            0.9631
# 4         33.0               1                 1            0.8864

# %%
save_model(best, 'my_best_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=C:\Users\du\AppData\Local\Temp\joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Number of times pregnant',
#                                               'Plasma glucose concentration a 2 '
#                                               'hours in an oral glucose '
#                                               'tolerance test',
#                                               'Diastolic blood pressure (mm Hg)',
#                                               'Triceps skin fold thickness (mm)',
#                                               '2-Hour serum insulin (mu U/ml)',
#                                               'Body mass index (weight in '
#                                               'kg...
#                                                                fill_value=None,
#                                                                missing_values=nan,
#                                                                strategy='most_frequent',
#                                                                verbose='deprecated'))),
#                  ('trained_model',
#                   LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                      fit_intercept=True, intercept_scaling=1,
#                                      l1_ratio=None, max_iter=1000,
#                                      multi_class='auto', n_jobs=None,
#                                      penalty='l2', random_state=8116,
#                                      solver='lbfgs', tol=0.0001, verbose=0,
#                                      warm_start=False))],
#           verbose=False),
#  'my_best_pipeline.pkl')

# %% [markdown]
# ### Reload Model

# %%
#To load the model back in environment:
loaded_model = load_model('my_best_pipeline')
print(loaded_model)
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=Memory(location=C:\Users\du\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['Number of times pregnant',
#                                              'Plasma glucose concentration a 2 '
#                                              'hours in an oral glucose '
#                                              'tolerance test',
#                                              'Diastolic blood pressure (mm Hg)',
#                                              'Triceps skin fold thickness (mm)',
#                                              '2-Hour serum insulin (mu U/ml)',
#                                              'Body mass index (weight in '
#                                              'kg...
#                                                               fill_value=None,
#                                                               missing_values=nan,
#                                                               strategy='most_frequent',
#                                                               verbose='deprecated'))),
#                 ('trained_model',
#                  LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=1000,
#                                     multi_class='auto', n_jobs=None,
#                                     penalty='l2', random_state=8116,
#                                     solver='lbfgs', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %% [markdown]
# ## Regression
# PyCaret’s Regression Module is a supervised machine learning module that is used for estimating the relationships between a dependent variable (often called the ‘outcome variable’, or ‘target’) and one or more independent variables (often called ‘features’, ‘predictors’, or ‘covariates’). The objective of regression is to predict continuous values such as predicting sales amount, predicting quantity, predicting temperature, etc. It provides several pre-processing features that prepare the data for modeling through the setup function. It has over 25 ready-to-use algorithms and several plots to analyze the performance of trained model

# %%
from pycaret.datasets import get_data
insurance = get_data('insurance')
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from pycaret.regression import *
s = setup(insurance, target = 'charges')
# Out:
# <style type="text/css">
# #T_6a10f_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6a10f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a10f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6a10f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a10f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6a10f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6a10f_row0_col1" class="data row0 col1" >4385</td>
#     </tr>
#     <tr>
#       <th id="T_6a10f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6a10f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6a10f_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
#       <th id="T_6a10f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6a10f_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_6a10f_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_6a10f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6a10f_row3_col0" class="data row3 col0" >Data shape</td>
#       <td id="T_6a10f_row3_col1" class="data row3 col1" >(1338, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_6a10f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6a10f_row4_col0" class="data row4 col0" >Train data shape</td>
#       <td id="T_6a10f_row4_col1" class="data row4 col1" >(936, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_6a10f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6a10f_row5_col0" class="data row5 col0" >Test data shape</td>
#       <td id="T_6a10f_row5_col1" class="data row5 col1" >(402, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_6a10f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6a10f_row6_col0" class="data row6 col0" >Ordinal features</td>
#       <td id="T_6a10f_row6_col1" class="data row6 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_6a10f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6a10f_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_6a10f_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_6a10f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6a10f_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_6a10f_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_6a10f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6a10f_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_6a10f_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6a10f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6a10f_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_6a10f_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_6a10f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6a10f_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_6a10f_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_6a10f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6a10f_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_6a10f_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_6a10f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6a10f_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_6a10f_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_6a10f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6a10f_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_6a10f_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_6a10f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6a10f_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_6a10f_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_6a10f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6a10f_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_6a10f_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_6a10f_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_6a10f_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_6a10f_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_6a10f_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_6a10f_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_6a10f_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6a10f_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_6a10f_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_6a10f_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6a10f_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_6a10f_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_6a10f_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_6a10f_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_6a10f_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_6a10f_row21_col1" class="data row21 col1" >a75f</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Compare Models
# This function trains and evaluates the performance of all the estimators available in the model library using cross-validation. The output of this function is a scoring grid with average cross-validated scores. Metrics evaluated during CV can be accessed using the get_metrics function. Custom metrics can be added or removed using add_metric and remove_metric function

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_28f61 th {
#   text-align: left;
# }
# #T_28f61_row0_col0, #T_28f61_row0_col6, #T_28f61_row1_col0, #T_28f61_row1_col1, #T_28f61_row1_col2, #T_28f61_row1_col3, #T_28f61_row1_col4, #T_28f61_row1_col5, #T_28f61_row1_col6, #T_28f61_row2_col0, #T_28f61_row2_col1, #T_28f61_row2_col2, #T_28f61_row2_col3, #T_28f61_row2_col4, #T_28f61_row2_col5, #T_28f61_row2_col6, #T_28f61_row3_col0, #T_28f61_row3_col1, #T_28f61_row3_col2, #T_28f61_row3_col3, #T_28f61_row3_col4, #T_28f61_row3_col5, #T_28f61_row3_col6, #T_28f61_row4_col0, #T_28f61_row4_col1, #T_28f61_row4_col2, #T_28f61_row4_col3, #T_28f61_row4_col4, #T_28f61_row4_col5, #T_28f61_row4_col6, #T_28f61_row5_col0, #T_28f61_row5_col1, #T_28f61_row5_col2, #T_28f61_row5_col3, #T_28f61_row5_col4, #T_28f61_row5_col5, #T_28f61_row5_col6, #T_28f61_row6_col0, #T_28f61_row6_col1, #T_28f61_row6_col2, #T_28f61_row6_col3, #T_28f61_row6_col4, #T_28f61_row6_col5, #T_28f61_row6_col6, #T_28f61_row7_col0, #T_28f61_row7_col1, #T_28f61_row7_col2, #T_28f61_row7_col3, #T_28f61_row7_col4, #T_28f61_row7_col5, #T_28f61_row7_col6, #T_28f61_row8_col0, #T_28f61_row8_col1, #T_28f61_row8_col2, #T_28f61_row8_col3, #T_28f61_row8_col4, #T_28f61_row8_col5, #T_28f61_row8_col6, #T_28f61_row9_col0, #T_28f61_row9_col1, #T_28f61_row9_col2, #T_28f61_row9_col3, #T_28f61_row9_col4, #T_28f61_row9_col5, #T_28f61_row9_col6, #T_28f61_row10_col0, #T_28f61_row10_col1, #T_28f61_row10_col2, #T_28f61_row10_col3, #T_28f61_row10_col4, #T_28f61_row10_col5, #T_28f61_row10_col6, #T_28f61_row11_col0, #T_28f61_row11_col1, #T_28f61_row11_col2, #T_28f61_row11_col3, #T_28f61_row11_col4, #T_28f61_row11_col5, #T_28f61_row11_col6, #T_28f61_row12_col0, #T_28f61_row12_col1, #T_28f61_row12_col2, #T_28f61_row12_col3, #T_28f61_row12_col4, #T_28f61_row12_col5, #T_28f61_row13_col0, #T_28f61_row13_col1, #T_28f61_row13_col2, #T_28f61_row13_col3, #T_28f61_row13_col4, #T_28f61_row13_col5, #T_28f61_row13_col6, #T_28f61_row14_col0, #T_28f61_row14_col1, #T_28f61_row14_col2, #T_28f61_row14_col3, #T_28f61_row14_col4, #T_28f61_row14_col5, #T_28f61_row14_col6, #T_28f61_row15_col0, #T_28f61_row15_col1, #T_28f61_row15_col2, #T_28f61_row15_col3, #T_28f61_row15_col4, #T_28f61_row15_col5, #T_28f61_row15_col6, #T_28f61_row16_col0, #T_28f61_row16_col1, #T_28f61_row16_col2, #T_28f61_row16_col3, #T_28f61_row16_col4, #T_28f61_row16_col5, #T_28f61_row16_col6, #T_28f61_row17_col0, #T_28f61_row17_col1, #T_28f61_row17_col2, #T_28f61_row17_col3, #T_28f61_row17_col4, #T_28f61_row17_col5, #T_28f61_row17_col6 {
#   text-align: left;
# }
# #T_28f61_row0_col1, #T_28f61_row0_col2, #T_28f61_row0_col3, #T_28f61_row0_col4, #T_28f61_row0_col5, #T_28f61_row12_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_28f61_row0_col7, #T_28f61_row1_col7, #T_28f61_row2_col7, #T_28f61_row3_col7, #T_28f61_row4_col7, #T_28f61_row5_col7, #T_28f61_row6_col7, #T_28f61_row7_col7, #T_28f61_row8_col7, #T_28f61_row9_col7, #T_28f61_row10_col7, #T_28f61_row11_col7, #T_28f61_row12_col7, #T_28f61_row13_col7, #T_28f61_row14_col7, #T_28f61_row15_col7, #T_28f61_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_28f61_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_28f61">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28f61_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_28f61_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_28f61_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_28f61_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_28f61_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_28f61_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_28f61_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_28f61_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28f61_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_28f61_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_28f61_row0_col1" class="data row0 col1" >2647.2339</td>
#       <td id="T_28f61_row0_col2" class="data row0 col2" >22505428.6148</td>
#       <td id="T_28f61_row0_col3" class="data row0 col3" >4670.6330</td>
#       <td id="T_28f61_row0_col4" class="data row0 col4" >0.8338</td>
#       <td id="T_28f61_row0_col5" class="data row0 col5" >0.4070</td>
#       <td id="T_28f61_row0_col6" class="data row0 col6" >0.2851</td>
#       <td id="T_28f61_row0_col7" class="data row0 col7" >0.1330</td>
#     </tr>
#     <tr>
#       <th id="T_28f61_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_28f61_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_28f61_row1_col1" class="data row1 col1" >2766.7518</td>
#       <td id="T_28f61_row1_col2" class="data row1 col2" >24551013.3402</td>
#       <td id="T_28f61_row1_col3" class="data row1 col3" >4869.4438</td>
#       <td id="T_28f61_row1_col4" class="data row1 col4" >0.8177</td>
#       <td id="T_28f61_row1_col5" class="data row1 col5" >0.4301</td>
#       <td id="T_28f61_row1_col6" class="data row1 col6" >0.2962</td>
#       <td id="T_28f61_row1_col7" class="data row1 col7" >0.2900</td>
#     </tr>
#     <tr>
#       <th id="T_28f61_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_28f61_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_28f61_row2_col1" class="data row2 col1" >2959.3983</td>
#       <td id="T_28f61_row2_col2" class="data row2 col2" >24342068.6689</td>
#       <td id="T_28f61_row2_col3" class="data row2 col3" >4839.7147</td>
#       <td id="T_28f61_row2_col4" class="data row2 col4" >0.8177</td>
#       <td id="T_28f61_row2_col5" class="data row2 col5" >0.5382</td>
#       <td id="T_28f61_row2_col6" class="data row2 col6" >0.3488</td>
#       <td id="T_28f61_row2_col7" class="data row2 col7" >0.3690</td>
#     </tr>
#     <tr>
#       <th id="T_28f61_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_28f61_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_28f61_row3_col1" class="data row3 col1" >2759.3111</td>
#       <td id="T_28f61_row3_col2" class="data row3 col2" >26850423.3736</td>
#       <td id="T_28f61_row3_col3" class="data row3 col3" >5084.8696</td>
#       <td id="T_28f61_row3_col4" class="data row3 col4" >0.8001</td>
#       <td id="T_28f61_row3_col5" class="data row3 col5" >0.4440</td>
#       <td id="T_28f61_row3_col6" class="data row3 col6" >0.2970</td>
#       <td id="T_28f61_row3_col7" class="data row3 col7" >0.2530</td>
#     </tr>
#     <tr>
#       <th id="T_28f61_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_28f61_row4_col0" class="data row4 col0" >AdaBoost Regressor</td>
#       <td id="T_28f61_row4_col1" class="data row4 col1" >4429.9610</td>
#       <td id="T_28f61_row4_col2" class="data row4 col2" >29855721.9282</td>
#       <td id="T_28f61_row4_col3" class="data row4 col3" >5428.6548</td>
#       <td id="T_28f61_row4_col4" class="data row4 col4" >0.7859</td>
#       <td id="T_28f61_row4_col5" class="data row4 col5" >0.6247</td>
#       <td id="T_28f61_row4_col6" class="data row4 col6" >0.7256</td>
#       <td id="T_28f61_row4_col7" class="data row4 col7" >0.0830</td>
#     </tr>
#     <tr>
#       <th id="T_28f61_level0_row5" class="row_heading level0 row5" >lar</th>
#       <td id="T_28f61_row5_col0" class="data row5 col0" >Least Angle Regression</td>
#       <td id="T_28f61_row5_col1" class="data row5 col1" >4349.7115</td>
#       <td id="T_28f61_row5_col2" class="data row5 col2" >38772998.6078</td>
#       <td id="T_28f61_row5_col3" class="data row5 col3" >6181.4099</td>
#       <td id="T_28f61_row5_col4" class="data row5 col4" >0.7196</td>
#       <td id="T_28f61_row5_col5" class="data row5 col5" >0.5906</td>
#       <td id="T_28f61_row5_col6" class="data row5 col6" >0.4353</td>
#       <td id="T_28f61_row5_col7" class="
# Processing:   0%|          | 0/77 [00:00<?, ?it/s]

# %%
print(best)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='squared_error',
#                           max_depth=3, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_samples_leaf=1,
#                           min_samples_split=2, min_weight_fraction_leaf=0.0,
#                           n_estimators=100, n_iter_no_change=None,
#                           random_state=4385, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %% [markdown]
# ### Analyze Model
# This function analyzes the performance of a trained model on the test set. It may require re-training the model in certain cases.

# %%
evaluate_model(best)
#evaluate_model can only be used in Notebook since it uses ipywidget .
#You can also use the plot_model function to generate plots individually.
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
plot_model(best, plot = 'residuals')

# %%
plot_model(best, plot = 'feature')

# %% [markdown]
# ### Predictions
# This function predicts Label using the trained model. When data is None, it predicts label and score on the test set (created during the setup function).

# %%
predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_26fc5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26fc5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_26fc5_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_26fc5_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_26fc5_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_26fc5_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_26fc5_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_26fc5_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26fc5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_26fc5_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_26fc5_row0_col1" class="data row0 col1" >2470.1790</td>
#       <td id="T_26fc5_row0_col2" class="data row0 col2" >18818392.9414</td>
#       <td id="T_26fc5_row0_col3" class="data row0 col3" >4338.0172</td>
#       <td id="T_26fc5_row0_col4" class="data row0 col4" >0.8651</td>
#       <td id="T_26fc5_row0_col5" class="data row0 col5" >0.4432</td>
#       <td id="T_26fc5_row0_col6" class="data row0 col6" >0.3081</td>
#     </tr>
#   </tbody>
# </table>
#        age  sex        bmi  children  smoker  region_southwest  \
# 936   56.0  0.0  28.785000       0.0     0.0               0.0
# 937   45.0  1.0  30.495001       2.0     0.0               0.0
# 938   43.0  0.0  24.700001       2.0     1.0               0.0
# 939   57.0  1.0  40.945000       0.0     0.0               0.0
# 940   27.0  1.0  33.660000       0.0     0.0               0.0
# ...    ...  ...        ...       ...     ...               ...
# 1333  48.0  0.0  27.360001       1.0     0.0               0.0
# 1334  40.0  1.0  29.900000       2.0     0.0               1.0
# 1335  45.0  0.0  36.299999       2.0     0.0               0.0
# 1336  26.0  1.0  31.065001       0.0     0.0               0.0
# 1337  48.0  1.0  30.200001       2.0     0.0               1.0
#
#       region_northwest  region_southeast  region_northeast       charges  \
# 936                0.0               0.0               1.0  11658.378906
# 937                1.0               0.0               0.0   8413.462891
# 938                1.0               0.0               0.0  21880.820312
# 939                0.0               0.0               1.0  11566.300781
# 940                0.0               1.0               0.0   2498.414307
# ...                ...               ...               ...           ...
# 1333               0.0               0.0               1.0   9447.382812
# 1334               0.0               0.0               0.0   6600.360840
# 1335               0.0               1.0               0.0   8527.532227
# 1336               1.0               0.0               0.0   2699.568359
# 1337               0.0               0.0               0.0   8968.330078
#
#       prediction_label
# 936       12252.074512
# 937       10370.588270
# 938       23245.450862
# 939       13359.996303
# 940        3991.340517
# ...                ...
# 1333      12249.497153
# 1334       6787.438995
# 1335       9985.536127
# 1336       4029.112551
# 1337      10504.874477
#
# [402 rows x 11 columns]

# %% [markdown]
# The evaluation metrics are calculated on the test set. The second output is the pd.DataFrame with predictions on the test set (see the last two columns). To generate labels on the unseen (new) dataset, simply pass the dataset in the predict_model function.

# %%
predictions = predict_model(best, data=insurance)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_dd81c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd81c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_dd81c_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_dd81c_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_dd81c_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_dd81c_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_dd81c_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_dd81c_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd81c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dd81c_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_dd81c_row0_col1" class="data row0 col1" >2173.4127</td>
#       <td id="T_dd81c_row0_col2" class="data row0 col2" >15175328.3513</td>
#       <td id="T_dd81c_row0_col3" class="data row0 col3" >3895.5524</td>
#       <td id="T_dd81c_row0_col4" class="data row0 col4" >0.8964</td>
#       <td id="T_dd81c_row0_col5" class="data row0 col5" >0.3602</td>
#       <td id="T_dd81c_row0_col6" class="data row0 col6" >0.2512</td>
#     </tr>
#   </tbody>
# </table>
#     age  sex        bmi  children  smoker  region_southwest  region_northwest  \
# 0  19.0  0.0  27.900000       0.0     1.0               1.0               0.0
# 1  18.0  1.0  33.770000       1.0     0.0               0.0               0.0
# 2  28.0  1.0  33.000000       3.0     0.0               0.0               0.0
# 3  33.0  1.0  22.705000       0.0     0.0               0.0               1.0
# 4  32.0  1.0  28.879999       0.0     0.0               0.0               1.0
#
#    region_southeast  region_northeast       charges  prediction_label
# 0               0.0               0.0  16884.923828      18593.914595
# 1               1.0               0.0   1725.552246       2782.685478
# 2               1.0               0.0   4449.461914       6715.062281
# 3               0.0               0.0  21984.470703       8391.168049
# 4               0.0               0.0   3866.855225       4423.142536

# %%
save_model(best, 'my_LR')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=C:\Users\du\AppData\Local\Temp\joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['age', 'bmi', 'children'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                missing_values=nan,
#                                                                strategy='mean',
#                                                                verbose='deprecated'))),
#                  ('categorical_imputer',
#                   TransformerWrapper(exclude=None,...
#                                             criterion='friedman_mse', init=None,
#                                             learning_rate=0.1,
#                                             loss='squared_error', max_depth=3,
#                                             max_features=None,
#                                             max_leaf_nodes=None,
#                                             min_impurity_decrease=0.0,
#                                             min_samples_leaf=1,
#                                             min_samples_split=2,
#                                             min_weight_fraction_leaf=0.0,
#                                             n_estimators=100,
#                                             n_iter_no_change=None,
#                                             random_state=4385, subsample=1.0,
#                                             tol=0.0001, validation_fraction=0.1,
#                                             verbose=0, warm_start=False))],
#           verbose=False),
#  'my_LR.pkl')

# %%
loaded_model = load_model('my_LR')
print(loaded_model)
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=Memory(location=C:\Users\du\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['age', 'bmi', 'children'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               missing_values=nan,
#                                                               strategy='mean',
#                                                               verbose='deprecated'))),
#                 ('categorical_imputer',
#                  TransformerWrapper(exclude=None,...
#                                            criterion='friedman_mse', init=None,
#                                            learning_rate=0.1,
#                                            loss='squared_error', max_depth=3,
#                                            max_features=None,
#                                            max_leaf_nodes=None,
#                                            min_impurity_decrease=0.0,
#                                            min_samples_leaf=1,
#                                            min_samples_split=2,
#                                            min_weight_fraction_leaf=0.0,
#                                            n_estimators=100,
#                                            n_iter_no_change=None,
#                                            random_state=4385, subsample=1.0,
#                                            tol=0.0001, validation_fraction=0.1,
#                                            verbose=0, warm_start=False))],
#          verbose=False)

# %% [markdown]
# ## Clustering
# PyCaret’s Clustering Module is an unsupervised machine learning module that performs the task of grouping a set of objects in such a way that objects in the same group (also known as a cluster) are more similar to each other than to those in other groups. It provides several pre-processing features that prepare the data for modeling through the setup function. It has over 10 ready-to-use algorithms and several plots to analyze the performance of trained models.

# %%
from pycaret.datasets import get_data
jewellery = get_data('jewellery')
# Out:
#    Age  Income  SpendingScore       Savings
# 0   58   77769       0.791329   6559.829923
# 1   59   81799       0.791082   5417.661426
# 2   62   74751       0.702657   9258.992965
# 3   59   74373       0.765680   7346.334504
# 4   87   17760       0.348778  16869.507130

# %%
jewellery.head()
# Out:
#    Age  Income  SpendingScore       Savings
# 0   58   77769       0.791329   6559.829923
# 1   59   81799       0.791082   5417.661426
# 2   62   74751       0.702657   9258.992965
# 3   59   74373       0.765680   7346.334504
# 4   87   17760       0.348778  16869.507130

# %%
from pycaret.clustering import *
s = setup(jewellery, normalize = True)
# Out:
# <style type="text/css">
# #T_1bfb9_row4_col1, #T_1bfb9_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1bfb9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1bfb9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1bfb9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bfb9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1bfb9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_1bfb9_row0_col1" class="data row0 col1" >685</td>
#     </tr>
#     <tr>
#       <th id="T_1bfb9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1bfb9_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_1bfb9_row1_col1" class="data row1 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_1bfb9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1bfb9_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_1bfb9_row2_col1" class="data row2 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_1bfb9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1bfb9_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_1bfb9_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_1bfb9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1bfb9_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_1bfb9_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1bfb9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1bfb9_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_1bfb9_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_1bfb9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1bfb9_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_1bfb9_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_1bfb9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1bfb9_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_1bfb9_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_1bfb9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1bfb9_row8_col0" class="data row8 col0" >Normalize</td>
#       <td id="T_1bfb9_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1bfb9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1bfb9_row9_col0" class="data row9 col0" >Normalize method</td>
#       <td id="T_1bfb9_row9_col1" class="data row9 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_1bfb9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1bfb9_row10_col0" class="data row10 col0" >CPU Jobs</td>
#       <td id="T_1bfb9_row10_col1" class="data row10 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_1bfb9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1bfb9_row11_col0" class="data row11 col0" >Use GPU</td>
#       <td id="T_1bfb9_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1bfb9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1bfb9_row12_col0" class="data row12 col0" >Log Experiment</td>
#       <td id="T_1bfb9_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1bfb9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1bfb9_row13_col0" class="data row13 col0" >Experiment Name</td>
#       <td id="T_1bfb9_row13_col1" class="data row13 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_1bfb9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1bfb9_row14_col0" class="data row14 col0" >USI</td>
#       <td id="T_1bfb9_row14_col1" class="data row14 col1" >8f3c</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Create Model
# This function trains and evaluates the performance of a given model. Metrics evaluated can be accessed using the get_metrics function. Custom metrics can be added or removed using the add_metric and remove_metric function. All the available models can be accessed using the models function.

# %%
kmeans = create_model('kmeans')
# Out:
# <style type="text/css">
# </style>
# <table id="T_03f6b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03f6b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_03f6b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_03f6b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_03f6b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_03f6b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_03f6b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03f6b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_03f6b_row0_col0" class="data row0 col0" >0.7581</td>
#       <td id="T_03f6b_row0_col1" class="data row0 col1" >1611.2647</td>
#       <td id="T_03f6b_row0_col2" class="data row0 col2" >0.3743</td>
#       <td id="T_03f6b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_03f6b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_03f6b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
print(kmeans)
# Out:
# KMeans(algorithm='lloyd', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, random_state=685, tol=0.0001, verbose=0)

# %% [markdown]
# ### Analyse Model
# evaluate_model can only be used in Notebook since it uses ipywidget . You can also use the plot_model function to generate plots individually.

# %%
evaluate_model(kmeans)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
plot_model(kmeans, plot = 'silhouette')

# %% [markdown]
# ### Assign Model
# This function assigns cluster labels to the training data, given a trained model.

# %%
result = assign_model(kmeans)
result.head()
# Out:
#    Age  Income  SpendingScore       Savings    Cluster
# 0   58   77769       0.791329   6559.830078  Cluster 1
# 1   59   81799       0.791082   5417.661621  Cluster 1
# 2   62   74751       0.702657   9258.993164  Cluster 1
# 3   59   74373       0.765680   7346.334473  Cluster 1
# 4   87   17760       0.348778  16869.507812  Cluster 0

# %% [markdown]
# ### Predictions
# This function generates cluster labels using a trained model on the new/unseen dataset.

# %%
predictions = predict_model(kmeans, data = data)
predictions.head(

# %% [markdown]
# ### Save the model

# %%
save_model(kmeans, 'kmeans_pipeline')

# %% [markdown]
# ### Reload Model

# %%
loaded_model = load_model('kmeans_pipeline')
print(loaded_model)

# %% [markdown]
# # Natural Language Processing
# PyCaret’s Natural Language Processing is an unsupervised machine learning module that is used for training topic models on text data. There are several techniques that are used to analyze text data and Topic Modeling is one of them. A topic model is a type of statistical model for discovering abstract topics in a collection of documents.

# %% [markdown]
# ## Setup
# This function initializes the training environment and creates the text transformation pipeline. The setup function must be called before executing any other function.

# %%
# load dataset
from pycaret.datasets import get_data
kiva = get_data('kiva')

# %%
kiva.head()

# %%
# print first document
print(data['en'][0])

# %%
# init setup
from pycaret.nlp import *
s = setup(data, target = 'en')

# %% [markdown]
# ### Create Model
# This function trains an unsupervised topic model. All the available models can be accessed using the models function.

# %%
models()

# %% [markdown]
# ### To train a model:

# %%
lda = create_model('lda')
print(lda)

# %%
### Analyze Model

# %%
plot_model(lda, plot = 'frequency')

# %%
plot_model(lda, plot = 'sentiment')

# %%
#Alternatively, you can also use the evaluate_model function.
evaluate_model(lda)

# %% [markdown]
# ### Assign Model
# This function assigns topic labels to the dataset for a given model.

# %%
lda_results = assign_model(lda)
lda_results.head()

# %%
#Save the model

# %%
save_model(lda, 'my_lda_model')

# %%
# Reload Model

# %%
loaded_model = load_model('my_lda_model')

# %% [markdown]
# ## Association Rules Mining
# PyCaret's association rule module is a supervised machine learning module that is used for discovering interesting relations between variables in the dataset. This module automatically transforms any transactional database into a shape that is acceptable for the apriori algorithm. Apriori is an algorithm for frequent itemset mining and association rule learning over relational databases.

# %% [markdown]
# ### Setup

# %%
from pycaret.datasets import get_data
france = get_data('france')
# Out:
#   InvoiceNo StockCode                      Description  Quantity  \
# 0    536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 1    536370     22727        ALARM CLOCK BAKELIKE RED         24
# 2    536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 3    536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 4    536370     21883                 STARS GIFT TAPE         24
#
#       InvoiceDate  UnitPrice  CustomerID Country
# 0  12/1/2010 8:45       3.75     12583.0  France
# 1  12/1/2010 8:45       3.75     12583.0  France
# 2  12/1/2010 8:45       3.75     12583.0  France
# 3  12/1/2010 8:45       0.85     12583.0  France
# 4  12/1/2010 8:45       0.65     12583.0  France

# %%
france.head()
# Out:
#   InvoiceNo StockCode                      Description  Quantity  \
# 0    536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 1    536370     22727        ALARM CLOCK BAKELIKE RED         24
# 2    536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 3    536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 4    536370     21883                 STARS GIFT TAPE         24
#
#       InvoiceDate  UnitPrice  CustomerID Country
# 0  12/1/2010 8:45       3.75     12583.0  France
# 1  12/1/2010 8:45       3.75     12583.0  France
# 2  12/1/2010 8:45       3.75     12583.0  France
# 3  12/1/2010 8:45       0.85     12583.0  France
# 4  12/1/2010 8:45       0.65     12583.0  France

# %%
from pycaret.arules import * 
arules = setup(france, transaction_id = 'InvoiceNo', item_id = 'Description')
# Out:
# <style type="text/css">
# </style>
# <table id="T_89041">
#   <thead>
#     <tr>
#       <th id="T_89041_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_89041_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_89041_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_89041_row0_col1" class="data row0 col1" >3859</td>
#     </tr>
#     <tr>
#       <td id="T_89041_row1_col0" class="data row1 col0" ># Transactions</td>
#       <td id="T_89041_row1_col1" class="data row1 col1" >461</td>
#     </tr>
#     <tr>
#       <td id="T_89041_row2_col0" class="data row2 col0" ># Items</td>
#       <td id="T_89041_row2_col1" class="data row2 col1" >1565</td>
#     </tr>
#     <tr>
#       <td id="T_89041_row3_col0" class="data row3 col0" >Ignore Items</td>
#       <td id="T_89041_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(arules[1:5])
# Out:
# ('InvoiceNo', 'Description', None, 3859)

# %% [markdown]
# ### Create Model

# %%
create_model(metric = 'confidence', threshold = 0.3)
# Out:
#                                            antecedents  \
# 0                         (JUMBO BAG WOODLAND ANIMALS)
# 1    (SET/20 RED RETROSPOT PAPER NAPKINS , SET/6 RE...
# 2    (SET/20 RED RETROSPOT PAPER NAPKINS , SET/6 RE...
# 3    (SET/20 RED RETROSPOT PAPER NAPKINS , POSTAGE,...
# 4    (SET/20 RED RETROSPOT PAPER NAPKINS , SET/6 RE...
# ..                                                 ...
# 149                          (LUNCH BAG RED RETROSPOT)
# 150                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 151                   (PLASTERS IN TIN CIRCUS PARADE )
# 152                          (LUNCH BAG RED RETROSPOT)
# 153              (ROUND SNACK BOXES SET OF4 WOODLAND )
#
#                                            consequents  antecedent support  \
# 0                                            (POSTAGE)              0.0651
# 1                        (SET/6 RED SPOTTY PAPER CUPS)              0.0868
# 2                      (SET/6 RED SPOTTY PAPER PLATES)              0.0868
# 3                      (SET/6 RED SPOTTY PAPER PLATES)              0.0716
# 4                        (SET/6 RED SPOTTY PAPER CUPS)              0.0716
# ..                                                 ...                 ...
# 149                           (LUNCH BAG APPLE DESIGN)              0.1323
# 150  (PLASTERS IN TIN SPACEBOY, PLASTERS IN TIN CIR...              0.1453
# 151  (PLASTERS IN TIN SPACEBOY, PLASTERS IN TIN WOO...              0.1475
# 152                  (LUNCH BAG APPLE DESIGN, POSTAGE)              0.1323
# 153               (ROUND SNACK BOXES SET OF 4 FRUITS )              0.1388
#
#      consequent support  support  confidence    lift  leverage  conviction
# 0                0.6746   0.0651      1.0000  1.4823    0.0212         inf
# 1                0.1171   0.0846      0.9750  8.3236    0.0744     35.3145
# 2                0.1085   0.0846      0.9750  8.9895    0.0752     35.6616
# 3                0.1085   0.0694      0.9697  8.9406    0.0617     29.4208
# 4                0.1171   0.0694      0.9697  8.2783    0.0610     29.1345
# ..                  ...      ...         ...     ...       ...         ...
# 149              0.1085   0.0564      0.4262  3.9298    0.0420      1.5538
# 150              0.0781   0.0586      0.4030  5.1604    0.0472      1.5442
# 151              0.0889   0.0586      0.3971  4.4645    0.0454      1.5110
# 152              0.0889   0.0521      0.3934  4.4238    0.0403      1.5020
# 153              0.0933   0.0542      0.3906  4.1879    0.0413      1.4880
#
# [154 rows x 9 columns]

# %%
#print(model)
compare_models()
# Out:
# <style type="text/css">
# #T_87ced th {
#   text-align: left;
# }
# #T_87ced_row0_col0, #T_87ced_row0_col7, #T_87ced_row1_col0, #T_87ced_row1_col1, #T_87ced_row1_col2, #T_87ced_row1_col3, #T_87ced_row1_col4, #T_87ced_row1_col5, #T_87ced_row1_col6, #T_87ced_row1_col7, #T_87ced_row2_col0, #T_87ced_row2_col1, #T_87ced_row2_col2, #T_87ced_row2_col3, #T_87ced_row2_col4, #T_87ced_row2_col5, #T_87ced_row2_col6, #T_87ced_row2_col7, #T_87ced_row3_col0, #T_87ced_row3_col1, #T_87ced_row3_col2, #T_87ced_row3_col3, #T_87ced_row3_col4, #T_87ced_row3_col5, #T_87ced_row3_col6, #T_87ced_row3_col7, #T_87ced_row4_col0, #T_87ced_row4_col1, #T_87ced_row4_col2, #T_87ced_row4_col3, #T_87ced_row4_col4, #T_87ced_row4_col5, #T_87ced_row4_col6, #T_87ced_row5_col0, #T_87ced_row5_col1, #T_87ced_row5_col2, #T_87ced_row5_col3, #T_87ced_row5_col4, #T_87ced_row5_col5, #T_87ced_row5_col6, #T_87ced_row5_col7, #T_87ced_row6_col0, #T_87ced_row6_col1, #T_87ced_row6_col2, #T_87ced_row6_col3, #T_87ced_row6_col4, #T_87ced_row6_col5, #T_87ced_row6_col6, #T_87ced_row6_col7, #T_87ced_row7_col0, #T_87ced_row7_col1, #T_87ced_row7_col2, #T_87ced_row7_col3, #T_87ced_row7_col4, #T_87ced_row7_col5, #T_87ced_row7_col6, #T_87ced_row7_col7, #T_87ced_row8_col0, #T_87ced_row8_col1, #T_87ced_row8_col2, #T_87ced_row8_col3, #T_87ced_row8_col4, #T_87ced_row8_col5, #T_87ced_row8_col6, #T_87ced_row8_col7, #T_87ced_row9_col0, #T_87ced_row9_col1, #T_87ced_row9_col2, #T_87ced_row9_col3, #T_87ced_row9_col4, #T_87ced_row9_col5, #T_87ced_row9_col6, #T_87ced_row9_col7, #T_87ced_row10_col0, #T_87ced_row10_col1, #T_87ced_row10_col2, #T_87ced_row10_col3, #T_87ced_row10_col4, #T_87ced_row10_col5, #T_87ced_row10_col6, #T_87ced_row10_col7, #T_87ced_row11_col0, #T_87ced_row11_col1, #T_87ced_row11_col2, #T_87ced_row11_col3, #T_87ced_row11_col4, #T_87ced_row11_col5, #T_87ced_row11_col6, #T_87ced_row11_col7, #T_87ced_row12_col0, #T_87ced_row12_col1, #T_87ced_row12_col2, #T_87ced_row12_col3, #T_87ced_row12_col4, #T_87ced_row12_col5, #T_87ced_row12_col6, #T_87ced_row12_col7, #T_87ced_row13_col0, #T_87ced_row13_col1, #T_87ced_row13_col2, #T_87ced_row13_col3, #T_87ced_row13_col4, #T_87ced_row13_col5, #T_87ced_row13_col6, #T_87ced_row13_col7, #T_87ced_row14_col0, #T_87ced_row14_col1, #T_87ced_row14_col2, #T_87ced_row14_col3, #T_87ced_row14_col4, #T_87ced_row14_col5, #T_87ced_row14_col6, #T_87ced_row14_col7, #T_87ced_row15_col0, #T_87ced_row15_col1, #T_87ced_row15_col2, #T_87ced_row15_col3, #T_87ced_row15_col4, #T_87ced_row15_col5, #T_87ced_row15_col6, #T_87ced_row15_col7, #T_87ced_row16_col0, #T_87ced_row16_col1, #T_87ced_row16_col2, #T_87ced_row16_col3, #T_87ced_row16_col4, #T_87ced_row16_col5, #T_87ced_row16_col6, #T_87ced_row16_col7, #T_87ced_row17_col0, #T_87ced_row17_col1, #T_87ced_row17_col2, #T_87ced_row17_col3, #T_87ced_row17_col4, #T_87ced_row17_col5, #T_87ced_row17_col6, #T_87ced_row17_col7, #T_87ced_row18_col0, #T_87ced_row18_col1, #T_87ced_row18_col2, #T_87ced_row18_col3, #T_87ced_row18_col4, #T_87ced_row18_col5, #T_87ced_row18_col6, #T_87ced_row18_col7, #T_87ced_row19_col0, #T_87ced_row19_col1, #T_87ced_row19_col2, #T_87ced_row19_col3, #T_87ced_row19_col4, #T_87ced_row19_col5, #T_87ced_row19_col6, #T_87ced_row19_col7, #T_87ced_row20_col0, #T_87ced_row20_col1, #T_87ced_row20_col2, #T_87ced_row20_col3, #T_87ced_row20_col4, #T_87ced_row20_col5, #T_87ced_row20_col6, #T_87ced_row20_col7, #T_87ced_row21_col0, #T_87ced_row21_col1, #T_87ced_row21_col2, #T_87ced_row21_col3, #T_87ced_row21_col4, #T_87ced_row21_col5, #T_87ced_row21_col6, #T_87ced_row21_col7, #T_87ced_row22_col0, #T_87ced_row22_col1, #T_87ced_row22_col2, #T_87ced_row22_col3, #T_87ced_row22_col4, #T_87ced_row22_col5, #T_87ced_row22_col6, #T_87ced_row22_col7, #T_87ced_row23_col0, #T_87ced_row23_col1, #T_87ced_row23_col2, #T_87ced_row23_col3, #T_87ced_row23_col4, #T_87ced_row23_col5, #T_87ced_row23_col6, #T_87ced_row23_col7, #T_87ced_row24_col0, #T_87ced_row24_col1, #T_87ced_row24_col2, #T_87ced_row24_col3, #T_87ced_row24_col4, #T_87ced_row24_col5, #T_87ced_row24_col6, #T_87ced_row24_col7, #T_87ced_row25_col0, ...
#   text-align: left;
# }
# #T_87ced_row0_col1, #T_87ced_row0_col2, #T_87ced_row0_col3, #T_87ced_row0_col4, #T_87ced_row0_col5, #T_87ced_row0_col6, #T_87ced_row4_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_87ced_row0_col8, #T_87ced_row1_col8, #T_87ced_row2_col8, #T_87ced_row3_col8, #T_87ced_row4_col8, #T_87ced_row5_col8, #T_87ced_row6_col8, #T_87ced_row7_col8, #T_87ced_row8_col8, #T_87ced_row9_col8, #T_87ced_row10_col8, #T_87ced_row11_col8, #T_87ced_row12_col8, #T_87ced_row13_col8, #T_87ced_row14_col8, #T_87ced_row15_col8, #T_87ced_row16_col8, #T_87ced_row17_col8, #T_87ced_row18_col8, #T_87ced_row19_col8, #T_87ced_row20_col8, #T_87ced_row21_col8, #T_87ced_row22_col8, #T_87ced_row23_col8, #T_87ced_row25_col8, #T_87ced_row26_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_87ced_row24_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_87ced">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87ced_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_87ced_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_87ced_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_87ced_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_87ced_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_87ced_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_87ced_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_87ced_level0_col7" class="col_heading level0 col7" >R2</th>
#       <th id="T_87ced_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87ced_level0_row0" class="row_heading level0 row0" >exp_smooth</th>
#       <td id="T_87ced_row0_col0" class="data row0 col0" >Exponential Smoothing</td>
#       <td id="T_87ced_row0_col1" class="data row0 col1" >0.5063</td>
#       <td id="T_87ced_row0_col2" class="data row0 col2" >0.5378</td>
#       <td id="T_87ced_row0_col3" class="data row0 col3" >15.2910</td>
#       <td id="T_87ced_row0_col4" class="data row0 col4" >18.4465</td>
#       <td id="T_87ced_row0_col5" class="data row0 col5" >0.0334</td>
#       <td id="T_87ced_row0_col6" class="data row0 col6" >0.0335</td>
#       <td id="T_87ced_row0_col7" class="data row0 col7" >-0.0522</td>
#       <td id="T_87ced_row0_col8" class="data row0 col8" >0.2980</td>
#     </tr>
#     <tr>
#       <th id="T_87ced_level0_row1" class="row_heading level0 row1" >ets</th>
#       <td id="T_87ced_row1_col0" class="data row1 col0" >ETS</td>
#       <td id="T_87ced_row1_col1" class="data row1 col1" >0.5519</td>
#       <td id="T_87ced_row1_col2" class="data row1 col2" >0.5801</td>
#       <td id="T_87ced_row1_col3" class="data row1 col3" >16.6150</td>
#       <td id="T_87ced_row1_col4" class="data row1 col4" >19.8378</td>
#       <td id="T_87ced_row1_col5" class="data row1 col5" >0.0354</td>
#       <td id="T_87ced_row1_col6" class="data row1 col6" >0.0357</td>
#       <td id="T_87ced_row1_col7" class="data row1 col7" >-0.0740</td>
#       <td id="T_87ced_row1_col8" class="data row1 col8" >0.2440</td>
#     </tr>
#     <tr>
#       <th id="T_87ced_level0_row2" class="row_heading level0 row2" >arima</th>
#       <td id="T_87ced_row2_col0" class="data row2 col0" >ARIMA</td>
#       <td id="T_87ced_row2_col1" class="data row2 col1" >0.6480</td>
#       <td id="T_87ced_row2_col2" class="data row2 col2" >0.6501</td>
#       <td id="T_87ced_row2_col3" class="data row2 col3" >19.5728</td>
#       <td id="T_87ced_row2_col4" class="data row2 col4" >22.3027
# Processing:   0%|          | 0/117 [00:00<?, ?it/s]
# ExponentialSmoothing(damped_trend=False, damping_trend=None, initial_level=None,
#                      initial_seasonal=None, initial_trend=None,
#                      initialization_method='estimated', method=None,
#                      minimize_kwargs=None, optimized=True, random_state=None,
#                      remove_bias=False, seasonal='mul', smoothing_level=None,
#                      smoothing_seasonal=None, smoothing_trend=None, sp=12,
#                      start_params=None, trend='add', use_boxcox=None,
#                      use_brute=True)

# %% [markdown]
# ### Analyse Model

# %%
plot_model(model, plot = '3d')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20684\2881635289.py in <module>
# ----> 1 plot_model(model, plot = '3d')
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## Time Series
# PyCaret's new time series module is now available in 3.0-rc. Staying true to the simplicity of PyCaret, it is consistent with our existing API and fully loaded with functionalities. Statistical testing, model training and selection (30+ algorithms), model analysis, automated hyperparameter tuning, experiment logging, deployment on cloud, and more. All of this with only a few lines of code.

# %% [markdown]
# ### Setup
# This function initializes the training environment and creates the transformation pipeline. Setup function must be called before executing any other function.

# %%
# loading dataset
from pycaret.datasets import get_data
airline = get_data('airline')
# Out:
# Period
# 1949-01    112.0
# 1949-02    118.0
# 1949-03    132.0
# 1949-04    129.0
# 1949-05    121.0
# Freq: M, Name: Number of airline passengers, dtype: float64

# %%
airline.head()
# Out:
# Period
# 1949-01    112.0
# 1949-02    118.0
# 1949-03    132.0
# 1949-04    129.0
# 1949-05    121.0
# Freq: M, Name: Number of airline passengers, dtype: float64

# %%
from pycaret.time_series import *
s = setup(airline, fh = 3, fold = 5, session_id = 123)
# Out:
# <style type="text/css">
# #T_a6c97_row13_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a6c97">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6c97_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a6c97_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6c97_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a6c97_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_a6c97_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_a6c97_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a6c97_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a6c97_row1_col1" class="data row1 col1" >Number of airline passengers</td>
#     </tr>
#     <tr>
#       <th id="T_a6c97_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a6c97_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_a6c97_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_a6c97_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a6c97_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_a6c97_row3_col1" class="data row3 col1" >Not Present</td>
#     </tr>
#     <tr>
#       <th id="T_a6c97_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a6c97_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_a6c97_row4_col1" class="data row4 col1" >(144, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_a6c97_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a6c97_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_a6c97_row5_col1" class="data row5 col1" >(144, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_a6c97_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a6c97_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_a6c97_row6_col1" class="data row6 col1" >(141, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_a6c97_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a6c97_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_a6c97_row7_col1" class="data row7 col1" >(3, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_a6c97_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a6c97_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_a6c97_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_a6c97_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a6c97_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_a6c97_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_a6c97_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a6c97_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_a6c97_row10_col1" class="data row10 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_a6c97_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a6c97_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_a6c97_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a6c97_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a6c97_row12_col0" class="data row12 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_a6c97_row12_col1" class="data row12 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_a6c97_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a6c97_row13_col0" class="data row13 col0" >Seasonality Present</td>
#       <td id="T_a6c97_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a6c97_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a6c97_row14_col0" class="data row14 col0" >Seasonalities Detected</td>
#       <td id="T_a6c97_row14_col1" class="data row14 col1" >[12]</td>
#     </tr>
#     <tr>
#       <th id="T_a6c97_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a6c97_row15_col0" class="data row15 col0" >Primary Seasonality</td>
#       <td id="T_a6c97_row15_col1" class="data row15 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_a6c97_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a6c97_row16_col0" class="data row16 col0" >Target Strictly Positive</td>
#       <td id="T_a6c97_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a6c97_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a6c97_row17_col0" class="data row17 col0" >Target White Noise</td>
#       <td id="T_a6c97_row17_col1" class="data row17 col1" >No</td>
#     </tr>
#     <tr>
#       <th id="T_a6c97_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a6c97_row18_col0" class="data row18 col0" >Recommended d</td>
#       <td id="T_a6c97_row18_col1" class="data row18 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a6c97_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a6c97_row19_col0" class="data row19 col0" >Recommended Seasonal D</td>
#       <td id="T_a6c97_row19_col1" class="data row19 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a6c97_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a6c97_row20_col0" class="data row20 col0" >Preprocess</td>
#       <td id="T_a6c97_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a6c97_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_a6c97_row21_col0" class="data row21 col0" >CPU Jobs</td>
#       <td id="T_a6c97_row21_col1" class="data row21 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a6c97_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_a6c97_row22_col0" class="data row22 col0" >Use GPU</td>
#       <td id="T_a6c97_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a6c97_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_a6c97_row23_col0" class="data row23 col0" >Log Experiment</td>
#       <td id="T_a6c97_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a6c97_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_a6c97_row24_col0" class="data row24 col0" >Experiment Name</td>
#       <td id="T_a6c97_row24_col1" class="data row24 col1" >ts-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a6c97_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_a6c97_row25_col0" class="data row25 col0" >USI</td>
#       <td id="T_a6c97_row25_col1" class="data row25 col1" >d112</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Compare Models
# This function trains and evaluates the performance of all the estimators available in the model library using cross-validation. The output of this function is a scoring grid with average cross-validated scores. Metrics evaluated during CV can be accessed using the get_metrics function. Custom metrics can be added or removed using add_metric and remove_metric function

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_d1c6f th {
#   text-align: left;
# }
# #T_d1c6f_row0_col0, #T_d1c6f_row0_col7, #T_d1c6f_row1_col0, #T_d1c6f_row1_col1, #T_d1c6f_row1_col2, #T_d1c6f_row1_col3, #T_d1c6f_row1_col4, #T_d1c6f_row1_col5, #T_d1c6f_row1_col6, #T_d1c6f_row1_col7, #T_d1c6f_row2_col0, #T_d1c6f_row2_col1, #T_d1c6f_row2_col2, #T_d1c6f_row2_col3, #T_d1c6f_row2_col4, #T_d1c6f_row2_col5, #T_d1c6f_row2_col6, #T_d1c6f_row2_col7, #T_d1c6f_row3_col0, #T_d1c6f_row3_col1, #T_d1c6f_row3_col2, #T_d1c6f_row3_col3, #T_d1c6f_row3_col4, #T_d1c6f_row3_col5, #T_d1c6f_row3_col6, #T_d1c6f_row3_col7, #T_d1c6f_row4_col0, #T_d1c6f_row4_col1, #T_d1c6f_row4_col2, #T_d1c6f_row4_col3, #T_d1c6f_row4_col4, #T_d1c6f_row4_col5, #T_d1c6f_row4_col6, #T_d1c6f_row5_col0, #T_d1c6f_row5_col1, #T_d1c6f_row5_col2, #T_d1c6f_row5_col3, #T_d1c6f_row5_col4, #T_d1c6f_row5_col5, #T_d1c6f_row5_col6, #T_d1c6f_row5_col7, #T_d1c6f_row6_col0, #T_d1c6f_row6_col1, #T_d1c6f_row6_col2, #T_d1c6f_row6_col3, #T_d1c6f_row6_col4, #T_d1c6f_row6_col5, #T_d1c6f_row6_col6, #T_d1c6f_row6_col7, #T_d1c6f_row7_col0, #T_d1c6f_row7_col1, #T_d1c6f_row7_col2, #T_d1c6f_row7_col3, #T_d1c6f_row7_col4, #T_d1c6f_row7_col5, #T_d1c6f_row7_col6, #T_d1c6f_row7_col7, #T_d1c6f_row8_col0, #T_d1c6f_row8_col1, #T_d1c6f_row8_col2, #T_d1c6f_row8_col3, #T_d1c6f_row8_col4, #T_d1c6f_row8_col5, #T_d1c6f_row8_col6, #T_d1c6f_row8_col7, #T_d1c6f_row9_col0, #T_d1c6f_row9_col1, #T_d1c6f_row9_col2, #T_d1c6f_row9_col3, #T_d1c6f_row9_col4, #T_d1c6f_row9_col5, #T_d1c6f_row9_col6, #T_d1c6f_row9_col7, #T_d1c6f_row10_col0, #T_d1c6f_row10_col1, #T_d1c6f_row10_col2, #T_d1c6f_row10_col3, #T_d1c6f_row10_col4, #T_d1c6f_row10_col5, #T_d1c6f_row10_col6, #T_d1c6f_row10_col7, #T_d1c6f_row11_col0, #T_d1c6f_row11_col1, #T_d1c6f_row11_col2, #T_d1c6f_row11_col3, #T_d1c6f_row11_col4, #T_d1c6f_row11_col5, #T_d1c6f_row11_col6, #T_d1c6f_row11_col7, #T_d1c6f_row12_col0, #T_d1c6f_row12_col1, #T_d1c6f_row12_col2, #T_d1c6f_row12_col3, #T_d1c6f_row12_col4, #T_d1c6f_row12_col5, #T_d1c6f_row12_col6, #T_d1c6f_row12_col7, #T_d1c6f_row13_col0, #T_d1c6f_row13_col1, #T_d1c6f_row13_col2, #T_d1c6f_row13_col3, #T_d1c6f_row13_col4, #T_d1c6f_row13_col5, #T_d1c6f_row13_col6, #T_d1c6f_row13_col7, #T_d1c6f_row14_col0, #T_d1c6f_row14_col1, #T_d1c6f_row14_col2, #T_d1c6f_row14_col3, #T_d1c6f_row14_col4, #T_d1c6f_row14_col5, #T_d1c6f_row14_col6, #T_d1c6f_row14_col7, #T_d1c6f_row15_col0, #T_d1c6f_row15_col1, #T_d1c6f_row15_col2, #T_d1c6f_row15_col3, #T_d1c6f_row15_col4, #T_d1c6f_row15_col5, #T_d1c6f_row15_col6, #T_d1c6f_row15_col7, #T_d1c6f_row16_col0, #T_d1c6f_row16_col1, #T_d1c6f_row16_col2, #T_d1c6f_row16_col3, #T_d1c6f_row16_col4, #T_d1c6f_row16_col5, #T_d1c6f_row16_col6, #T_d1c6f_row16_col7, #T_d1c6f_row17_col0, #T_d1c6f_row17_col1, #T_d1c6f_row17_col2, #T_d1c6f_row17_col3, #T_d1c6f_row17_col4, #T_d1c6f_row17_col5, #T_d1c6f_row17_col6, #T_d1c6f_row17_col7, #T_d1c6f_row18_col0, #T_d1c6f_row18_col1, #T_d1c6f_row18_col2, #T_d1c6f_row18_col3, #T_d1c6f_row18_col4, #T_d1c6f_row18_col5, #T_d1c6f_row18_col6, #T_d1c6f_row18_col7, #T_d1c6f_row19_col0, #T_d1c6f_row19_col1, #T_d1c6f_row19_col2, #T_d1c6f_row19_col3, #T_d1c6f_row19_col4, #T_d1c6f_row19_col5, #T_d1c6f_row19_col6, #T_d1c6f_row19_col7, #T_d1c6f_row20_col0, #T_d1c6f_row20_col1, #T_d1c6f_row20_col2, #T_d1c6f_row20_col3, #T_d1c6f_row20_col4, #T_d1c6f_row20_col5, #T_d1c6f_row20_col6, #T_d1c6f_row20_col7, #T_d1c6f_row21_col0, #T_d1c6f_row21_col1, #T_d1c6f_row21_col2, #T_d1c6f_row21_col3, #T_d1c6f_row21_col4, #T_d1c6f_row21_col5, #T_d1c6f_row21_col6, #T_d1c6f_row21_col7, #T_d1c6f_row22_col0, #T_d1c6f_row22_col1, #T_d1c6f_row22_col2, #T_d1c6f_row22_col3, #T_d1c6f_row22_col4, #T_d1c6f_row22_col5, #T_d1c6f_row22_col6, #T_d1c6f_row22_col7, #T_d1c6f_row23_col0, #T_d1c6f_row23_col1, #T_d1c6f_row23_col2, #T_d1c6f_row23_col3, #T_d1c6f_row23_col4, #T_d1c6f_row23_col5, #T_d1c6f_row23_col6, #T_d1c6f_row23_col7, #T_d1c6f_row24_col0, #T_d1c6f_row24_col1, #T_d1c6f_row24_col2, #T_d1c6f_row24_col3, #T_d1c6f_row24_col4, #T_d1c6f_row24_col5, #T_d1c6f_row24_col6, #T_d1c6f_row24_col7, #T_d1c6f_row25_col0, ...
#   text-align: left;
# }
# #T_d1c6f_row0_col1, #T_d1c6f_row0_col2, #T_d1c6f_row0_col3, #T_d1c6f_row0_col4, #T_d1c6f_row0_col5, #T_d1c6f_row0_col6, #T_d1c6f_row4_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d1c6f_row0_col8, #T_d1c6f_row1_col8, #T_d1c6f_row2_col8, #T_d1c6f_row3_col8, #T_d1c6f_row4_col8, #T_d1c6f_row5_col8, #T_d1c6f_row6_col8, #T_d1c6f_row7_col8, #T_d1c6f_row8_col8, #T_d1c6f_row9_col8, #T_d1c6f_row10_col8, #T_d1c6f_row11_col8, #T_d1c6f_row12_col8, #T_d1c6f_row13_col8, #T_d1c6f_row14_col8, #T_d1c6f_row15_col8, #T_d1c6f_row16_col8, #T_d1c6f_row17_col8, #T_d1c6f_row18_col8, #T_d1c6f_row19_col8, #T_d1c6f_row20_col8, #T_d1c6f_row21_col8, #T_d1c6f_row22_col8, #T_d1c6f_row23_col8, #T_d1c6f_row26_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_d1c6f_row24_col8, #T_d1c6f_row25_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d1c6f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1c6f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d1c6f_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_d1c6f_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_d1c6f_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_d1c6f_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_d1c6f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_d1c6f_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_d1c6f_level0_col7" class="col_heading level0 col7" >R2</th>
#       <th id="T_d1c6f_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1c6f_level0_row0" class="row_heading level0 row0" >exp_smooth</th>
#       <td id="T_d1c6f_row0_col0" class="data row0 col0" >Exponential Smoothing</td>
#       <td id="T_d1c6f_row0_col1" class="data row0 col1" >0.5063</td>
#       <td id="T_d1c6f_row0_col2" class="data row0 col2" >0.5378</td>
#       <td id="T_d1c6f_row0_col3" class="data row0 col3" >15.2910</td>
#       <td id="T_d1c6f_row0_col4" class="data row0 col4" >18.4465</td>
#       <td id="T_d1c6f_row0_col5" class="data row0 col5" >0.0334</td>
#       <td id="T_d1c6f_row0_col6" class="data row0 col6" >0.0335</td>
#       <td id="T_d1c6f_row0_col7" class="data row0 col7" >-0.0522</td>
#       <td id="T_d1c6f_row0_col8" class="data row0 col8" >0.2580</td>
#     </tr>
#     <tr>
#       <th id="T_d1c6f_level0_row1" class="row_heading level0 row1" >ets</th>
#       <td id="T_d1c6f_row1_col0" class="data row1 col0" >ETS</td>
#       <td id="T_d1c6f_row1_col1" class="data row1 col1" >0.5519</td>
#       <td id="T_d1c6f_row1_col2" class="data row1 col2" >0.5801</td>
#       <td id="T_d1c6f_row1_col3" class="data row1 col3" >16.6150</td>
#       <td id="T_d1c6f_row1_col4" class="data row1 col4" >19.8378</td>
#       <td id="T_d1c6f_row1_col5" class="data row1 col5" >0.0354</td>
#       <td id="T_d1c6f_row1_col6" class="data row1 col6" >0.0357</td>
#       <td id="T_d1c6f_row1_col7" class="data row1 col7" >-0.0740</td>
#       <td id="T_d1c6f_row1_col8" class="data row1 col8" >0.2440</td>
#     </tr>
#     <tr>
#       <th id="T_d1c6f_level0_row2" class="row_heading level0 row2" >arima</th>
#       <td id="T_d1c6f_row2_col0" class="data row2 col0" >ARIMA</td>
#       <td id="T_d1c6f_row2_col1" class="data row2 col1" >0.6480</td>
#       <td id="T_d1c6f_row2_col2" class="data row2 col2" >0.6501</td>
#       <td id="T_d1c6f_row2_col3" class="data row2 col3" >19.5728</td>
#       <td id="T_d1c6f_row2_col4" class="data row2 col4" >22.3027
# Processing:   0%|          | 0/117 [00:00<?, ?it/s]

# %% [markdown]
# ### Analyze Model

# %%
plot_model(best, plot = 'forecast', data_kwargs = {'fh' : 24})

# %%
plot_model(best, plot = 'diagnostics')

# %%
plot_model(best, plot = 'insample')

# %% [markdown]
# ### Predictions

# %%
# finalize model
final_best = finalize_model(best)
predict_model(best, fh = 24)

# %% [markdown]
# ### Save the model

# %%
save_model(final_best, 'ts_pipiline')

# %%
### Load the model

# %%
loaded_model = load_model('my_final_best_model')
print(loaded_model)
