# %% [markdown]
# # Save Graphs in python

# %% [markdown]
# ## image

# %% [markdown]
# ## pdf
# plt.savefig("myImagePDF.pdf", format="pdf", bbox_inches="tight") method, we can save a figure in PDF format.

# %%
import pandas as pd
from matplotlib import pyplot as plt
d = {'Column 1': [i for i in range(10)], 'Column 2': [i * i for i in range(10)]}
df = pd.DataFrame(d)
df
# Out:
#    Column 1  Column 2
# 0         0         0
# 1         1         1
# 2         2         4
# 3         3         9
# 4         4        16
# 5         5        25
# 6         6        36
# 7         7        49
# 8         8        64
# 9         9        81

# %%
df.plot(style=['o', 'rx'])
plt.savefig("myImagePDF.pdf", format="pdf", bbox_inches="tight")
plt.show();

# %%
# check
import os
list(filter(lambda f: os.path.isfile(f) and f.lower().endswith(".pdf"), os.listdir(".")))
# Out:
# ['myImagePDF.pdf']

# %%
import glob
glob.glob("*.pdf")
# Out:
# ['myImagePDF.pdf']

# %% [markdown]
# ## others

# %% [markdown]
# ## multiple graphs in pdf

# %%
from matplotlib import pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# %%
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True

# %%
fig1 = plt.figure()
plt.plot([17, 45, 7, 8, 7], color='orange')
  
fig2 = plt.figure()
plt.plot([13, 25, 1, 6, 3], color='blue')
  
Fig3 = plt.figure()
plt.plot([22, 11, 2, 1, 23], color='green')
  
  
def save_image(filename):
    
    # PdfPages is a wrapper around pdf 
    # file so there is no clash and create
    # files with no error.
    p = PdfPages(filename)
      
    # get_fignums Return list of existing 
    # figure numbers
    fig_nums = plt.get_fignums()  
    figs = [plt.figure(n) for n in fig_nums]
      
    # iterating over the numbers in list
    for fig in figs: 
        
        # and saving the files
        fig.savefig(p, format='pdf') 
      
    # close the object
    p.close()  
  
# name your Pdf file
filename = "multi_plot_image.pdf"  
  
# call the function
save_image(filename)

# %%
import glob
glob.glob("*.pdf")
# Out:
# ['multi_plot_image.pdf', 'myImagePDF.pdf']
