# %% [markdown]
# # Pandas Functions
# data analysis and manipulation
# Rows are denoted using axis=0
# Columns are denoted using axis=1

# %% [markdown]
#    # Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 import numpy as np
# ----> 2 import pandas as pd
#       3 import seaborn as sns
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# #pandas DF are combination of panda Series..
# #one column data is a Series of one datatype, DF can have multiple data types

# %%
from pydataset import data
mtcars = data('mtcars')
mtcarsDF = mtcars
mtcarsDF.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
## Help
pd?
# Out:
#   Input In [3]
#     pd?
#       ^
# SyntaxError: invalid syntax

# %%
# data types
mtcarsDF.dtypes

# %% [markdown]
# ##    Describe data
# data.describe(include=[np.number])
# data.describe()
# data.describe(include='all')
# data.numeric.describe()
# data.describe(include=[np.number])
# data.describe(include=[np.object])
# data.describe(include=['category'])
# data.describe(exclude=[np.number])
# data.describe(exclude=[np.object])

# %%
mtcarsDF.describe(include='all')

# %%
#change data type of few columns
mtcarsDF[['am', 'vs', 'gear', 'cyl', 'carb']] = mtcarsDF[['am', 'vs', 'gear', 'cyl', 'carb']].astype('category')
#mtcarsDF.carb = pd.Categorical(mtcarsDF.carb).codes  #code used for linear regression
mtcarsDF.dtypes

# %%
mtcarsDF.describe(include='all') #all column types
#category - count, unique, top, freq
#numeric - count, mean, std, min, max, Qs

# %% [markdown]
# ## Display certain data types

# %%
mtcarsDF.select_dtypes(include=['int64']).head()

# %%
mtcarsDF.select_dtypes(exclude=['int64']).head()  #display data types excl int64 ie decimal

# %% [markdown]
# ## Missing Values

# %%
mtcarsDF.isna().head()  #missing values

# %%
mtcarsDF.notna().head() #check each cell value

# %%
id(mtcarsDF) #storage location of data in memory

# %%
mtcars.empty #is DF empty, False here

# %%
mtcars.size  #memory size

# %%
mtcars.ndim   #dimensions

# %%
mtcars.axes  #axis values   - rowname, column name

# %%
mtcars.values  #just the data without axis values, np array

# %% [markdown]
# ## Describe a Panda DF

# %%
mtcarsDF.shape  #dimensions of DF
# Out:
# (32, 11)

# %%
mtcarsDF.head(4) #first 4 rows of DF
# Out:
#                  mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# Mazda RX4       21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# Mazda RX4 Wag   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# Datsun 710      22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1

# %%
mtcarsDF.tail(3) #last 3 rows of DF
# Out:
#                 mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# Ferrari Dino   19.7    6  145.0  175  3.62  2.77  15.5   0   1     5     6
# Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   1     5     8
# Volvo 142E     21.4    4  121.0  109  4.11  2.78  18.6   1   1     4     2

# %%
mtcarsDF.describe()  #describe or summarise DF (default - numeric cols)
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# 25%    16.892500   0.000000   0.000000   3.000000   2.0000
# 50%    17.710000   0.000000   0.000000   4.000000   2.0000
# 75%    18.900000   1.000000   1.000000   4.000000   4.0000
# max    22.900000   1.000000   1.000000   5.000000   8.0000

# %%
mtcarsDF.columns   #column names
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
mtcarsDF.dtypes # data types
# Out:
# mpg     float64
# cyl       int64
# disp    float64
# hp        int64
# drat    float64
# wt      float64
# qsec    float64
# vs        int64
# am        int64
# gear      int64
# carb      int64
# dtype: object

# %%
mtcarsDF.select_dtypes(include=['int64']).head()  #show only dtypes of int64 only first few rows
# Out:
#                    cyl   hp  vs  am  gear  carb
# Mazda RX4            6  110   0   1     4     4
# Mazda RX4 Wag        6  110   0   1     4     4
# Datsun 710           4   93   1   1     4     1
# Hornet 4 Drive       6  110   1   0     3     1
# Hornet Sportabout    8  175   0   0     3     2

# %%
mtcarsDF.notna() #is there no missing value (not missing)
# Out:
#                       mpg   cyl  disp    hp  drat    wt  qsec    vs    am  \
# Mazda RX4            True  True  True  True  True  True  True  True  True
# Mazda RX4 Wag        True  True  True  True  True  True  True  True  True
# Datsun 710           True  True  True  True  True  True  True  True  True
# Hornet 4 Drive       True  True  True  True  True  True  True  True  True
# Hornet Sportabout    True  True  True  True  True  True  True  True  True
# Valiant              True  True  True  True  True  True  True  True  True
# Duster 360           True  True  True  True  True  True  True  True  True
# Merc 240D            True  True  True  True  True  True  True  True  True
# Merc 230             True  True  True  True  True  True  True  True  True
# Merc 280             True  True  True  True  True  True  True  True  True
# Merc 280C            True  True  True  True  True  True  True  True  True
# Merc 450SE           True  True  True  True  True  True  True  True  True
# Merc 450SL           True  True  True  True  True  True  True  True  True
# Merc 450SLC          True  True  True  True  True  True  True  True  True
# Cadillac Fleetwood   True  True  True  True  True  True  True  True  True
# Lincoln Continental  True  True  True  True  True  True  True  True  True
# Chrysler Imperial    True  True  True  True  True  True  True  True  True
# Fiat 128             True  True  True  True  True  True  True  True  True
# Honda Civic          True  True  True  True  True  True  True  True  True
# Toyota Corolla       True  True  True  True  True  True  True  True  True
# Toyota Corona        True  True  True  True  True  True  True  True  True
# Dodge Challenger     True  True  True  True  True  True  True  True  True
# AMC Javelin          True  True  True  True  True  True  True  True  True
# Camaro Z28           True  True  True  True  True  True  True  True  True
# Pontiac Firebird     True  True  True  True  True  True  True  True  True
# Fiat X1-9            True  True  True  True  True  True  True  True  True
# Porsche 914-2        True  True  True  True  True  True  True  True  True
# Lotus Europa         True  True  True  True  True  True  True  True  True
# Ford Pantera L       True  True  True  True  True  True  True  True  True
# Ferrari Dino         True  True  True  True  True  True  True  True  True
# Maserati Bora        True  True  True  True  True  True  True  True  True
# Volvo 142E           True  True  True  True  True  True  True  True  True
#
#                      gear  carb
# Mazda RX4            True  True
# Mazda RX4 Wag        True  True
# Datsun 710           True  True
# Hornet 4 Drive       True  True
# Hornet Sportabout    True  True
# Valiant              True  True
# Duster 360           True  True
# Merc 240D            True  True
# Merc 230             True  True
# Merc 280             True  True
# Merc 280C            True  True
# Merc 450SE           True  True
# Merc 450SL           True  True
# Merc 450SLC          True  True
# Cadillac Fleetwood   True  True
# Lincoln Continental  True  True
# Chrysler Imperial    True  True
# Fiat 128             True  True
# Honda Civic          True  True
# Toyota Corolla       True  True
# Toyota Corona        True  True
# Dodge Challenger     True  True
# AMC Javelin          True  True
# Camaro Z28           True  True
# Pontiac Firebird     True  True
# Fiat X1-9            True  True
# Porsche 914-2        True  True
# Lotus Europa         True  True
# Ford Pantera L       True  True
# Ferrari Dino         True  True
# Maserati Bora        True  True
# Volvo 142E           True  True

# %%
mtcarsDF.isnull().sum()  #count of missing values
# Out:
# mpg     0
# cyl     0
# disp    0
# hp      0
# drat    0
# wt      0
# qsec    0
# vs      0
# am      0
# gear    0
# carb    0
# dtype: int64

# %%
mtcarsDF.isna().sum(axis=1)  #rowwise count of missing values

# %%
mtcarsDF.ndim  #no of dimensions 2 for DF,1 for list

# %%
mtcarsDF.shape   #no of rows and column

# %%
### Accessing DF

# %%
mtcarsDF[0:5] # first 5 rows

# %%
mtcarsDF.iloc[0:5, 0:3]  #first 5 rows and first 3 columns - integer locations

# %%
mtcarsDF.at['Mazda RX4', 'mpg']  #particular cell (single value access) by name

# %%
mtcarsDF.iat[0,0]  #single value using iat  - integer; first row, first col

# %%
mtcarsDF.index  #row or index names

# %%
mtcarsDF.loc[['Mazda RX4']] #row details with rowname or index

# %%
mtcarsDF.loc[['Mazda RX4','Datsun 710'],['mpg', 'wt']]  #particular locations

# %%
mtcarsDF.loc['Mazda RX4':'Datsun 710']   #particular sequence of locations

# %%
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# Merc 450SE           16.4    8  275.8  180  3.07  4.070  17.40   0   0     3
# Merc 450SL           17.3    8  275.8  180  3.07  3.730  17.60   0   0     3
# Merc 450SLC          15.2    8  275.8  180  3.07  3.780  18.00   0   0     3
# Cadillac Fleetwood   10.4    8  472.0  205  2.93  5.250  17.98   0   0     3
# Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0     3
# Chrysler Imperial    14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Fiat 128             32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# Honda Civic          30.4    4   75.7   52  4.93  1.615  18.52   1   1     4
# Toyota Corolla       33.9    4   71.1   65  4.22  1.835  19.90   1   1     4
# Toyota Corona        21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# Dodge Challenger     15.5    8  318.0  150  2.76  3.520  16.87   0   0     3
# AMC Javelin          15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# Camaro Z28           13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Pontiac Firebird     19.2    8  400.0  175  3.08  3.845  17.05   0   0     3
# Fiat X1-9            27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# Porsche 914-2        26.0    4  120.3   91  4.43  2.140  16.70   0   1     5
# Lotus Europa         30.4    4   95.1  113  3.77  1.513  16.90   1   1     5
# Ford Pantera L       15.8    8  351.0  264  4.22  3.170  14.50   0   1     5
# Ferrari Dino         19.7    6  145.0  175  3.62  2.770  15.50   0   1     5
# Maserati Bora        15.0    8  301.0  335  3.54  3.570  14.60   0   1     5
# Volvo 142E           21.4    4  121.0  109  4.11  2.780  18.60   1   1     4
#
#                      carb
# Mazda RX4               4
# Mazda RX4 Wag           4
# Hornet Sportabout       2
# Valiant                 1
# Duster 360              4
# Merc 240D               2
# Merc 230                2
# Merc 280                4
# Merc 280C               4
# Merc 450SE              3
# Merc 450SL              3
# Merc 450SLC             3
# Cadillac Fleetwood      4
# Lincoln Continental     4
# Chrysler Imperial       4
# Fiat 128                1
# Honda Civic             2
# Toyota Corolla          1
# Toyota Corona           1
# Dodge Challenger        2
# AMC Javelin             2
# Camaro Z28              4
# Pontiac Firebird        2
# Fiat X1-9               1
# Porsche 914-2           2
# Lotus Europa            2
# Ford Pantera L          4
# Ferrari Dino            6
# Maserati Bora           8
# Volvo 142E              2

# %%
## Delete Rows

# %%
mtcarsDF.drop(mtcarsDF.index[2:4], inplace=False)
#index[2:4] generates a range of rows from 2 to 4. 
#The lower limit of the range is inclusive and the upper limit of the range is exclusive. 
#This means that rows 2 and 3 will be deleted and row 4 will not be deleted.

# %%
#select rows from 0 to the index 2. This results in dropping the rows after the index 2.
mtcarsDF.iloc[:2]
# Out:
#                 mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# Mazda RX4      21.0    6  160.0  110   3.9  2.620  16.46   0   1     4     4
# Mazda RX4 Wag  21.0    6  160.0  110   3.9  2.875  17.02   0   1     4     4

# %%
#Drop Rows with Multiple Conditions in Pandas
mtcarsDF.drop(mtcarsDF[(mtcarsDF['mpg'] > 25) & (mtcarsDF['am'] == 0)].index, inplace=False).sort_values(by=['am','mpg'])
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Cadillac Fleetwood   10.4    8  472.0  205  2.93  5.250  17.98   0   0     3
# Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0     3
# Camaro Z28           13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Chrysler Imperial    14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Merc 450SLC          15.2    8  275.8  180  3.07  3.780  18.00   0   0     3
# AMC Javelin          15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# Dodge Challenger     15.5    8  318.0  150  2.76  3.520  16.87   0   0     3
# Merc 450SE           16.4    8  275.8  180  3.07  4.070  17.40   0   0     3
# Merc 450SL           17.3    8  275.8  180  3.07  3.730  17.60   0   0     3
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Pontiac Firebird     19.2    8  400.0  175  3.08  3.845  17.05   0   0     3
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Toyota Corona        21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Maserati Bora        15.0    8  301.0  335  3.54  3.570  14.60   0   1     5
# Ford Pantera L       15.8    8  351.0  264  4.22  3.170  14.50   0   1     5
# Ferrari Dino         19.7    6  145.0  175  3.62  2.770  15.50   0   1     5
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Volvo 142E           21.4    4  121.0  109  4.11  2.780  18.60   1   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Porsche 914-2        26.0    4  120.3   91  4.43  2.140  16.70   0   1     5
# Fiat X1-9            27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# Honda Civic          30.4    4   75.7   52  4.93  1.615  18.52   1   1     4
# Lotus Europa         30.4    4   95.1  113  3.77  1.513  16.90   1   1     5
# Fiat 128             32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# Toyota Corolla       33.9    4   71.1   65  4.22  1.835  19.90   1   1     4
#
#                      carb
# Cadillac Fleetwood      4
# Lincoln Continental     4
# Camaro Z28              4
# Duster 360              4
# Chrysler Imperial       4
# Merc 450SLC             3
# AMC Javelin             2
# Dodge Challenger        2
# Merc 450SE              3
# Merc 450SL              3
# Merc 280C               4
# Valiant                 1
# Hornet Sportabout       2
# Merc 280                4
# Pontiac Firebird        2
# Hornet 4 Drive          1
# Toyota Corona           1
# Merc 230                2
# Merc 240D               2
# Maserati Bora           8
# Ford Pantera L          4
# Ferrari Dino            6
# Mazda RX4               4
# Mazda RX4 Wag           4
# Volvo 142E              2
# Datsun 710              1
# Porsche 914-2           2
# Fiat X1-9               1
# Honda Civic             2
# Lotus Europa            2
# Fiat 128                1
# Toyota Corolla          1

# %% [markdown]
# ## Add / Delete Columns
# dataframe.insert() method – Use insert() method when you want to insert a column in a specific index position of the dataframe.
# datafame.assign() method – Use assign() method when you want to insert a column and create a new dataframe out of it rather inserting a new column in the same dataframe.

# %%
mtcarsDF2 = mtcarsDF.copy()  # make a copy for practise
mtcarsDF2["newMPG"] = pd.NaT  #fastest way
mtcarsDF2.head()
#pd.NaT – To specify the values as NaT for all the rows of this column. 
#Its normally used to denote missing values. You can use when you don’t know the values upfront.
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb newMPG
# Mazda RX4             4    NaT
# Mazda RX4 Wag         4    NaT
# Datsun 710            1    NaT
# Hornet 4 Drive        1    NaT
# Hornet Sportabout     2    NaT

# %%
newColValues = np.random.randint(10,20,32)
mtcarsDF2["newHP"] = newColValues
#Creating a new column in the dataframe and assign the list of values to the new column.
mtcarsDF2.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb newMPG  newHP
# Mazda RX4             4    NaT     10
# Mazda RX4 Wag         4    NaT     16
# Datsun 710            1    NaT     18
# Hornet 4 Drive        1    NaT     17
# Hornet Sportabout     2    NaT     18

# %%
# insert a new col after wt
mtcarsDF2.columns
mtcarsDF2.insert(6, "newWT", mtcarsDF2.wt * 1.2, True) # multiply existing wt by 1.2
#6 – Position where the new column needs to be inserted
mtcarsDF2.head()
#To allow duplicate columns. If False, the new column will not be inserted 
#if a column with name Tax% is already existing. If you run this multiple times, multiple cols will get created
# Out:
#                     mpg  cyl   disp   hp  drat     wt  newWT   qsec  vs  am  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  3.144  16.46   0   1
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  3.450  17.02   0   1
# Datsun 710         22.8    4  108.0   93  3.85  2.320  2.784  18.61   1   1
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  3.858  19.44   1   0
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  4.128  17.02   0   0
#
#                    gear  carb newMPG  newHP
# Mazda RX4             4     4    NaT     10
# Mazda RX4 Wag         4     4    NaT     16
# Datsun 710            4     1    NaT     18
# Hornet 4 Drive        3     1    NaT     17
# Hornet Sportabout     3     2    NaT     18

# %%
print(mtcarsDF2.assign(remarks = pd.NaT))
print(mtcarsDF2)
# Out:
#                       mpg  cyl   disp   hp  drat     wt   newWT   qsec  vs  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  3.1440  16.46   0
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  3.4500  17.02   0
# Datsun 710           22.8    4  108.0   93  3.85  2.320  2.7840  18.61   1
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  3.8580  19.44   1
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  4.1280  17.02   0
# Valiant              18.1    6  225.0  105  2.76  3.460  4.1520  20.22   1
# Duster 360           14.3    8  360.0  245  3.21  3.570  4.2840  15.84   0
# Merc 240D            24.4    4  146.7   62  3.69  3.190  3.8280  20.00   1
# Merc 230             22.8    4  140.8   95  3.92  3.150  3.7800  22.90   1
# Merc 280             19.2    6  167.6  123  3.92  3.440  4.1280  18.30   1
# Merc 280C            17.8    6  167.6  123  3.92  3.440  4.1280  18.90   1
# Merc 450SE           16.4    8  275.8  180  3.07  4.070  4.8840  17.40   0
# Merc 450SL           17.3    8  275.8  180  3.07  3.730  4.4760  17.60   0
# Merc 450SLC          15.2    8  275.8  180  3.07  3.780  4.5360  18.00   0
# Cadillac Fleetwood   10.4    8  472.0  205  2.93  5.250  6.3000  17.98   0
# Lincoln Continental  10.4    8  460.0  215  3.00  5.424  6.5088  17.82   0
# Chrysler Imperial    14.7    8  440.0  230  3.23  5.345  6.4140  17.42   0
# Fiat 128             32.4    4   78.7   66  4.08  2.200  2.6400  19.47   1
# Honda Civic          30.4    4   75.7   52  4.93  1.615  1.9380  18.52   1
# Toyota Corolla       33.9    4   71.1   65  4.22  1.835  2.2020  19.90   1
# Toyota Corona        21.5    4  120.1   97  3.70  2.465  2.9580  20.01   1
# Dodge Challenger     15.5    8  318.0  150  2.76  3.520  4.2240  16.87   0
# AMC Javelin          15.2    8  304.0  150  3.15  3.435  4.1220  17.30   0
# Camaro Z28           13.3    8  350.0  245  3.73  3.840  4.6080  15.41   0
# Pontiac Firebird     19.2    8  400.0  175  3.08  3.845  4.6140  17.05   0
# Fiat X1-9            27.3    4   79.0   66  4.08  1.935  2.3220  18.90   1
# Porsche 914-2        26.0    4  120.3   91  4.43  2.140  2.5680  16.70   0
# Lotus Europa         30.4    4   95.1  113  3.77  1.513  1.8156  16.90   1
# Ford Pantera L       15.8    8  351.0  264  4.22  3.170  3.8040  14.50   0
# Ferrari Dino         19.7    6  145.0  175  3.62  2.770  3.3240  15.50   0
# Maserati Bora        15.0    8  301.0  335  3.54  3.570  4.2840  14.60   0
# Volvo 142E           21.4    4  121.0  109  4.11  2.780  3.3360  18.60   1
#
#                      am  gear  carb newMPG  newHP remarks
# Mazda RX4             1     4     4    NaT     10     NaT
# Mazda RX4 Wag         1     4     4    NaT     16     NaT
# Datsun 710            1     4     1    NaT     18     NaT
# Hornet 4 Drive        0     3     1    NaT     17     NaT
# Hornet Sportabout     0     3     2    NaT     18     NaT
# Valiant               0     3     1    NaT     11     NaT
# Duster 360            0     3     4    NaT     12     NaT
# Merc 240D             0     4     2    NaT     19     NaT
# Merc 230              0     4     2    NaT     16     NaT
# Merc 280              0     4     4    NaT     10     NaT
# Merc 280C             0     4     4    NaT     17     NaT
# Merc 450SE            0     3     3    NaT     11     NaT
# Merc 450SL            0     3     3    NaT     14     NaT
# Merc 450SLC           0     3     3    NaT     17     NaT
# Cadillac Fleetwood    0     3     4    NaT     17     NaT
# Lincoln Continental   0     3     4    NaT     18     NaT
# Chrysler Imperial     0     3     4    NaT     14     NaT
# Fiat 128              1     4     1    NaT     14     NaT
# Honda Civic           1     4     2    NaT     19     NaT
# Toyota Corolla        1     4     1    NaT     19     NaT
# Toyota Corona         0     3     1    NaT     19     NaT
# Dodge Challenger      0     3     2    NaT     14     NaT
# AMC Javelin           0     3     2    NaT     18     NaT
# Camaro Z28            0     3     4    NaT     18     NaT
# Pontiac Firebird      0     3     2    NaT     10     NaT
# Fiat X1-9             1     4     1    NaT     10     NaT
# Porsche 914-2         1     5     2    NaT     18     NaT
# Lotus Europa          1     5     2    NaT     16     NaT
# Ford Pantera L        1     5     4    NaT     16     NaT
# Ferrari Dino          1     5     6    NaT     12     NaT
# Maserati Bora         1     5     8    NaT     12     NaT
# Volvo 142E            1     4     2    NaT     10     NaT
#                       mpg  cyl   disp   hp  drat     wt   newWT   qsec  vs  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  3.1440  16.46   0
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  3.4500  17.02   0
# Datsun 710           22.8    4  108.0   93  3.85  2.320  2.7840  18.61   1
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  3.8580  19.44   1
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  4.1280  17.02   0
# Valiant              18.1    6  225.0  105  2.76  3.460  4.1520  20.22   1
# Duster 360           14.3    8  360.0  245  3.21  3.570  4.2840  15.84   0
# Merc 240D            24.4    4  146.7   62  3.69  3.190  3.8280  20.00   1
# Merc 230             22.8    4  140.8   95  3.92  3.150  3.7800  22.90   1
# Merc 280             19.2    6  167.6  123  3.92  3.440  4.1280  18.30   1
# Merc 280C            17.8    6  167.6  123  3.92  3.440  4.1280  18.90   1
# Merc 450SE           16.4    8  275.8  180  3.07  4.070  4.8840  17.40   0
# Merc 450SL           17.3    8  275.8  180  3.07  3.730  4.4760  17.60   0
# Merc 450SLC          15.2    8  275.8  180  3.07  3.780  4.5360  18.00   0
# Cadillac Fleetwood   10.4    8  472.0  205  2.93  5.250  6.3000  17.98   0
# Lincoln Continental  10.4    8  460.0  215  3.00  5.424  6.5088  17.82   0
# Chrysler Imperial    14.7    8  440.0  230  3.23  5.345  6.4140  17.42   0
# Fiat 128             32.4    4   78.7   66  4.08  2.200  2.6400  19.47   1
# Honda Civic          30.4    4   75.7   52  4.93  1.615  1.9380  18.52   1
# Toyota Corolla       33.9    4   71.1   65  4.22  1.835  2.2020  19.90   1
# Toyota Corona        21.5    4  120.1   97  3.70  2.465  2.9580  20.01   1
# Dodge Challenger     15.5    8  318.0  150  2.76  3.520  4.2240  16.87   0
# AMC Javelin          15.2    8  304.0  150  3.15  3.435  4.1220  17.30   0
# Camaro Z28           13.3    8  350.0  245  3.73  3.840  4.6080  15.41   0
# Pontiac Firebird     19.2    8  400.0  175  3.08  3.845  4.6140  17.05   0
# Fiat X1-9            27.3    4   79.0   66  4.08  1.935  2.3220  18.90   1
# Porsche 914-2        26.0    4  120.3   91  4.43  2.140  2.5680  16.70   0
# Lotus Europa         30.4    4   95.1  113  3.77  1.513  1.8156  16.90   1
# Ford Pantera L       15.8    8  351.0  264  4.22  3.170  3.8040  14.50   0
# Ferrari Dino         19.7    6  145.0  175  3.62  2.770  3.3240  15.50   0
# Maserati Bora        15.0    8  301.0  335  3.54  3.570  4.2840  14.60   0
# Volvo 142E           21.4    4  121.0  109  4.11  2.780  3.3360  18.60   1
#
#                      am  gear  carb newMPG  newHP
# Mazda RX4             1     4     4    NaT     10
# Mazda RX4 Wag         1     4     4    NaT     16
# Datsun 710            1     4     1    NaT     18
# Hornet 4 Drive        0     3     1    NaT     17
# Hornet Sportabout     0     3     2    NaT     18
# Valiant               0     3     1    NaT     11
# Duster 360            0     3     4    NaT     12
# Merc 240D             0     4     2    NaT     19
# Merc 230              0     4     2    NaT     16
# Merc 280              0     4     4    NaT     10
# Merc 280C             0     4     4    NaT     17
# Merc 450SE            0     3     3    NaT     11
# Merc 450SL            0     3     3    NaT     14
# Merc 450SLC           0     3     3    NaT     17
# Cadillac Fleetwood    0     3     4    NaT     17
# Lincoln Continental   0     3     4    NaT     18
# Chrysler Imperial     0     3     4    NaT     14
# Fiat 128              1     4     1    NaT     14
# Honda Civic           1     4     2    NaT     19
# Toyota Corolla        1     4     1    NaT     19
# Toyota Corona         0     3     1    NaT     19
# Dodge Challenger      0     3     2    NaT     14
# AMC Javelin           0     3     2    NaT     18
# Camaro Z28            0     3     4    NaT     18
# Pontiac Firebird      0     3     2    NaT     10
# Fiat X1-9             1     4     1    NaT     10
# Porsche 914-2         1     5     2    NaT     18
# Lotus Europa          1     5     2    NaT     16
# Ford Pantera L        1     5     4    NaT     16
# Ferrari Dino          1     5     6    NaT     12
# Maserati Bora         1     5     8    NaT     12
# Volvo 142E            1     4     2    NaT     10

# %% [markdown]
# #### iloc - integer location

# %%
mtcarsDF.iloc[1:10, 1:5]  #select rows and columns by integer value

# %%
mtcarsDF.iloc[1:10:3, 1:5:2]  #alternate rows or columns within a range

# %%
mtcarsDF.iloc[[1,5,7], [6,2]]  #alternate rows or columns within a range # no or name ?

# %%
mtcarsDF.iloc[0]  #first row

# %%
mtcarsDF.iloc[::,0]  #first column

# %%
mtcarsDF.iloc[1::5, 1::2]  #every fifth row, every alternate column

# %%
mtcarsDF.iloc[1, 5]  # 1st row and 5th column (all rows & col start at 0)

# %%
mtcarsDF.iloc[-1]  #last row

# %%
mtcarsDF.iloc[:,-1]  #last Column

# %%
mtcarsDF[::2]  #alternate rows

# %%
mtcarsDF.iloc[:,::2].head()  #alternate columns

# %%
mtcarsDF.iloc[::-1]  #reverse order of rows

# %%
mtcarsDF.iloc[:,::-1].head()  #reverse order of columns

# %%
mtcarsDF.iloc[::2].iloc[::2]  #alternate rows, then again alternate row

# %%
mtcarsDF.iloc[5:0:-2, 4:1:-1]  # 5th to 1st row, alternate; 4th to 1st column, alternating

# %%
mtcarsDF.tail() #check tail rows

# %%
### Filter rows based on column/ row values

# %%
#select columns

# %%
mtcarsDF.gear.head()  #one column only gear

# %%
mtcarsDF['gear'].head()  #one column

# %%
mtcarsDF[['gear','cyl']].head()  #two columns

# %%
mtcarsDF.filter(['gear']).head()  #selected col using filter

# %%
mtcarsDF.filter(items=['gear', 'cyl']).head()  #selected cols using filter

# %%
mtcarsDF.filter(regex = '[gGa]').head()  #selected cols using filter by characters - g G a

# %%
mtcarsDF.filter(regex = 'Toyota', axis=0).head()  #selected rows(axis=0) using filter by characters - Toyota

# %%
mtcarsDF.filter(regex = 'am', axis=1).head()  #selected cols(axis=1) using filter by characters - am

# %% [markdown]
# ## Conditions with filter
# DataFrame.filter(items=None, like=None, regex=None, axis=None)
# item – Takes list of axis labels that you wanted to filter.
# like – Takes axis string label that you wanted to filter
# regex – regular expression
# axis – {0 or ‘index’, 1 or ‘columns’, None}, default None. When not specified it used columns.

# %%
#df.filter(items=['Courses','Fee'])  #selected columns

# %%
#df.filter(like='ration', axis=1) # selected columns by names like

# %%
#df.filter(regex='e$', axis=1) # Filr column names by regex

# %%
#df.filter(items=[3,5], axis=0) # Filter rows

# %%
#df.filter(like='4', axis=0) # Filter row using like

# %%
mtcarsDF['gear'] == 3  # True or False depending upon condition

# %%
mtcarsDF[mtcarsDF['gear'] == 3]  # rows which match the condition

# %%
mtcarsDF.loc[(mtcarsDF['gear'] != 3) & (mtcarsDF['mpg'] > 25), ['gear','mpg','am']] # rows which match the condition

# %%
mtcarsDF[mtcarsDF.gear.eq(3)].head()  #chaining method

# %%
mtcarsDF.gear.unique()  #unique values of gears

# %%
mtcarsDF.carb.unique() #unique value of carb

# %%
gears = [4, 5]  #list of gears
mtcarsDF[mtcarsDF.gear.isin(gears)]  #is there a car from the list [4,5]

# %%
mtcarsDF[~ mtcarsDF.gear.isin(gears)].head()  #is there a car not from the list ~ tilde symbol

# %%
carbs = [1,3]  #list of carburators
mtcarsDF[mtcarsDF.gear.isin(gears) & mtcarsDF.carb.isin(carbs)] #multiple conditions with isin

# %%
mtcarsDF[~mtcarsDF.gear.isin(gears) & mtcarsDF.carb.isin(carbs)] #not with gear, yes with carbs

# %%
mtcarsDF[mtcarsDF.mpg > mtcarsDF.qsec].head()  #comparing columns

# %% [markdown]
# ##  Query function

# %%
mtcarsDF.query('gear==4')

# %%
mtcarsDF.query('gear=="4"')  #if a column is string

# %%
#mtcarsDF.query('index=="4"')  #if a column is string - not working here

# %%
mtcarsDF.query('gear==4 & am==0')  #twin conditions

# %%
mtcarsDF.query('gear in [3,7]').head()  #twin conditions

# %% [markdown]
# ## Sort

# %% [raw]
# #DataFrame.sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last', ignore_index=False, key=None)

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_values.html

# %%
mtcarsDF.sort_values(by='mpg', axis=0).head()  #sort DF by mpg - ascending order

# %%
mtcarsDF.sort_values(by=['carb','mpg'], axis=0).head(10)  #sort DF by carb, mpg - ascending order

# %%
mtcarsDF.sort_values(by=['carb','mpg'], ascending =[False, True] , axis=0).head(10) #asc-carb, desc mpg

# %% [markdown]
# ## Group By
# When you pass multiple group keys, only those rows whose group key values match with each other for all the group keys will be added in a group.
# Set the sort parameter as False for faster code execution.
# You can chain the steps of grouping and applying a function to reduce the lines of code.

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html

# %% [raw]
# #df.groupby(by=None, axis=0, level=None, as_index=True, sort=True, group_keys=True, squeeze=<object object>, observed=False, dropna=True)

# %%
mtcarsDF.groupby('gear')  #nothing will happen unless we ask for something

# %%
mtcarsDF.groupby(['gear','cyl'])  #nothing will happen unless we ask for something

# %%
mtcarsDF.groupby(['gear']).groups.keys() #grouping values , ie how groups will be created

# %%
mtcarsDF.groupby(['gear']).groups[3] #select rows with gear 3

# %%
mtcarsDF.groupby(['gear']).first() #first row of each group, default order

# %%
mtcarsDF.groupby(['gear']).last() #last 1 row of each group, default order

# %%
mtcarsDF.groupby(['gear','am']).first() #first row of each group and subgroup if there are default order

# %%
mtcarsDF.groupby(['gear'])['mpg'].mean()  #mean mpg of each group

# %%
mtcarsDF.groupby(['gear']).agg('mean')  #mean of all cols of each group

# %%
mtcarsDF.groupby(['gear']).agg('mean').add_prefix('MEAN_')  #mean of all cols of each group with name change

# %%
mtcarsDF.groupby(['gear','am']).agg(['mean','max'])  #mean & max of all cols of each groups

# %%
mtcarsDF.groupby(['gear','am'])[['mpg','hp']].agg(['mean','max']).reindex()  #mean & max of 2 cols of each groups

# %%
mtcarsDF.groupby(['gear','am'])[['mpg','hp']].apply(sum) #apply a function to grouping

# %%
#mtcarsDF.groupby(['gear','am'])[['mpg','hp']].apply([sum, mean]) #apply a function to grouping/ not working

# %% [markdown]
# ### size/ counts

# %%
mtcarsDF.groupby(['gear']).size()  #count of each category

# %%
mtcarsDF.groupby(['gear']).count()  #count of each category from all columns(not good)

# %%
mtcarsDF.groupby(['gear'])['mpg'].count()  #count of each category from all columns(slightly better good)

# %%
mtcarsDF['gear'].value_counts()  #count of each category

# %%
mtcarsDF.gear.value_counts()  #count of each category - this is for only 1 column

# %% [markdown]
# ### More aggregate functions

# %%
mtcarsDF.groupby(['gear'])[['mpg','wt']].agg([np.mean, np.median, 'count'])  #np functions are faster
# Out:
#             mpg                     wt
#            mean median count      mean median count
# gear
# 3     16.106667   15.5    15  3.892600   3.73    15
# 4     24.533333   22.8    12  2.616667   2.70    12
# 5     21.380000   19.7     5  2.632600   2.77     5

# %%
mtcarsDF.groupby('gear')['mpg'].agg([np.mean, np.sum, 'count']).rename(columns={'mean':'MEAN','sum' : 'SUM', 'count':'TOTAL'})
# Out:
#            MEAN    SUM  TOTAL
# gear
# 3     16.106667  241.6     15
# 4     24.533333  294.4     12
# 5     21.380000  106.9      5

# %% [markdown]
# ### Nth item

# %%
mtcarsDF.groupby(['gear']).nth(1) #nth item withing the group similar to first
# Out:
#        mpg  cyl   disp   hp  drat     wt   qsec  vs  am  carb
# gear
# 3     18.7    8  360.0  175  3.15  3.440  17.02   0   0     2
# 4     21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 5     30.4    4   95.1  113  3.77  1.513  16.90   1   1     2

# %%
mtcarsDF.groupby(['gear']).nth(3) #nth item withing the group similar to first
# Out:
#        mpg  cyl   disp   hp  drat    wt   qsec  vs  am  carb
# gear
# 3     14.3    8  360.0  245  3.21  3.57  15.84   0   0     4
# 4     24.4    4  146.7   62  3.69  3.19  20.00   1   0     2
# 5     19.7    6  145.0  175  3.62  2.77  15.50   0   1     6

# %%
mtcarsDF.sort_values(by='mpg', ascending=False).groupby(['gear']).head(3)  #top 3 by mpg from each gp
# Out:
#                    mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Toyota Corolla    33.9    4   71.1   65  4.22  1.835  19.90   1   1     4
# Fiat 128          32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# Lotus Europa      30.4    4   95.1  113  3.77  1.513  16.90   1   1     5
# Honda Civic       30.4    4   75.7   52  4.93  1.615  18.52   1   1     4
# Porsche 914-2     26.0    4  120.3   91  4.43  2.140  16.70   0   1     5
# Toyota Corona     21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# Hornet 4 Drive    21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Ferrari Dino      19.7    6  145.0  175  3.62  2.770  15.50   0   1     5
# Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0     3
#
#                   carb
# Toyota Corolla       1
# Fiat 128             1
# Lotus Europa         2
# Honda Civic          2
# Porsche 914-2        2
# Toyota Corona        1
# Hornet 4 Drive       1
# Ferrari Dino         6
# Pontiac Firebird     2

# %%
mtcarsDF.sort_values(by='mpg', ascending=False).groupby(['gear']).nth(2)  # 3rd by mpg from each gp
# Out:
#        mpg  cyl   disp   hp  drat     wt   qsec  vs  am  carb
# gear
# 3     19.2    8  400.0  175  3.08  3.845  17.05   0   0     2
# 4     30.4    4   75.7   52  4.93  1.615  18.52   1   1     2
# 5     19.7    6  145.0  175  3.62  2.770  15.50   0   1     6

# %%
mtcarsDF.sort_values(by='mpg', ascending=False).groupby(['gear']).nth([0,2])  # 1 & 3rd by mpg from each gp
# Out:
#        mpg  cyl   disp   hp  drat     wt   qsec  vs  am  carb
# gear
# 3     21.5    4  120.1   97  3.70  2.465  20.01   1   0     1
# 3     19.2    8  400.0  175  3.08  3.845  17.05   0   0     2
# 4     33.9    4   71.1   65  4.22  1.835  19.90   1   1     1
# 4     30.4    4   75.7   52  4.93  1.615  18.52   1   1     2
# 5     30.4    4   95.1  113  3.77  1.513  16.90   1   1     2
# 5     19.7    6  145.0  175  3.62  2.770  15.50   0   1     6

# %%
mtcarsDF.groupby(["gear"])["mpg"].nlargest(3) #within each gp top 3 by mpg, index values
# Out:
# gear
# 3     Toyota Corona       21.5
#       Hornet 4 Drive      21.4
#       Pontiac Firebird    19.2
# 4     Toyota Corolla      33.9
#       Fiat 128            32.4
#       Honda Civic         30.4
# 5     Lotus Europa        30.4
#       Porsche 914-2       26.0
#       Ferrari Dino        19.7
# Name: mpg, dtype: float64

# %%
mtcarsDF.groupby(["gear"])["mpg"].nsmallest(1) #within each gp bottom 1 by mpg, index values
# Out:
# gear
# 3     Cadillac Fleetwood    10.4
# 4     Merc 280C             17.8
# 5     Maserati Bora         15.0
# Name: mpg, dtype: float64

# %%
mtcarsDF.groupby(["gear"]).apply(lambda x: x.sort_values(['cyl','mpg'], ascending = [False,True])).reset_index(drop=True)
#group by gear, sort by cyl, mpg and display , no aggregation
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   10.4    8  472.0  205  2.93  5.250  17.98   0   0     3     4
# 1   10.4    8  460.0  215  3.00  5.424  17.82   0   0     3     4
# 2   13.3    8  350.0  245  3.73  3.840  15.41   0   0     3     4
# 3   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 4   14.7    8  440.0  230  3.23  5.345  17.42   0   0     3     4
# 5   15.2    8  275.8  180  3.07  3.780  18.00   0   0     3     3
# 6   15.2    8  304.0  150  3.15  3.435  17.30   0   0     3     2
# 7   15.5    8  318.0  150  2.76  3.520  16.87   0   0     3     2
# 8   16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 9   17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# 10  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 11  19.2    8  400.0  175  3.08  3.845  17.05   0   0     3     2
# 12  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 13  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 14  21.5    4  120.1   97  3.70  2.465  20.01   1   0     3     1
# 15  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 16  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 17  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 18  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 19  21.4    4  121.0  109  4.11  2.780  18.60   1   1     4     2
# 20  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 21  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 22  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 23  27.3    4   79.0   66  4.08  1.935  18.90   1   1     4     1
# 24  30.4    4   75.7   52  4.93  1.615  18.52   1   1     4     2
# 25  32.4    4   78.7   66  4.08  2.200  19.47   1   1     4     1
# 26  33.9    4   71.1   65  4.22  1.835  19.90   1   1     4     1
# 27  15.0    8  301.0  335  3.54  3.570  14.60   0   1     5     8
# 28  15.8    8  351.0  264  4.22  3.170  14.50   0   1     5     4
# 29  19.7    6  145.0  175  3.62  2.770  15.50   0   1     5     6
# 30  26.0    4  120.3   91  4.43  2.140  16.70   0   1     5     2
# 31  30.4    4   95.1  113  3.77  1.513  16.90   1   1     5     2

# %%
### Crosstab

# %% [raw]
# #https://pbpython.com/pandas-crosstab.html https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.crosstab.html

# %% [raw]
# #pd.crosstab(index, columns, values=None, rownames=None, colnames=None, aggfunc=None, margins=False, margins_name='All', dropna=True, normalize=False)[source]

# %%
pd.crosstab(index=mtcarsDF.cyl, columns=mtcarsDF.gear)  #cyl vs gear : count of values
# Out:
# gear   3  4  5
# cyl
# 4      1  8  2
# 6      2  4  1
# 8     12  0  2

# %%
pd.crosstab(index=mtcarsDF.cyl, columns=[mtcarsDF.gear, mtcarsDF.am])  #cyl vs gear & am : count of values
# Out:
# gear   3  4     5
# am     0  0  1  1
# cyl
# 4      1  2  6  2
# 6      2  2  2  1
# 8     12  0  0  2

# %%
pd.crosstab(mtcarsDF.cyl, mtcarsDF.gear, margins=True, margins_name='TotalCars')  #cyl vs gear : count of values
# Out:
# gear        3   4  5  TotalCars
# cyl
# 4           1   8  2         11
# 6           2   4  1          7
# 8          12   0  2         14
# TotalCars  15  12  5         32

# %%
pd.crosstab(index=[mtcarsDF.cyl, mtcarsDF.vs], columns=[mtcarsDF.gear, mtcarsDF.am], rownames=['Cylinder','EngineShape'], colnames =['Gear','AutoManual'])  #cyl & vs - gear & am : count of values, names changed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 pd.crosstab(index=[mtcarsDF.cyl, mtcarsDF.vs], columns=[mtcarsDF.gear, mtcarsDF.am], rownames=['Cylinder','EngineShape'], colnames =['Gear','AutoManual'])
#
# NameError: name 'pd' is not defined

# %%
pd.crosstab(index=mtcarsDF.cyl, columns=[mtcarsDF.gear, mtcarsDF.am]).reindex() #??
# Out:
# gear   3  4     5
# am     0  0  1  1
# cyl
# 4      1  2  6  2
# 6      2  2  2  1
# 8     12  0  0  2

# %%
pd.crosstab(mtcarsDF.cyl, mtcarsDF.gear, values=mtcarsDF.mpg, aggfunc='mean').round(0)
# Out:
# gear     3     4     5
# cyl
# 4     22.0  27.0  28.0
# 6     20.0  20.0  20.0
# 8     15.0   NaN  15.0

# %%
pd.crosstab(mtcarsDF.cyl, mtcarsDF.gear)
# Out:
# gear   3  4  5
# cyl
# 4      1  8  2
# 6      2  4  1
# 8     12  0  2

# %% [raw]
# #above is the count of cars #now we can find %

# %%
pd.crosstab(mtcarsDF.cyl, mtcarsDF.gear, normalize=True)  #% of cars
# Out:
# gear        3      4        5
# cyl
# 4     0.03125  0.250  0.06250
# 6     0.06250  0.125  0.03125
# 8     0.37500  0.000  0.06250

# %%
pd.crosstab(mtcarsDF.cyl, mtcarsDF.gear, normalize='columns').round(1) #column sums=1
# Out:
# gear    3    4    5
# cyl
# 4     0.1  0.7  0.4
# 6     0.1  0.3  0.2
# 8     0.8  0.0  0.4

# %%
pd.crosstab(mtcarsDF.cyl, mtcarsDF.gear, normalize='index').round(1) #rows sum =1
# Out:
# gear    3    4    5
# cyl
# 4     0.1  0.7  0.2
# 6     0.3  0.6  0.1
# 8     0.9  0.0  0.1

# %%
sns.heatmap(pd.crosstab(mtcarsDF.cyl, mtcarsDF.gear), cmap="YlGnBu", annot=True, cbar=False)
# Out:
# <AxesSubplot:xlabel='gear', ylabel='cyl'>

# %%
mtcarsDF.groupby(['gear', 'cyl'])['am'].count().unstack().fillna(0)  #using grouby
# Out:
# cyl     4    6     8
# gear
# 3     1.0  2.0  12.0
# 4     8.0  4.0   0.0
# 5     2.0  1.0   2.0

# %%
mtcarsDF.pivot_table(index='gear', columns='cyl', aggfunc={'am':len}, fill_value=0)
# Out:
#      am
# cyl   4  6   8
# gear
# 3     1  2  12
# 4     8  4   0
# 5     2  1   2

# %% [raw]
# it can be tough to remember all the steps to make this happen on your own. The simple crosstab API is the quickest route to the solution and provides some useful shortcuts for certain types of analysis.In my experience, it is important to know about the options and use the one that flows most naturally from the analysis. I have had experiences where I struggled trying to make a pivot_table solution and then quickly got what I wanted by using a crosstab. The great thing about pandas is that once the data is in a dataframe all these manipulations are 1 line of code so you are free to experiment. https://pbpython.com/images/crosstab_cheatsheet.png

# %% [markdown]
# ### Pivot

# %% [raw]
# #pd.pivot(index=None, columns=None, values=None) : This function does not support data aggregation,: Changes shape of data

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html

# %%
#mtcarsDF.pivot(index='cyl', columns='gear', values='am')  #needs unique columns

# %%
df = pd.DataFrame({'course': ['BBA', 'BBA', 'MBA', 'MBA','PHD','PHD'],'gender': ['M', 'F', 'M', 'F', 'M', 'F'], 'count': [10, 12, 23, 14, 15, 6]})

# %%
df
# Out:
#   course gender  count
# 0    BBA      M     10
# 1    BBA      F     12
# 2    MBA      M     23
# 3    MBA      F     14
# 4    PHD      M     15
# 5    PHD      F      6

# %%
df.pivot(index='course', columns='gender', values='count')
# Out:
# gender   F   M
# course
# BBA     12  10
# MBA     14  23
# PHD      6  15

# %%
#mtcarsDF.pivot(index='gear', columns='cyl', values='am')

# %% [markdown]
# ### Pivot Table with pivot_table

# %% [raw]
# #pd.pivot_table(data, values=None, index=None, columns=None, aggfunc='mean', fill_value=None, margins=False, dropna=True, margins_name='All', observed=False)

# %%
pd.pivot_table(data=mtcarsDF, columns=['gear'], values='mpg', index=['am', 'cyl'], aggfunc=np.sum)
#group by am & cyl, find mean mpg of each gear type
# Out:
# gear        3      4     5
# am cyl
# 0  4     21.5   47.2   NaN
#    6     39.5   37.0   NaN
#    8    180.6    NaN   NaN
# 1  4      NaN  168.2  56.4
#    6      NaN   42.0  19.7
#    8      NaN    NaN  30.8

# %%
mtcarsDF.groupby(['gear']).agg({'mpg':'mean','hp':'max'})  #mean mpg & max hp of each group
# Out:
#             mpg   hp
# gear
# 3     16.106667  245
# 4     24.533333  123
# 5     21.380000  335

# %% [markdown]
# # Statistics

# %%
mtcarsDF.mean(axis=0)  #mean col wise, g. mean marks, subject wise
# Out:
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64

# %%
mtcarsDF.mean(axis=1)  #mean row wise , not relevant here. eg Mean marks of each student
# Out:
# Mazda RX4              29.907273
# Mazda RX4 Wag          29.981364
# Datsun 710             23.598182
# Hornet 4 Drive         38.739545
# Hornet Sportabout      53.664545
# Valiant                35.049091
# Duster 360             59.720000
# Merc 240D              24.634545
# Merc 230               27.233636
# Merc 280               31.860000
# Merc 280C              31.787273
# Merc 450SE             46.430909
# Merc 450SL             46.500000
# Merc 450SLC            46.350000
# Cadillac Fleetwood     66.232727
# Lincoln Continental    66.058545
# Chrysler Imperial      65.972273
# Fiat 128               19.440909
# Honda Civic            17.742273
# Toyota Corolla         18.814091
# Toyota Corona          24.888636
# Dodge Challenger       47.240909
# AMC Javelin            46.007727
# Camaro Z28             58.752727
# Pontiac Firebird       57.379545
# Fiat X1-9              18.928636
# Porsche 914-2          24.779091
# Lotus Europa           24.880273
# Ford Pantera L         60.971818
# Ferrari Dino           34.508182
# Maserati Bora          63.155455
# Volvo 142E             26.262727
# dtype: float64

# %%
mtcarsDF.kurt(axis=0) # kurtosis - col
# Out:
# mpg    -0.022006
# cyl    -1.762794
# disp   -1.067523
# hp      0.275212
# drat   -0.450432
# wt      0.416595
# qsec    0.864931
# vs     -2.063273
# am     -1.966550
# gear   -0.895292
# carb    2.020059
# dtype: float64

# %%
mtcarsDF.skew(axis=0) # skewness - row
# Out:
# mpg     0.672377
# cyl    -0.192261
# disp    0.420233
# hp      0.799407
# drat    0.292780
# wt      0.465916
# qsec    0.406347
# vs      0.264542
# am      0.400809
# gear    0.582309
# carb    1.157091
# dtype: float64

# %%
mtcarsDF.max(axis=0) # max - col
# Out:
# mpg      33.900
# cyl       8.000
# disp    472.000
# hp      335.000
# drat      4.930
# wt        5.424
# qsec     22.900
# vs        1.000
# am        1.000
# gear      5.000
# carb      8.000
# dtype: float64

# %%
mtcarsDF.min(axis=0) # min - col
# Out:
# mpg     10.400
# cyl      4.000
# disp    71.100
# hp      52.000
# drat     2.760
# wt       1.513
# qsec    14.500
# vs       0.000
# am       0.000
# gear     3.000
# carb     1.000
# dtype: float64

# %%
mtcarsDF.rank(axis=0).head() # rank of row within the column
# Out:
#                     mpg   cyl  disp    hp  drat    wt  qsec    vs    am  gear  \
# Mazda RX4          19.5  15.0  13.5  13.0  21.5   9.0   6.0   9.5  26.0  21.5
# Mazda RX4 Wag      19.5  15.0  13.5  13.0  21.5  12.0  10.5   9.5  26.0  21.5
# Datsun 710         24.5   6.0   6.0   7.0  20.0   7.0  23.0  25.5  26.0  21.5
# Hornet 4 Drive     21.5  15.0  18.0  13.0   8.5  16.0  26.0  25.5  10.0   8.0
# Hornet Sportabout  15.0  25.5  27.5  21.0  10.5  19.0  10.5   9.5  10.0   8.0
#
#                    carb
# Mazda RX4          25.5
# Mazda RX4 Wag      25.5
# Datsun 710          4.0
# Hornet 4 Drive      4.0
# Hornet Sportabout  12.5

# %%
mtcarsDF.median(axis=0) # median - col
# Out:
# mpg      19.200
# cyl       6.000
# disp    196.300
# hp      123.000
# drat      3.695
# wt        3.325
# qsec     17.710
# vs        0.000
# am        0.000
# gear      4.000
# carb      2.000
# dtype: float64

# %%
mtcarsDF.quantile([.25,.5,.75,1]) # quantile - col
# Out:
#          mpg  cyl     disp     hp   drat       wt     qsec   vs   am  gear  \
# 0.25  15.425  4.0  120.825   96.5  3.080  2.58125  16.8925  0.0  0.0   3.0
# 0.50  19.200  6.0  196.300  123.0  3.695  3.32500  17.7100  0.0  0.0   4.0
# 0.75  22.800  8.0  326.000  180.0  3.920  3.61000  18.9000  1.0  1.0   4.0
# 1.00  33.900  8.0  472.000  335.0  4.930  5.42400  22.9000  1.0  1.0   5.0
#
#       carb
# 0.25   2.0
# 0.50   2.0
# 0.75   4.0
# 1.00   8.0

# %%
mtcarsDF.describe() # range & other values - col
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# 25%    16.892500   0.000000   0.000000   3.000000   2.0000
# 50%    17.710000   0.000000   0.000000   4.000000   2.0000
# 75%    18.900000   1.000000   1.000000   4.000000   4.0000
# max    22.900000   1.000000   1.000000   5.000000   8.0000

# %%
mtcarsDF['gear'].count()  #count of col values
# Out:
# 32

# %%
mtcarsDF['gear'].value_counts()  #count of each distinct col values (esp when col are category)
# Out:
# 3    15
# 4    12
# 5     5
# Name: gear, dtype: int64

# %%
mtcarsDF['wt'][mtcarsDF['gear']==4]  #wt of gear 4 cars
# Out:
# Mazda RX4         2.620
# Mazda RX4 Wag     2.875
# Datsun 710        2.320
# Merc 240D         3.190
# Merc 230          3.150
# Merc 280          3.440
# Merc 280C         3.440
# Fiat 128          2.200
# Honda Civic       1.615
# Toyota Corolla    1.835
# Fiat X1-9         1.935
# Volvo 142E        2.780
# Name: wt, dtype: float64

# %%
mtcarsDF['wt'][mtcarsDF['gear']==4].sum() # sum of wt of gear 4 cars
# Out:
# 31.4

# %%
mtcarsDF[mtcarsDF['hp'] > 150].gear.value_counts()  # cars with hp> 150, their gear type and counts
# Out:
# 3    10
# 5     3
# Name: gear, dtype: int64

# %%
mtcarsDF['mpg'].unique()   #unique values of mileage
# Out:
# array([21. , 22.8, 21.4, 18.7, 18.1, 14.3, 24.4, 19.2, 17.8, 16.4, 17.3,
#        15.2, 10.4, 14.7, 32.4, 30.4, 33.9, 21.5, 15.5, 13.3, 27.3, 26. ,
#        15.8, 19.7, 15. ])

# %%
len(mtcars['mpg'].unique())  #count unique values of mileage
# Out:
# 25

# %%
mtcars['mpg'].nunique()   #non null & unique values of mileage, sometimes null can be counted as unique
# Out:
# 25

# %%
mtcarsDF
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# Merc 450SE           16.4    8  275.8  180  3.07  4.070  17.40   0   0     3
# Merc 450SL           17.3    8  275.8  180  3.07  3.730  17.60   0   0     3
# Merc 450SLC          15.2    8  275.8  180  3.07  3.780  18.00   0   0     3
# Cadillac Fleetwood   10.4    8  472.0  205  2.93  5.250  17.98   0   0     3
# Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0     3
# Chrysler Imperial    14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Fiat 128             32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# Honda Civic          30.4    4   75.7   52  4.93  1.615  18.52   1   1     4
# Toyota Corolla       33.9    4   71.1   65  4.22  1.835  19.90   1   1     4
# Toyota Corona        21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# Dodge Challenger     15.5    8  318.0  150  2.76  3.520  16.87   0   0     3
# AMC Javelin          15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# Camaro Z28           13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Pontiac Firebird     19.2    8  400.0  175  3.08  3.845  17.05   0   0     3
# Fiat X1-9            27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# Porsche 914-2        26.0    4  120.3   91  4.43  2.140  16.70   0   1     5
# Lotus Europa         30.4    4   95.1  113  3.77  1.513  16.90   1   1     5
# Ford Pantera L       15.8    8  351.0  264  4.22  3.170  14.50   0   1     5
# Ferrari Dino         19.7    6  145.0  175  3.62  2.770  15.50   0   1     5
# Maserati Bora        15.0    8  301.0  335  3.54  3.570  14.60   0   1     5
# Volvo 142E           21.4    4  121.0  109  4.11  2.780  18.60   1   1     4
#
#                      carb
# Mazda RX4               4
# Mazda RX4 Wag           4
# Datsun 710              1
# Hornet 4 Drive          1
# Hornet Sportabout       2
# Valiant                 1
# Duster 360              4
# Merc 240D               2
# Merc 230                2
# Merc 280                4
# Merc 280C               4
# Merc 450SE              3
# Merc 450SL              3
# Merc 450SLC             3
# Cadillac Fleetwood      4
# Lincoln Continental     4
# Chrysler Imperial       4
# Fiat 128                1
# Honda Civic             2
# Toyota Corolla          1
# Toyota Corona           1
# Dodge Challenger        2
# AMC Javelin             2
# Camaro Z28              4
# Pontiac Firebird        2
# Fiat X1-9               1
# Porsche 914-2           2
# Lotus Europa            2
# Ford Pantera L          4
# Ferrari Dino            6
# Maserati Bora           8
# Volvo 142E              2

# %%
type(mtcarsDF)  #type of structure
# Out:
# pandas.core.frame.DataFrame

# %%
mtcarsDF.index #index key (normally rownames)
# Out:
# Index(['Mazda RX4', 'Mazda RX4 Wag', 'Datsun 710', 'Hornet 4 Drive',
#        'Hornet Sportabout', 'Valiant', 'Duster 360', 'Merc 240D', 'Merc 230',
#        'Merc 280', 'Merc 280C', 'Merc 450SE', 'Merc 450SL', 'Merc 450SLC',
#        'Cadillac Fleetwood', 'Lincoln Continental', 'Chrysler Imperial',
#        'Fiat 128', 'Honda Civic', 'Toyota Corolla', 'Toyota Corona',
#        'Dodge Challenger', 'AMC Javelin', 'Camaro Z28', 'Pontiac Firebird',
#        'Fiat X1-9', 'Porsche 914-2', 'Lotus Europa', 'Ford Pantera L',
#        'Ferrari Dino', 'Maserati Bora', 'Volvo 142E'],
#       dtype='object')

# %% [markdown]
# ## Class Intervals

# %%
pd.cut(x=mtcarsDF.mpg, bins=5)
#pandas.cut(x, bins, right=True, labels=None, precision=3, include_lowest=False, duplicates='raise', ordered=True)
# Out:
# Mazda RX4                (19.8, 24.5]
# Mazda RX4 Wag            (19.8, 24.5]
# Datsun 710               (19.8, 24.5]
# Hornet 4 Drive           (19.8, 24.5]
# Hornet Sportabout        (15.1, 19.8]
# Valiant                  (15.1, 19.8]
# Duster 360             (10.376, 15.1]
# Merc 240D                (19.8, 24.5]
# Merc 230                 (19.8, 24.5]
# Merc 280                 (15.1, 19.8]
# Merc 280C                (15.1, 19.8]
# Merc 450SE               (15.1, 19.8]
# Merc 450SL               (15.1, 19.8]
# Merc 450SLC              (15.1, 19.8]
# Cadillac Fleetwood     (10.376, 15.1]
# Lincoln Continental    (10.376, 15.1]
# Chrysler Imperial      (10.376, 15.1]
# Fiat 128                 (29.2, 33.9]
# Honda Civic              (29.2, 33.9]
# Toyota Corolla           (29.2, 33.9]
# Toyota Corona            (19.8, 24.5]
# Dodge Challenger         (15.1, 19.8]
# AMC Javelin              (15.1, 19.8]
# Camaro Z28             (10.376, 15.1]
# Pontiac Firebird         (15.1, 19.8]
# Fiat X1-9                (24.5, 29.2]
# Porsche 914-2            (24.5, 29.2]
# Lotus Europa             (29.2, 33.9]
# Ford Pantera L           (15.1, 19.8]
# Ferrari Dino             (15.1, 19.8]
# Maserati Bora          (10.376, 15.1]
# Volvo 142E               (19.8, 24.5]
# Name: mpg, dtype: category
# Categories (5, interval[float64, right]): [(10.376, 15.1] < (15.1, 19.8] < (19.8, 24.5] < (24.5, 29.2] < (29.2, 33.9]]

# %%
pd.cut(x=mtcarsDF.mpg, bins=[10,15,20,30,40], labels=False)
# Out:
# Mazda RX4              2
# Mazda RX4 Wag          2
# Datsun 710             2
# Hornet 4 Drive         2
# Hornet Sportabout      1
# Valiant                1
# Duster 360             0
# Merc 240D              2
# Merc 230               2
# Merc 280               1
# Merc 280C              1
# Merc 450SE             1
# Merc 450SL             1
# Merc 450SLC            1
# Cadillac Fleetwood     0
# Lincoln Continental    0
# Chrysler Imperial      0
# Fiat 128               3
# Honda Civic            3
# Toyota Corolla         3
# Toyota Corona          2
# Dodge Challenger       1
# AMC Javelin            1
# Camaro Z28             0
# Pontiac Firebird       1
# Fiat X1-9              2
# Porsche 914-2          2
# Lotus Europa           3
# Ford Pantera L         1
# Ferrari Dino           1
# Maserati Bora          0
# Volvo 142E             2
# Name: mpg, dtype: int64

# %%
#quartiles or partition numbers 
pd.qcut(x=mtcarsDF.mpg, q=4, precision=2)
# Out:
# Mazda RX4                (19.2, 22.8]
# Mazda RX4 Wag            (19.2, 22.8]
# Datsun 710               (19.2, 22.8]
# Hornet 4 Drive           (19.2, 22.8]
# Hornet Sportabout       (15.42, 19.2]
# Valiant                 (15.42, 19.2]
# Duster 360             (10.39, 15.42]
# Merc 240D                (22.8, 33.9]
# Merc 230                 (19.2, 22.8]
# Merc 280                (15.42, 19.2]
# Merc 280C               (15.42, 19.2]
# Merc 450SE              (15.42, 19.2]
# Merc 450SL              (15.42, 19.2]
# Merc 450SLC            (10.39, 15.42]
# Cadillac Fleetwood     (10.39, 15.42]
# Lincoln Continental    (10.39, 15.42]
# Chrysler Imperial      (10.39, 15.42]
# Fiat 128                 (22.8, 33.9]
# Honda Civic              (22.8, 33.9]
# Toyota Corolla           (22.8, 33.9]
# Toyota Corona            (19.2, 22.8]
# Dodge Challenger        (15.42, 19.2]
# AMC Javelin            (10.39, 15.42]
# Camaro Z28             (10.39, 15.42]
# Pontiac Firebird        (15.42, 19.2]
# Fiat X1-9                (22.8, 33.9]
# Porsche 914-2            (22.8, 33.9]
# Lotus Europa             (22.8, 33.9]
# Ford Pantera L          (15.42, 19.2]
# Ferrari Dino             (19.2, 22.8]
# Maserati Bora          (10.39, 15.42]
# Volvo 142E               (19.2, 22.8]
# Name: mpg, dtype: category
# Categories (4, interval[float64, right]): [(10.39, 15.42] < (15.42, 19.2] < (19.2, 22.8] < (22.8, 33.9]]

# %%
pd.qcut(x=mtcarsDF.mpg, q=10, precision=2)
# Out:
# Mazda RX4                (19.2, 21.0]
# Mazda RX4 Wag            (19.2, 21.0]
# Datsun 710             (21.47, 24.08]
# Hornet 4 Drive          (21.0, 21.47]
# Hornet Sportabout       (17.92, 19.2]
# Valiant                 (17.92, 19.2]
# Duster 360             (10.39, 14.34]
# Merc 240D              (24.08, 30.09]
# Merc 230               (21.47, 24.08]
# Merc 280                (17.92, 19.2]
# Merc 280C              (15.98, 17.92]
# Merc 450SE             (15.98, 17.92]
# Merc 450SL             (15.98, 17.92]
# Merc 450SLC             (14.34, 15.2]
# Cadillac Fleetwood     (10.39, 14.34]
# Lincoln Continental    (10.39, 14.34]
# Chrysler Imperial       (14.34, 15.2]
# Fiat 128                (30.09, 33.9]
# Honda Civic             (30.09, 33.9]
# Toyota Corolla          (30.09, 33.9]
# Toyota Corona          (21.47, 24.08]
# Dodge Challenger        (15.2, 15.98]
# AMC Javelin             (14.34, 15.2]
# Camaro Z28             (10.39, 14.34]
# Pontiac Firebird        (17.92, 19.2]
# Fiat X1-9              (24.08, 30.09]
# Porsche 914-2          (24.08, 30.09]
# Lotus Europa            (30.09, 33.9]
# Ford Pantera L          (15.2, 15.98]
# Ferrari Dino             (19.2, 21.0]
# Maserati Bora           (14.34, 15.2]
# Volvo 142E              (21.0, 21.47]
# Name: mpg, dtype: category
# Categories (10, interval[float64, right]): [(10.39, 14.34] < (14.34, 15.2] < (15.2, 15.98] < (15.98, 17.92] ... (21.0, 21.47] < (21.47, 24.08] < (24.08, 30.09] < (30.09, 33.9]]

# %%
pd.qcut(x=mtcarsDF.mpg, q=10, precision=2).value_counts()
# Out:
# (10.39, 14.34]    4
# (14.34, 15.2]     4
# (17.92, 19.2]     4
# (30.09, 33.9]     4
# (15.98, 17.92]    3
# (19.2, 21.0]      3
# (21.47, 24.08]    3
# (24.08, 30.09]    3
# (15.2, 15.98]     2
# (21.0, 21.47]     2
# Name: mpg, dtype: int64

# %% [markdown]
# ## Other Functions
# melt
# pivot
# pivot_table
# crosstab
# cut
# qcut
# merge
# merge_ordered
# merg_asof
# concat
# get_dummies
# factorize
# unique
# wide_to_long
# isna
# isnull
# notna
# notnull
# to_numeric
# to_datetime
# to_timedelta
# date_range
# bdate_range
# period_range
# timedelta_range
# infer_freq
# interval_range
# eval
# util.hash_array
# api.interchange.from_dataframe

# %% [markdown]
# ### End of Code
