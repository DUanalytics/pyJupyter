# %% [markdown]
# # Queries
# List of queries
# - Some Columns and rows not seen while printing data frame
# - Why certain stats functions are not used from pandas (functions from np prefered)

# %% [markdown]
# ## Pending Queries

# %%
# Libraries
import numpy as np
import pandas as pd

# %%
# Datset for explanations
from pydataset import data
mtcars = data('mtcars')
mtcarsDF = mtcars
mtcarsDF.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %% [markdown]
# ### Why limited columns are visible
# Pandas autodetects the size of your terminal window if you set pd.options.display.width = 0
# pandas.set_option(optname, val), or equivalently
# pd.options.<opt.hierarchical.name> = val
# display.[chop_threshold, colheader_justify, column_space, date_dayfirst, date_yearfirst, encoding, expand_frame_repr, float_format, height,line_width, max_columns, max_colwidth, max_info_columns, max_info_rows,max_rows, max_seq_items, mpl_style, multi_sparse, notebook_repr_html, pprint_nest_depth, precision, width]
# https://pandas.pydata.org/pandas-docs/version/0.15.2/generated/pandas.set_option.html

# %%
import pandas as pd
pd.set_option('display.max_rows', 5)
pd.set_option('display.max_columns', 5)

# %%
mtcarsDF
# Out:
#                 mpg  \
# Mazda RX4      21.0
# Mazda RX4 Wag  21.0
# ...             ...
# Maserati Bora  15.0
# Volvo 142E     21.4
#
#                cyl  \
# Mazda RX4        6
# Mazda RX4 Wag    6
# ...            ...
# Maserati Bora    8
# Volvo 142E       4
#
#                ...  \
# Mazda RX4      ...
# Mazda RX4 Wag  ...
# ...            ...
# Maserati Bora  ...
# Volvo 142E     ...
#
#                gear  \
# Mazda RX4         4
# Mazda RX4 Wag     4
# ...             ...
# Maserati Bora     5
# Volvo 142E        4
#
#                carb
# Mazda RX4         4
# Mazda RX4 Wag     4
# ...             ...
# Maserati Bora     8
# Volvo 142E        2
#
# [32 rows x 11 columns]

# %%
pd.set_option('display.max_rows', 15)
pd.set_option('display.max_columns', 11)
pd.set_option('display.width', 10)
mtcarsDF
# Out:
#                     mpg  \
# Mazda RX4          21.0
# Mazda RX4 Wag      21.0
# Datsun 710         22.8
# Hornet 4 Drive     21.4
# Hornet Sportabout  18.7
# ...                 ...
# Lotus Europa       30.4
# Ford Pantera L     15.8
# Ferrari Dino       19.7
# Maserati Bora      15.0
# Volvo 142E         21.4
#
#                    cyl  \
# Mazda RX4            6
# Mazda RX4 Wag        6
# Datsun 710           4
# Hornet 4 Drive       6
# Hornet Sportabout    8
# ...                ...
# Lotus Europa         4
# Ford Pantera L       8
# Ferrari Dino         6
# Maserati Bora        8
# Volvo 142E           4
#
#                     disp  \
# Mazda RX4          160.0
# Mazda RX4 Wag      160.0
# Datsun 710         108.0
# Hornet 4 Drive     258.0
# Hornet Sportabout  360.0
# ...                  ...
# Lotus Europa        95.1
# Ford Pantera L     351.0
# Ferrari Dino       145.0
# Maserati Bora      301.0
# Volvo 142E         121.0
#
#                     hp  \
# ...

# %% [markdown]
# ## Sometimes it is preferable to use numpy functions instead of pandas as there are faster
# mean values from pandas and numpy
# np.mean, np.min  - are from numpy https://numpy.org/doc/stable/reference/generated/numpy.std.html
# min, max, std - are from pandas https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.std.html

# %%
mtcarsDF.gear.mean()
# Out:
# 3.6875

# %%
mtcarsDF.groupby(['gear'])[['mpg','wt']].mean() #pandas
# Out:
#             mpg        wt
# gear
# 3     16.106667  3.892600
# 4     24.533333  2.616667
# 5     21.380000  2.632600

# %%
mtcarsDF.groupby(['gear'])[['mpg','wt']].agg(np.mean) #numpy
# Out:
#             mpg        wt
# gear
# 3     16.106667  3.892600
# 4     24.533333  2.616667
# 5     21.380000  2.632600

# %%
mtcarsDF.groupby(['gear']).aggregate({'mpg':[np.mean, 'mean',np.min, 'min',np.max,'max', np.std, 'std']})

# %%
# %timeit max(range(100000))
# Out:
# 6.07 ms ± 148 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit mtcarsDF.aggregate({'mpg':[np.mean]})
# Out:
# 2.28 ms ± 92.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit mtcarsDF.mpg.mean()
# Out:
# 143 µs ± 11 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# # Other queries Raised
