# %%
#simple LR using stats

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

# %%
#Execute a method that returns some important key values of Linear Regression:
slope, intercept, r, p, std_err = stats.linregress(x, y)

# %%
print(stats.linregress(x,y))
# Out:
# LinregressResult(slope=-1.7512877115526118, intercept=103.10596026490066, rvalue=-0.758591524376155, pvalue=0.0026468739224561064, stderr=0.453536157607742, intercept_stderr=3.9034928101545123)

# %%
print("\n Slope- ", slope, "\n Intercept -", intercept, "\n R2 - ", r, "\n pValue - ", p , "\n Std Error- ", std_err)
# Out:
#  Slope-  -1.7512877115526118
#  Intercept - 103.10596026490066
#  R2 -  -0.758591524376155
#  pValue -  0.0026468739224561064
#  Std Error-  0.453536157607742

# %%
##Create a function that uses the slope and intercept values to return a new value.
#This new value represents where on the y-axis the corresponding x value will be placed:
def myfunc(x):  return slope * x + intercept
#Run each value of the x array through the function. This will result in a new array with new values for the y-axis:

# %%
mymodel = list(map(myfunc, x))

# %%
mymodel
# Out:
# [94.3495217071376,
#  90.84694628403238,
#  89.09565857247976,
#  90.84694628403238,
#  99.60338484179543,
#  73.33406916850626,
#  99.60338484179543,
#  87.34437086092716,
#  96.10080941869022,
#  83.84179543782193,
#  82.09050772626932,
#  87.34437086092716,
#  92.59823399558499]

# %%
plt.scatter(x, y)  # dots
plt.plot(x, mymodel)  #straight line
plt.show();

# %%
print(type(y), type(mymodel))
# Out:
# <class 'list'> <class 'list'>

# %%
print(r)
# Out:
# -0.758591524376155

# %%
print(myfunc(10))  #predict for certain input 10yr old car
# Out:
# 85.59308314937454

# %%
plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()
