# %% [markdown]
# # Time Series
# Time series is a series of data points in which each data point is associated with a timestamp. A simple example is the price of a stock in the stock market at different points of time on a given day. Another example is the amount of rainfall in a region at different months of the year.

# %% [markdown]
# ## Libraries

# %%
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#!pip install pandas_datareader

# %%
## Import Data

# %%
#dataLink = 'https://github.com/DUanalytics/datasets/blob/master/csv/stock1.csv'
#SBI stock prices
#data = pd.read_csv(dataLink)
#df = pd.DataFrame(data, columns = ['StockPrice','ValueDate'])

# Set the Date as Index
#df['ValueDate'] = pd.to_datetime(df['ValueDate'])
#df.index = df['ValueDate']
#del df['ValueDate']

# %%
import pandas_datareader as pdr
# Reading Apple shares from yahoo finance server    
shares_df = pdr.DataReader('AAPL', 'yahoo', start='2022-01-01', end='2022-11-01')
# Look at the data read
print(shares_df)
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2021-12-31  179.229996  177.259995  178.089996  177.570007   64062300.0
# 2022-01-03  182.880005  177.710007  177.830002  182.009995  104487900.0
# 2022-01-04  182.940002  179.119995  182.630005  179.699997   99310400.0
# 2022-01-05  180.169998  174.639999  179.610001  174.919998   94537600.0
# 2022-01-06  175.300003  171.639999  172.699997  172.000000   96904000.0
# ...                ...         ...         ...         ...          ...
# 2022-10-26  151.990005  148.039993  150.960007  149.350006   88194300.0
# 2022-10-27  149.050003  144.130005  148.070007  144.800003  109180200.0
# 2022-10-28  157.500000  147.820007  148.199997  155.740005  164762400.0
# 2022-10-31  154.240005  151.919998  153.160004  153.339996   97943200.0
# 2022-11-01  155.449997  149.130005  155.080002  150.649994   80321400.0
#
#              Adj Close
# Date
# 2021-12-31  176.838242
# 2022-01-03  181.259918
# 2022-01-04  178.959457
# 2022-01-05  174.199158
# 2022-01-06  171.291183
# ...                ...
# 2022-10-26  149.350006
# 2022-10-27  144.800003
# 2022-10-28  155.740005
# 2022-10-31  153.339996
# 2022-11-01  150.649994
#
# [211 rows x 6 columns]

# %%
type(shares_df)
# Out:
# pandas.core.frame.DataFrame

# %%
shares_df['Close'].plot(figsize=(15, 6))
plt.show()

# %%
companies = ['AAPL', 'MSFT', 'GE']
shares_multiple_df = pdr.DataReader(companies, 'yahoo', start='2022-01-01', end='2022-11-01')
print(shares_multiple_df.head())
# Out:
# Attributes   Adj Close                              Close              \
# Symbols           AAPL        MSFT         GE        AAPL        MSFT
# Date
# 2021-12-31  176.838257  334.136902  94.155807  177.570007  336.320007
# 2022-01-03  181.259918  332.577087  95.919930  182.009995  334.750000
# 2022-01-04  178.959442  326.874359  99.039520  179.699997  329.010010
# 2022-01-05  174.199158  314.326355  99.039520  174.919998  316.380005
# 2022-01-06  171.291183  311.842560  99.617592  172.000000  313.880005
#
# Attributes                   High                                 Low  \
# Symbols            GE        AAPL        MSFT          GE        AAPL
# Date
# 2021-12-31  94.470001  179.229996  339.359985   94.970001  177.259995
# 2022-01-03  96.239998  182.880005  338.000000   97.440002  177.710007
# 2022-01-04  99.370003  182.940002  335.200012  100.050003  179.119995
# 2022-01-05  99.370003  180.169998  326.070007  101.790001  174.639999
# 2022-01-06  99.949997  175.300003  318.700012  101.080002  171.639999
#
# Attributes                               Open                          \
# Symbols           MSFT         GE        AAPL        MSFT          GE
# Date
# 2021-12-31  335.850006  93.900002  178.089996  338.510010   94.500000
# 2022-01-03  329.779999  94.750000  177.830002  335.350006   95.220001
# 2022-01-04  326.119995  98.089996  182.630005  334.829987   98.779999
# 2022-01-05  315.980011  99.290001  179.610001  325.859985   99.730003
# 2022-01-06  311.489990  99.419998  172.699997  313.149994  100.449997
#
# Attributes       Volume
# Symbols            AAPL        MSFT         GE
# Date
# 2021-12-31   64062300.0  18000800.0  3795700.0
# 2022-01-03  104487900.0  28865100.0  4619800.0
# 2022-01-04   99310400.0  32674300.0  7624100.0
# 2022-01-05   94537600.0  40054300.0  5894700.0
# 2022-01-06   96904000.0  39646100.0  4277000.0

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
# General routine for plotting time series data
def plot_timeseries_df(df, attrib, ticker_loc=1, title='Timeseries', 
                       legend=''):
    fig = plt.figure(figsize=(15,7))
    plt.plot(df[attrib], 'o-')
    _ = plt.xticks(rotation=90)
    plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(ticker_loc))
    plt.title(title)
    plt.gca().legend(legend)
    plt.show()
 
plot_timeseries_df(shares_multiple_df.loc["2022-10-01":"2022-11-01"], "Close",
                   ticker_loc=3, title="Close price", legend=companies)

# %%
#https://machinelearningmastery.com/a-guide-to-obtaining-time-series-datasets-in-python/
