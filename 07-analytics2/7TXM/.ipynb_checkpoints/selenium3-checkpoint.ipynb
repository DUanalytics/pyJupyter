# %% [markdown]
# # Selenium3
#
# https://selenium-python.readthedocs.io/getting-started.html
# https://stackoverflow.com/questions/55012755/how-to-set-window-size-in-selenium-chrome-python

# %%
#from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
#from selenium.webdriver.common.by import By
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# %%
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument("--start-maximized") #options.add_argument('window-size=1920x1080')

# %%
driver = webdriver.Chrome('C:\chromeDriver\chromedriver')
driver.get("http://www.python.org")

# %%
print(driver.current_url)
driver.maximize_window()
# Out:
# https://www.python.org/

# %%
ids = driver.find_elements_by_xpath('//*[@id]')
for ii in ids:
    #print ii.tag_name
    print(ii.get_attribute('id') )   # id name as string
# Out:
# homepage
# touchnav-wrapper
# nojs
# top
# close-python-network
# python-network
# site-map-link
# id-search-field
# submit
# mainnav
# about
# downloads
# documentation
# community
# success-stories
# news
# events
# dive-into-python
# launch-shell
# start-shell
# content
# success-story-838
# site-map
# back-to-top-1
# container
# back-to-top-2
# python-status-indicator

# %% [markdown]
# Search Button : id - q
# <input id="id-search-field" name="q" type="search" role="textbox" class="search-field" placeholder="Search" value="" tabindex="1">
# send pandas to this search button
# ![pythonSearch.png](attachment:pythonSearch.png)

# %%
print(driver.get_window_size())
# Out:
# {'width': 1382, 'height': 736}

# %%
assert "Python" in driver.title
elem = driver.find_element(By.NAME, "q")
elem.clear()
elem.send_keys("pandas")
elem.send_keys(Keys.RETURN)
#assert "No results found." not in driver.page_source

# %%
driver.close()

# %% [markdown]
# #QS Ranking
# https://www.topuniversities.com/university-rankings/university-subject-rankings/2023/arts-humanities?&tab=indicators

# %%
driver = webdriver.Chrome('C:\chromeDriver\chromedriver')
qss = 'https://www.topuniversities.com/university-rankings/university-subject-rankings/2023/arts-humanities?&tab=indicators'
driver.get(qss)

# %%
print(driver.current_url)
driver.maximize_window()
# Out:
# https://www.topuniversities.com/university-rankings/university-subject-rankings/2023/arts-humanities?&tab=indicators

# %%
ids = driver.find_elements_by_xpath('//*[@id]')
for ii in ids:
    #print ii.tag_name
    print(ii.get_attribute('id') )   # id name as string
# Out:
# LeadFlows-4668725
# cookieBanner-4668725
# hubspot-messages-loader
# hs-analytics
# hs-ads-pixel-4668725
# gpt-impl-0.9629292839822747
# sa-css
# LeadinColors-4433069
# lead-flows-style
# page-wrapper
# page
# user_login
# top_menu
# user_register
# user_login
# dropdownMenu2
# top_search
# main-wrapper
# main
# main-content
# block-tubreadcrumbs
# breadcrumbs
# block-tu-d8-content
# js-dfp-tag-top_slot
# google_ads_iframe_/8070/Topuni-Web/university-rankings/university-subject-rankings/2023/arts-humanities_0__container__
# google_ads_iframe_/8070/Topuni-Web/university-rankings/university-subject-rankings/2023/arts-humanities_0
# sign_up_today
# sign_up_today
# readmore
# pagenumberid
# selectedfactor_value
# selectedfactor_value_group
# rankingtype-check-new
# asia_ranking_type
# sustain-check-new
# trade-ranking-new
# ranking-fillters-div
# qs-ranking-year
# region-select-changer-desktop
# _university_search
# _university_search
# ranking-fillters
# year-select
# ...

# %%
ids = driver.find_elements_by_xpath('//*[@id]')
for ii in ids:
    #print ii.tag_name
    print(ii.get_attribute('class'), ii.get_attribute('href') , ii.get_attribute('src'))   # id name as string
# Out:
#  None https://js.hsleadflows.net/leadflows.js
#  None https://js.hs-banner.com/4668725.js
#  None https://js.usemessages.com/conversations-embed.js
#  None https://js.hs-analytics.net/analytics/1680184200000/4668725.js
#  None https://js.hsadspixel.net/fb.js
#  None https://securepubads.g.doubleclick.net/pagead/managed/js/gpt/m202303230101/pubads_impl.js
#  https://tags.srv.stackadapt.com/sa.css None
#  None None
#  None None
#  None None
#  None None
# nav-link reg-log-popup crm_top_nav https://www.topuniversities.com/signin?nid=%27%27&redirect_path=/university-rankings/university-subject-rankings/2023/arts-humanities None
# tu None None
# nav-link btn-green reg-log-popup crm_top_nav https://www.topuniversities.com/signup?nid=%27%27&redirect_path=/university-rankings/university-subject-rankings/2023/arts-humanities None
# ...

# %%
elem = driver.find_element(By.ID, "loaderforunivloadmore")  #
print(elem.get_property)
# Out:
# <bound method WebElement.get_property of <selenium.webdriver.remote.webelement.WebElement (session="91153b329cc4b4c3edbb91ebf4d68bc4", element="11b586c5-2209-4bea-9d10-c6d9cbdac5c1")>>

# %% [markdown]
# <button class="btn btn-primary loadmorebutton loadmorebutton_css mt-2" pageno="1">Load More</button>

# %%
driver.close()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15588\3193570824.py in <cell line: 1>()
# ----> 1 driver.close()
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in close(self)
#     594             driver.close()
#     595         """
# --> 596         self.execute(Command.CLOSE)
#     597
#     598     def quit(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     309         response = self.command_executor.execute(driver_command, params)
#     310         if response:
# --> 311             self.error_handler.check_response(response)
#     312             response['value'] = self._unwrap_value(
#     313                 response.get('value', None))
#
# ...
