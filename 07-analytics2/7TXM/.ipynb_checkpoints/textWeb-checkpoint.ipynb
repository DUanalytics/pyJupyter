# %% [markdown]
# # Analyse Web Text in Python
# - it usese common algorithms such as tokenisation, part of speech tagging, stemming, sentiment analysis, topic segmentations, named entitty recognition
# - bs4, urllib, BeautifulSoup

# %%
## Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pydataset import data
np.set_printoptions(precision=2)
pd.set_option("display.precision", 1)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
text = "Hello Mr Students, Welcome to this training on Data Science with Python. I hope you are enjoying the classes. Please share your feedback at the end of the classes. This class is happening from Noida, India"
text
# Out:
# 'Hello Mr Students, Welcome to this training on Data Science with Python. I hope you are enjoying the classes. Please share your feedback at the end of the classes. This class is happening from Noida, India'

# %%
### Get contents from webpage
import bs4
import urllib.request
link='https://www.g20.org/en/media-resources/speeches/march-23/fmm/'

# %%
webpage=str(urllib.request.urlopen(link).read())
soup = bs4.BeautifulSoup(webpage)
print(soup.get_text())
# Out:
# b'\n\n\n    \n    \n    Video Message by Prime Minister Shri Narendra Modi to G20 Foreign Ministers\xe2\x80\x99 Meeting\n\t\n    \n    \n      \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n\n    \n    \n\n\n\n    \n\n    \n    \n\n\n\n\n\n\n\n    \n    \n    \r\n\n    \n\n    \n\n\n        \n\n\n    \n    \n\n\n    \n    \n\n\n\n\n    \n    \n    \n\n\n\n    \n    \n\n    \n        \n        \n        \n            \n\n\n\n\n            \n\n\n    \n    \n        \n\n\n\n    \n    \n\n\n\n    \n    \n    \n    \n        \n        \n    Skip to content\n\n    \n        \n            \n                \n                    Suggestions from Citizens\n                \n                \n                    \n                \n                \n                    \n                \n                \n                     A -\n                \n                \n                     A \n                \n                \n                     A +\n                \n                \n                    \n                        \n                        \n                        \n                            \n                                \n                                    \n                                        \n                                            A\n                                            English\n                                        \n                                    \n                                \n                                \n                                    \n                                        \n                                            \xe0\xa4\x85\n                                            Hindi\n                                        \n                                    \n                                \n                                 \n                                    \n                                        \n                                            Japanese\n                                        \n                                    \n                                \n                                \n                                    \n                                        \n                                            French\n                                        \n                                    \n                                \n                                \n                                    \n                                        \n                                            German\n                                        \n                                    \n                                \n                                \n                                    \n                                        \n                                            Spanish\n                                        \n                                    \n                                \n                                \n                                    \n                                        \n                                            Russian\n                                        \n                                    \n                                \n                               \n                            \n                        \n                    \n                \n                \n                    \n                        \n                            \n                                \n                                    \n                            \n                                \n                                    \n                            \n                                \n                                    \n                            \n                                \n                                    \n                            \n                        \n                    \n                \n            \n        \n    \n\n    \n        \n            \n                \n            ...

# %%
pmspeech1 = soup.get_text()
type(pmspeech1)
# Out:
# str

# %% [markdown]
# newStr =[]
# for str in pmspeech1:
#     newStr.append(str.replace('\n', ''))
# print(newStr)

# %%
pms1 = pmspeech1

# %%
removeList = ['\\n', '\\t']

# %%
pms2 = pms1.replace('\\n','')
pms2 = pms2.replace('\\t','')
pms2 = pms2.replace('\\','')
print(pms2)
# Out:
# b'            Video Message by Prime Minister Shri Narendra Modi to G20 Foreign Ministersxe2x80x99 Meeting                                                                                      r                                                                                                                                                                    Skip to content                                                            Suggestions from Citizens                                                                                                                                                             A -                                                     A                                                      A +                                                                                                                                                                                                                                                                                                                A                                            English                                                                                                                                                                                                                                                                    xe0xa4x85                                            Hindi                                                                                                                                                                                                                                                                     Japanese                                                                                                                                                                                                                                                                    French                                                                                                                                                                                                                                                                    German                                                                                                                                                                                                                                                                    Spanish                                                                                                                                                                                                                                                                    Russian                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Registered on 14th J ...

# %%
import re
pms2 = re.sub(' +', ' ', pms2)  #note space in ' +'

# %%
re.sub(r'(\s)#\w+', r'\1', 'Hello all please help #me2   but#notme')
# [\w’]+ signals that the code should find all the alphanumeric characters 
# until any other character is encountered.
# Out:
# 'Hello all please help    but#notme'

# %%
pms2
# Out:
# "b' Video Message by Prime Minister Shri Narendra Modi to G20 Foreign Ministersxe2x80x99 Meeting r Skip to content Suggestions from Citizens A - A A + A English xe0xa4x85 Hindi Japanese French German Spanish Russian Registered on 14th Jan,2022 Profile Details Reset Password Logout Delete Account About G20 Overview G20 Members How G20 Works Previous Summits G20 India 2023 Logo & Theme New Delhi Summit Calendar Host Cities Visa Requirements G20 Secretariat Workstreams Sherpa Track Finance Track Engagement Groups Media & Resources Press Releases Documents Speeches Press Spotlight Peoplexe2x80x99s Connect Photo Gallery Social Media Videos Media Accreditation Tracker Explore India Incredible India Culture & Heritage Azadi Ka Amrit Mahotsav Indiaxe2x80x99s Achievements Registration & Accreditation My Dashboard Registered on 14th Jan, 2022 Profile Details Reset Password Logout Delete Account A - A A + A English xe0xa4x85 Hindi Japanese French German Spanish Russian Popular Keywords Calendar Workstreams Host Cities Visa Requirements Recent SearchesClear All Home Media & Resources Speeches Video Message by Prime Minister Shri Narendra Modi to G20 Foreign Ministersxe2x80x99 Meeting Speech PrintVideo Message by Prime Minister Shri Narendra Modi to G20 Foreign Ministersxe2x80x99 MeetingMarch 02, 2023Foreign ministers,Heads of international organizations,Excellencies,I welcome you to India for the G20 Foreign Ministers Meeting.India has selected the theme of xe2x80x98One Earth, One Family, One Futurexe2x80x99 for its G20 Presidency.It signals the need for unity of purpose and unity of action.I hope that your meeting today will reflect this spirit of coming together, for achieving common and concrete objectives.Excellencies,We must all acknowledge that multilateralism is in crisis today.The architecture of global governance, created after the Second World War, was to serve two functions.First, to prevent future wars by balancing competing interests.Second, to foster international cooperation on issues of common interests.The experience of the last few years xe2x80x93 financial crisis, climate change, pandemic, terrorism, and wars xe2x80x93 clearly shows that global governance has failed in both its mandates.We must also admit that the tragic consequences of this failure are being faced most of all by the developing countries.After years of progress, we are at risk today of moving back on the Sustainable Development Goals.Many developing countries are struggling with unsustainable debt, while trying to ensure food and energy security for their people.They are also the ones most affected by global warming caused by richer countries.This is why Indiaxe2x80x99s G20 Presidency has tried to give a voice to the Global South.No group can claim global leadership without listening to those most affected by its decisions.Excellencies,You are meeting at a time of deep global divisions.As Foreign Ministers, it is but natural that your discussions are affected by the geopolitical tensions of the day.We all have our positions and our perspectives on how these tensions should be resolved.However, as the leading economies of the world, we also have a responsibility towards those who are not in this room.The world looks upon the G20 to ease the challenges of growth; development; economic resilience; disaster resilience; financial stability; trans-national crime; corruption; terrorism; and food and energy security.In all these areas, the G20 has capacity to build consensus and deliver concrete results.We should not allow issues that we cannot resolve together to come in the way of those we can.As you meet in the land of Gandhi and the Buddha, I pray that you will draw inspiration from Indiaxe2x80x99s civilizational ethos - to focus not on what divides us, but on what unites us.Excellencies,In recent times, we have seen the most disastrous pandemic of a century.We have witnessed thousands of lives lost in natural disasters.We have seen global supply chains bre ...

# %%
# stop words
import nltk
from nltk.corpus import stopwords
#nltk.download('stopwords')
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
print(word_tokenize(text), '\t')
# Out:
# ['Hello', 'Mr', 'Students', ',', 'Welcome', 'to', 'this', 'training', 'on', 'Data', 'Science', 'with', 'Python', '.', 'I', 'hope', 'you', 'are', 'enjoying', 'the', 'classes', '.', 'Please', 'share', 'your', 'feedback', 'at', 'the', 'end', 'of', 'the', 'classes', '.', 'This', 'class', 'is', 'happening', 'from', 'Noida', ',', 'India']

# %%
print(stopwords.words('english')) # these types of words will be remove. 
# we can create our custom list also
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
myWordList = ['Reserved','Modi', 'brown']
all_stopwords = stopwords.words('english')
all_stopwords.extend(myWordList)

# %%
print(all_stopwords, '\t')
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'Reserved', 'Modi', 'brown']

# %%
print(word_tokenize(text), '\t')
# Out:
# ['Hello', 'Mr', 'Students', ',', 'Welcome', 'to', 'this', 'training', 'on', 'Data', 'Science', 'with', 'Python', '.', 'I', 'hope', 'you', 'are', 'enjoying', 'the', 'classes', '.', 'Please', 'share', 'your', 'feedback', 'at', 'the', 'end', 'of', 'the', 'classes', '.', 'This', 'class', 'is', 'happening', 'from', 'Noida', ',', 'India']

# %%
# we can remove stop words from existing dictionary
from gensim.parsing.preprocessing import remove_stopwords
#https://stackabuse.com/removing-stop-words-from-strings-in-python/

# %%
remove_stopwords(text)
# Out:
# 'Hello Mr Students, Welcome training Data Science Python. I hope enjoying classes. Please share feedback end classes. This class happening Noida, India'

# %%
all_stopwords.remove('Modi')

# %%
print(all_stopwords, '\t')
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'Reserved', 'brown']

# %% [markdown]
# # Tokenization

# %%
# split words from text
pms2.split(' ')
# Out:
# ["b'",
#  'Video',
#  'Message',
#  'by',
#  'Prime',
#  'Minister',
#  'Shri',
#  'Narendra',
#  'Modi',
#  'to',
#  'G20',
#  'Foreign',
#  'Ministersxe2x80x99',
#  'Meeting',
#  'r',
#  'Skip',
#  'to',
#  'content',
#  'Suggestions',
#  'from',
#  'Citizens',
#  'A',
#  '-',
#  'A',
#  'A',
#  '+',
#  'A',
#  'English',
#  'xe0xa4x85',
#  'Hindi',
#  'Japanese',
#  'French',
#  'German',
#  'Spanish',
#  'Russian',
#  'Registered',
#  'on',
#  '14th',
#  'Jan,2022',
#  'Profile',
#  'Details',
#  'Reset',
#  'Password',
#  'Logout',
#  'Delete',
#  'Account',
#  'About',
#  'G20',
#  'Overview',
#  'G20',
#  'Members',
#  'How',
#  'G20',
#  'Works',
#  'Previous',
#  'Summits',
#  'G20',
#  'India',
#  '2023',
#  'Logo',
#  '&',
#  'Theme',
#  'New',
#  'Delhi',
#  'Summit',
#  'Calendar',
#  'Host',
#  'Cities',
#  'Visa',
#  'Requirements',
#  'G20',
#  'Secretariat',
#  'Workstreams',
#  'Sherpa',
#  'Track',
#  'Finance',
#  'Track',
#  'Engagement',
#  'Groups',
#  'Media',
#  '&',
#  'Resources',
#  'Press',
#  'Releases',
#  'Documents',
#  'Speeches',
#  'Press',
#  'Spotlight',
#  'Peoplexe2x80x99s',
#  'Connect',
#  'Photo',
#  'Gallery',
#  'Social',
#  'Media',
#  'Videos',
#  'Media',
#  'Accreditation',
#  'Tracker',
#  'Explore',
#  'India',
#  'Incredible',
#  'India',
#  'Culture',
#  '&',
#  'Heritage',
#  'Azadi',
#  'Ka',
#  'Amrit',
#  'Mahotsav',
#  'Indiaxe2x80x99s',
#  'Achievements',
#  'Registration',
#  '&',
#  'Accreditation',
#  'My',
#  'Dashboard',
#  'Registered',
#  'on',
#  '14th',
#  'Jan,',
#  '2022',
#  'Profile',
#  'Details',
#  'Reset',
#  'Password',
#  'Logout',
#  'Delete',
#  'Account',
#  'A',
#  '-',
#  'A',
#  'A',
#  '+',
#  'A',
#  'English',
#  'xe0xa4x85',
#  'Hindi',
#  'Japanese',
#  'French',
#  'German',
#  'Spanish',
#  'Russian',
#  'Popular',
#  'Keywords',
#  'Calendar',
#  'Workstreams',
#  'Host',
#  'Cities',
#  'Visa',
#  'Requirements',
#  'Recent',
#  'SearchesClear',
#  'All',
#  'Home',
#  'Media',
#  '&',
#  'Resources',
#  'Speeches',
#  'Video',
#  'Message',
#  'by',
#  'Prime',
#  'Minister',
#  'Shri',
#  'Narendra',
#  'Modi',
#  'to',
#  'G20',
#  'Foreign',
#  'Ministersxe2x80x99',
#  'Meeting',
#  'Speech',
#  'PrintVideo',
#  'Message',
#  'by',
#  'Prime',
#  'Minister',
#  'Shri',
#  'Narendra',
#  'Modi',
#  'to',
#  'G20',
#  'Foreign',
#  'Ministersxe2x80x99',
#  'MeetingMarch',
#  '02,',
#  '2023Foreign',
#  'ministers,Heads',
#  'of',
#  'international',
#  'organizations,Excellencies,I',
#  'welcome',
#  'you',
#  'to',
#  'India',
#  'for',
#  'the',
#  'G20',
#  'Foreign',
#  'Ministers',
#  'Meeting.India',
#  'has',
#  'selected',
#  'the',
#  'theme',
#  'of',
#  'xe2x80x98One',
#  'Earth,',
#  'One',
#  'Family,',
#  'One',
#  'Futurexe2x80x99',
#  'for',
#  'its',
#  'G20',
#  'Presidency.It',
#  'signals',
#  'the',
#  'need',
#  'for',
#  'unity',
#  'of',
#  'purpose',
#  'and',
#  'unity',
#  'of',
#  'action.I',
#  'hope',
#  'that',
#  'your',
#  'meeting',
#  'today',
#  'will',
#  'reflect',
#  'this',
#  'spirit',
#  'of',
#  'coming',
#  'together,',
#  'for',
#  'achieving',
#  'common',
#  'and',
#  'concrete',
#  'objectives.Excellencies,We',
#  'must',
#  'all',
#  'acknowledge',
#  'that',
#  'multilateralism',
#  'is',
#  'in',
#  'crisis',
#  'today.The',
#  'architecture',
#  'of',
#  'global',
#  'governance,',
#  'created',
#  'after',
#  'the',
#  'Second',
#  'World',
#  'War,',
#  'was',
#  'to',
#  'serve',
#  'two',
#  'functions.First,',
#  'to',
#  'prevent',
#  'future',
#  'wars',
#  'by',
#  'balancing',
#  'competing',
#  'interests.Second,',
#  'to',
#  'foster',
#  'international',
#  'cooperation',
#  'on',
#  'issues',
#  'of',
#  'common',
#  'interests.The',
#  'experience',
#  'of',
#  'the',
#  'last',
#  'few',
#  'years',
#  'xe2x80x93',
#  'financial',
#  'crisis,',
#  'climate',
#  'change,',
#  'pandemic,',
#  'terrorism,',
#  'and',
#  'wars',
#  'xe2x80x93',
#  'clearly',
#  'shows',
#  'that',
#  'global',
#  'governance',
#  'has',
#  'failed',
#  'in',
#  'both',
#  'its',
#  'mandates.We',
#  'must',
#  'also',
#  'admit',
#  'that',
#  'the',
#  'tragic',
#  'consequences',
#  'of',
#  'this',
#  'failure',
#  'are',
#  'being',
#  'faced',
#  'most',
#  'of',
#  'all',
#  'by',
#  'the',
#  'developing',
#  'countries.After',
#  'years',
#  'of',
#  'progress,',
#  'we',
#  'are',
#  'at',
#  'risk',
#  'today',
#  'of',
#  'moving',
#  'back',
#  'on',
#  'the',
#  'Sustainable',
#  'Development',
#  'Goals.Many',
#  'developing',
#  'countries',
#  'are',
#  'struggling',
#  'with',
#  'unsustainable',
#  'debt,',
#  'while',
#  'trying',
#  'to',
#  'ensure',
#  'food',
#  'and',
#  'energy',
#  'security',
#  'for',
#  'their',
#  'people.They',
#  'are',
#  'also',
#  'the',
#  'ones',
#  'most',
#  'affected',
#  'by',
#  'global',
#  'warming',
#  'caused',
#  'by',
#  'richer',
#  'countries.This',
#  'is',
#  'why',
#  'Indiaxe2x80x99s',
#  'G20',
#  'Presidency',
#  'has',
#  'tried',
#  'to',
#  'give',
#  'a',
#  'voice',
#  'to',
#  'the',
#  'Global',
#  'South.No',
#  'group',
#  'can',
#  'claim',
#  'global',
#  'leadership',
#  'without',
#  'listening',
#  'to',
#  'those',
#  'most',
#  'affected',
#  'by',
#  'its',
#  'decisions.Excellencies,You',
#  'are',
#  'meeting',
#  'at',
#  'a',
#  'time',
#  'of',
#  'deep',
#  'global',
#  'divisions.As',
#  'Foreign',
#  'Ministers,',
#  'it',
#  'is',
#  'but',
#  'natural',
#  'that',
#  'your',
#  'discussions',
#  'are',
#  'affected',
#  'by',
#  'the',
#  'geopolitical',
#  'tensions',
#  'of',
#  'the',
#  'day.We',
#  'all',
#  'have',
#  'our',
#  'positions',
#  'and',
#  'our',
#  'perspectives',
#  'on',
#  'how',
#  'these',
#  'tensions',
#  'should',
#  'be',
#  'resolved.However,',
#  'as',
#  'the',
#  'leading',
#  'economies',
#  'of',
#  'the',
#  'world,',
#  'we',
#  'also',
#  'have',
#  'a',
#  'responsibility',
#  'towards',
#  'those',
#  'who',
#  'are',
#  'not',
#  'in',
#  'this',
#  'room.The',
#  'world',
#  'looks',
#  'upon',
#  'the',
#  'G20',
#  'to',
#  'ease',
#  'the',
#  'challenges',
#  'of',
#  'growth;',
#  'development;',
#  'economic',
#  'resilience;',
#  'disaster',
#  'resilience;',
#  'financial',
#  'stability;',
#  'trans-national',
#  'crime;',
#  'corruption;',
#  'terrorism;',
#  'and',
#  'food',
#  'and',
#  'energy',
#  'security.In',
#  'all',
#  'these',
#  'areas,',
#  'the',
#  'G20',
#  'has',
#  'capacity',
#  'to',
#  'build',
#  'consensus',
#  'and',
#  'deliver',
#  'concrete',
#  'results.We',
#  'should',
#  'not',
#  'allow',
#  'issues',
#  'that',
#  'we',
#  'cannot',
#  'resolve',
#  'together',
#  'to',
#  'come',
#  'in',
#  'the',
#  'way',
#  'of',
#  'those',
#  'we',
#  'can.As',
#  'you',
#  'meet',
#  'in',
#  'the',
#  'land',
#  'of',
#  'Gandhi',
#  'and',
#  'the',
#  'Buddha,',
#  'I',
#  'pray',
#  'that',
#  'you',
#  'will',
#  'draw',
#  'inspiration',
#  'from',
#  'Indiaxe2x80x99s',
#  'civilizational',
#  'ethos',
#  '-',
#  'to',
#  'focus',
#  'not',
#  'on',
#  'what',
#  'divides',
#  'us,',
#  'but',
#  'on',
#  'what',
#  'unites',
#  'us.Excellencies,In',
#  'recent',
#  'times,',
#  'we',
#  'have',
#  'seen',
#  'the',
#  'most',
#  'disastrous',
#  'pandemic',
#  'of',
#  'a',
#  'century.We',
#  'have',
#  'witnessed',
#  'thousands',
#  'of',
#  'lives',
#  'lost',
#  'in',
#  'natural',
#  'disasters.We',
#  'have',
#  'seen',
#  'global',
#  'supply',
#  'chains',
#  'break',
#  'down',
#  'during',
#  'times',
#  'of',
#  'stress.We',
#  'have',
#  'seen',
#  'stable',
#  'economies',
#  'suddenly',
#  'overwhelmed',
#  'by',
#  'debt',
#  'and',
#  'financial',
#  'crisis.These',
#  'experiences',
#  'clearly',
#  'show',
#  'the',
#  'need',
#  'for',
#  'resilience',
#  'xe2x80x93',
#  'in',
#  'our',
#  'societies,',
#  'in',
#  'our',
#  'economies,',
#  'in',
#  'our',
#  'healthcare',
#  'systems,',
#  'and',
#  'in',
#  'our',
#  'infrastructure.The',
#  'G20',
#  'has',
#  'a',
#  'critical',
#  'role',
#  'to',
#  'play',
#  'in',
#  'finding',
#  'the',
#  'right',
#  'balance',
#  'between',
#  'growth',
#  'and',
#  'efficiency',
#  'on',
#  'one',
#  'hand,',
#  'and',
#  'resilience',
#  'on',
#  'the',
#  'other.We',
#  'can',
#  'reach',
#  'this',
#  'balance',
#  'more',
#  'easily',
#  'by',
#  'working',
#  'together.',
#  'That',
#  'is',
#  'why',
#  'your',
#  'meeting',
#  'is',
#  'important.I',
#  'have',
#  'full',
#  'trust',
#  'in',
#  'your',
#  'collective',
#  'wisdom',
#  'and',
#  'ability.I',
#  'am',
#  'sure',
#  'that',
#  'todayxe2x80x99s',
#  'meeting',
#  'will',
#  'be',
#  'ambitious,',
#  'inclusive,',
#  'action-oriented,',
#  'and',
#  'will',
#  'rise',
#  'above',
#  'differences.I',
#  'thank',
#  'you',
#  'and',
#  'wish',
#  'you',
#  'all',
#  'the',
#  'best',
#  'for',
#  'a',
#  'productive',
#  'meeting.New',
#  'DelhiMarch',
#  '02,',
#  '2023',
#  'About',
#  'G20',
#  'Overview',
#  'G20',
#  'Members',
#  'How',
#  'G20',
#  'works',
#  'Previous',
#  'Summits',
#  'G20',
#  'India',
#  '2023',
#  'Logo',
#  '&',
#  'Theme',
#  'New',
#  'Delhi',
#  'Summit',
#  'Calendar',
#  'Host',
#  'Cities',
#  'Visa',
#  'Requirements',
#  'G20',
#  'Secretariat',
#  'Workstreams',
#  'Sherpa',
#  'Track',
#  'Finance',
#  'Track',
#  'Engagement',
#  'Groups',
#  'Media',
#  '&',
#  'Resources',
#  'Press',
#  'Releases',
#  'Documents',
#  'Speeches',
#  'Press',
#  'Spotlight',
#  'Peoplexe2x80x99s',
#  'Connect',
#  'Photo',
#  'Gallery',
#  'Social',
#  'Media',
#  'Videos',
#  'Media',
#  'Accreditation',
#  'Tracker',
#  'Explore',
#  'India',
#  'Incredible',
#  'India',
#  'Culture',
#  '&',
#  'Heritage',
#  'Azadi',
#  'Ka',
#  'Amrit',
#  'Mahotsav',
#  'Indiaxe2x80x99s',
#  'Achievements',
#  'G20',
#  'Secretariat',
#  'Contact',
#  'Us',
#  'Privacy',
#  'Policyxc2xa0',
#  '|',
#  'xc2xa0Terms',
#  '&',
#  'Conditionsxc2xa0',
#  '|',
#  'xc2xa0Copyright',
#  'Policyxc2xa0',
#  '|',
#  'xc2xa0Hyperlinking',
#  'Policyxc2xa0',
#  '|',
#  'xc2xa0Accessibility',
#  'Statement',
#  'xc2xa92023',
#  '.',
#  'All',
#  'Rights',
#  'Reserved.',
#  'xc2xa9',
#  'Content',
#  'owned',
#  'by',
#  'G20',
#  'Secretariat,',
#  'Ministry',
#  'of',
#  'External',
#  'Affairs,',
#  'Government',
#  'of',
#  'India.',
#  'Visitors:\xa0',
#  '\xa0',
#  'Page',
#  'last',
#  'updated',
#  'on:',
#  '02/03/2023',
#  'r',
#  "'"]

# %%
word_tokenize(pms2)
# Out:
# ['b',
#  "'",
#  'Video',
#  'Message',
#  'by',
#  'Prime',
#  'Minister',
#  'Shri',
#  'Narendra',
#  'Modi',
#  'to',
#  'G20',
#  'Foreign',
#  'Ministersxe2x80x99',
#  'Meeting',
#  'r',
#  'Skip',
#  'to',
#  'content',
#  'Suggestions',
#  'from',
#  'Citizens',
#  'A',
#  '-',
#  'A',
#  'A',
#  '+',
#  'A',
#  'English',
#  'xe0xa4x85',
#  'Hindi',
#  'Japanese',
#  'French',
#  'German',
#  'Spanish',
#  'Russian',
#  'Registered',
#  'on',
#  '14th',
#  'Jan,2022',
#  'Profile',
#  'Details',
#  'Reset',
#  'Password',
#  'Logout',
#  'Delete',
#  'Account',
#  'About',
#  'G20',
#  'Overview',
#  'G20',
#  'Members',
#  'How',
#  'G20',
#  'Works',
#  'Previous',
#  'Summits',
#  'G20',
#  'India',
#  '2023',
#  'Logo',
#  '&',
#  'Theme',
#  'New',
#  'Delhi',
#  'Summit',
#  'Calendar',
#  'Host',
#  'Cities',
#  'Visa',
#  'Requirements',
#  'G20',
#  'Secretariat',
#  'Workstreams',
#  'Sherpa',
#  'Track',
#  'Finance',
#  'Track',
#  'Engagement',
#  'Groups',
#  'Media',
#  '&',
#  'Resources',
#  'Press',
#  'Releases',
#  'Documents',
#  'Speeches',
#  'Press',
#  'Spotlight',
#  'Peoplexe2x80x99s',
#  'Connect',
#  'Photo',
#  'Gallery',
#  'Social',
#  'Media',
#  'Videos',
#  'Media',
#  'Accreditation',
#  'Tracker',
#  'Explore',
#  'India',
#  'Incredible',
#  'India',
#  'Culture',
#  '&',
#  'Heritage',
#  'Azadi',
#  'Ka',
#  'Amrit',
#  'Mahotsav',
#  'Indiaxe2x80x99s',
#  'Achievements',
#  'Registration',
#  '&',
#  'Accreditation',
#  'My',
#  'Dashboard',
#  'Registered',
#  'on',
#  '14th',
#  'Jan',
#  ',',
#  '2022',
#  'Profile',
#  'Details',
#  'Reset',
#  'Password',
#  'Logout',
#  'Delete',
#  'Account',
#  'A',
#  '-',
#  'A',
#  'A',
#  '+',
#  'A',
#  'English',
#  'xe0xa4x85',
#  'Hindi',
#  'Japanese',
#  'French',
#  'German',
#  'Spanish',
#  'Russian',
#  'Popular',
#  'Keywords',
#  'Calendar',
#  'Workstreams',
#  'Host',
#  'Cities',
#  'Visa',
#  'Requirements',
#  'Recent',
#  'SearchesClear',
#  'All',
#  'Home',
#  'Media',
#  '&',
#  'Resources',
#  'Speeches',
#  'Video',
#  'Message',
#  'by',
#  'Prime',
#  'Minister',
#  'Shri',
#  'Narendra',
#  'Modi',
#  'to',
#  'G20',
#  'Foreign',
#  'Ministersxe2x80x99',
#  'Meeting',
#  'Speech',
#  'PrintVideo',
#  'Message',
#  'by',
#  'Prime',
#  'Minister',
#  'Shri',
#  'Narendra',
#  'Modi',
#  'to',
#  'G20',
#  'Foreign',
#  'Ministersxe2x80x99',
#  'MeetingMarch',
#  '02',
#  ',',
#  '2023Foreign',
#  'ministers',
#  ',',
#  'Heads',
#  'of',
#  'international',
#  'organizations',
#  ',',
#  'Excellencies',
#  ',',
#  'I',
#  'welcome',
#  'you',
#  'to',
#  'India',
#  'for',
#  'the',
#  'G20',
#  'Foreign',
#  'Ministers',
#  'Meeting.India',
#  'has',
#  'selected',
#  'the',
#  'theme',
#  'of',
#  'xe2x80x98One',
#  'Earth',
#  ',',
#  'One',
#  'Family',
#  ',',
#  'One',
#  'Futurexe2x80x99',
#  'for',
#  'its',
#  'G20',
#  'Presidency.It',
#  'signals',
#  'the',
#  'need',
#  'for',
#  'unity',
#  'of',
#  'purpose',
#  'and',
#  'unity',
#  'of',
#  'action.I',
#  'hope',
#  'that',
#  'your',
#  'meeting',
#  'today',
#  'will',
#  'reflect',
#  'this',
#  'spirit',
#  'of',
#  'coming',
#  'together',
#  ',',
#  'for',
#  'achieving',
#  'common',
#  'and',
#  'concrete',
#  'objectives.Excellencies',
#  ',',
#  'We',
#  'must',
#  'all',
#  'acknowledge',
#  'that',
#  'multilateralism',
#  'is',
#  'in',
#  'crisis',
#  'today.The',
#  'architecture',
#  'of',
#  'global',
#  'governance',
#  ',',
#  'created',
#  'after',
#  'the',
#  'Second',
#  'World',
#  'War',
#  ',',
#  'was',
#  'to',
#  'serve',
#  'two',
#  'functions.First',
#  ',',
#  'to',
#  'prevent',
#  'future',
#  'wars',
#  'by',
#  'balancing',
#  'competing',
#  'interests.Second',
#  ',',
#  'to',
#  'foster',
#  'international',
#  'cooperation',
#  'on',
#  'issues',
#  'of',
#  'common',
#  'interests.The',
#  'experience',
#  'of',
#  'the',
#  'last',
#  'few',
#  'years',
#  'xe2x80x93',
#  'financial',
#  'crisis',
#  ',',
#  'climate',
#  'change',
#  ',',
#  'pandemic',
#  ',',
#  'terrorism',
#  ',',
#  'and',
#  'wars',
#  'xe2x80x93',
#  'clearly',
#  'shows',
#  'that',
#  'global',
#  'governance',
#  'has',
#  'failed',
#  'in',
#  'both',
#  'its',
#  'mandates.We',
#  'must',
#  'also',
#  'admit',
#  'that',
#  'the',
#  'tragic',
#  'consequences',
#  'of',
#  'this',
#  'failure',
#  'are',
#  'being',
#  'faced',
#  'most',
#  'of',
#  'all',
#  'by',
#  'the',
#  'developing',
#  'countries.After',
#  'years',
#  'of',
#  'progress',
#  ',',
#  'we',
#  'are',
#  'at',
#  'risk',
#  'today',
#  'of',
#  'moving',
#  'back',
#  'on',
#  'the',
#  'Sustainable',
#  'Development',
#  'Goals.Many',
#  'developing',
#  'countries',
#  'are',
#  'struggling',
#  'with',
#  'unsustainable',
#  'debt',
#  ',',
#  'while',
#  'trying',
#  'to',
#  'ensure',
#  'food',
#  'and',
#  'energy',
#  'security',
#  'for',
#  'their',
#  'people.They',
#  'are',
#  'also',
#  'the',
#  'ones',
#  'most',
#  'affected',
#  'by',
#  'global',
#  'warming',
#  'caused',
#  'by',
#  'richer',
#  'countries.This',
#  'is',
#  'why',
#  'Indiaxe2x80x99s',
#  'G20',
#  'Presidency',
#  'has',
#  'tried',
#  'to',
#  'give',
#  'a',
#  'voice',
#  'to',
#  'the',
#  'Global',
#  'South.No',
#  'group',
#  'can',
#  'claim',
#  'global',
#  'leadership',
#  'without',
#  'listening',
#  'to',
#  'those',
#  'most',
#  'affected',
#  'by',
#  'its',
#  'decisions.Excellencies',
#  ',',
#  'You',
#  'are',
#  'meeting',
#  'at',
#  'a',
#  'time',
#  'of',
#  'deep',
#  'global',
#  'divisions.As',
#  'Foreign',
#  'Ministers',
#  ',',
#  'it',
#  'is',
#  'but',
#  'natural',
#  'that',
#  'your',
#  'discussions',
#  'are',
#  'affected',
#  'by',
#  'the',
#  'geopolitical',
#  'tensions',
#  'of',
#  'the',
#  'day.We',
#  'all',
#  'have',
#  'our',
#  'positions',
#  'and',
#  'our',
#  'perspectives',
#  'on',
#  'how',
#  'these',
#  'tensions',
#  'should',
#  'be',
#  'resolved.However',
#  ',',
#  'as',
#  'the',
#  'leading',
#  'economies',
#  'of',
#  'the',
#  'world',
#  ',',
#  'we',
#  'also',
#  'have',
#  'a',
#  'responsibility',
#  'towards',
#  'those',
#  'who',
#  'are',
#  'not',
#  'in',
#  'this',
#  'room.The',
#  'world',
#  'looks',
#  'upon',
#  'the',
#  'G20',
#  'to',
#  'ease',
#  'the',
#  'challenges',
#  'of',
#  'growth',
#  ';',
#  'development',
#  ';',
#  'economic',
#  'resilience',
#  ';',
#  'disaster',
#  'resilience',
#  ';',
#  'financial',
#  'stability',
#  ';',
#  'trans-national',
#  'crime',
#  ';',
#  'corruption',
#  ';',
#  'terrorism',
#  ';',
#  'and',
#  'food',
#  'and',
#  'energy',
#  'security.In',
#  'all',
#  'these',
#  'areas',
#  ',',
#  'the',
#  'G20',
#  'has',
#  'capacity',
#  'to',
#  'build',
#  'consensus',
#  'and',
#  'deliver',
#  'concrete',
#  'results.We',
#  'should',
#  'not',
#  'allow',
#  'issues',
#  'that',
#  'we',
#  'can',
#  'not',
#  'resolve',
#  'together',
#  'to',
#  'come',
#  'in',
#  'the',
#  'way',
#  'of',
#  'those',
#  'we',
#  'can.As',
#  'you',
#  'meet',
#  'in',
#  'the',
#  'land',
#  'of',
#  'Gandhi',
#  'and',
#  'the',
#  'Buddha',
#  ',',
#  'I',
#  'pray',
#  'that',
#  'you',
#  'will',
#  'draw',
#  'inspiration',
#  'from',
#  'Indiaxe2x80x99s',
#  'civilizational',
#  'ethos',
#  '-',
#  'to',
#  'focus',
#  'not',
#  'on',
#  'what',
#  'divides',
#  'us',
#  ',',
#  'but',
#  'on',
#  'what',
#  'unites',
#  'us.Excellencies',
#  ',',
#  'In',
#  'recent',
#  'times',
#  ',',
#  'we',
#  'have',
#  'seen',
#  'the',
#  'most',
#  'disastrous',
#  'pandemic',
#  'of',
#  'a',
#  'century.We',
#  'have',
#  'witnessed',
#  'thousands',
#  'of',
#  'lives',
#  'lost',
#  'in',
#  'natural',
#  'disasters.We',
#  'have',
#  'seen',
#  'global',
#  'supply',
#  'chains',
#  'break',
#  'down',
#  'during',
#  'times',
#  'of',
#  'stress.We',
#  'have',
#  'seen',
#  'stable',
#  'economies',
#  'suddenly',
#  'overwhelmed',
#  'by',
#  'debt',
#  'and',
#  'financial',
#  'crisis.These',
#  'experiences',
#  'clearly',
#  'show',
#  'the',
#  'need',
#  'for',
#  'resilience',
#  'xe2x80x93',
#  'in',
#  'our',
#  'societies',
#  ',',
#  'in',
#  'our',
#  'economies',
#  ',',
#  'in',
#  'our',
#  'healthcare',
#  'systems',
#  ',',
#  'and',
#  'in',
#  'our',
#  'infrastructure.The',
#  'G20',
#  'has',
#  'a',
#  'critical',
#  'role',
#  'to',
#  'play',
#  'in',
#  'finding',
#  'the',
#  'right',
#  'balance',
#  'between',
#  'growth',
#  'and',
#  'efficiency',
#  'on',
#  'one',
#  'hand',
#  ',',
#  'and',
#  'resilience',
#  'on',
#  'the',
#  'other.We',
#  'can',
#  'reach',
#  'this',
#  'balance',
#  'more',
#  'easily',
#  'by',
#  'working',
#  'together',
#  '.',
#  'That',
#  'is',
#  'why',
#  'your',
#  'meeting',
#  'is',
#  'important.I',
#  'have',
#  'full',
#  'trust',
#  'in',
#  'your',
#  'collective',
#  'wisdom',
#  'and',
#  'ability.I',
#  'am',
#  'sure',
#  'that',
#  'todayxe2x80x99s',
#  'meeting',
#  'will',
#  'be',
#  'ambitious',
#  ',',
#  'inclusive',
#  ',',
#  'action-oriented',
#  ',',
#  'and',
#  'will',
#  'rise',
#  'above',
#  'differences.I',
#  'thank',
#  'you',
#  'and',
#  'wish',
#  'you',
#  'all',
#  'the',
#  'best',
#  'for',
#  'a',
#  'productive',
#  'meeting.New',
#  'DelhiMarch',
#  '02',
#  ',',
#  '2023',
#  'About',
#  'G20',
#  'Overview',
#  'G20',
#  'Members',
#  'How',
#  'G20',
#  'works',
#  'Previous',
#  'Summits',
#  'G20',
#  'India',
#  '2023',
#  'Logo',
#  '&',
#  'Theme',
#  'New',
#  'Delhi',
#  'Summit',
#  'Calendar',
#  'Host',
#  'Cities',
#  'Visa',
#  'Requirements',
#  'G20',
#  'Secretariat',
#  'Workstreams',
#  'Sherpa',
#  'Track',
#  'Finance',
#  'Track',
#  'Engagement',
#  'Groups',
#  'Media',
#  '&',
#  'Resources',
#  'Press',
#  'Releases',
#  'Documents',
#  'Speeches',
#  'Press',
#  'Spotlight',
#  'Peoplexe2x80x99s',
#  'Connect',
#  'Photo',
#  'Gallery',
#  'Social',
#  'Media',
#  'Videos',
#  'Media',
#  'Accreditation',
#  'Tracker',
#  'Explore',
#  'India',
#  'Incredible',
#  'India',
#  'Culture',
#  '&',
#  'Heritage',
#  'Azadi',
#  'Ka',
#  'Amrit',
#  'Mahotsav',
#  'Indiaxe2x80x99s',
#  'Achievements',
#  'G20',
#  'Secretariat',
#  'Contact',
#  'Us',
#  'Privacy',
#  'Policyxc2xa0',
#  '|',
#  'xc2xa0Terms',
#  '&',
#  'Conditionsxc2xa0',
#  '|',
#  'xc2xa0Copyright',
#  'Policyxc2xa0',
#  '|',
#  'xc2xa0Hyperlinking',
#  'Policyxc2xa0',
#  '|',
#  'xc2xa0Accessibility',
#  'Statement',
#  'xc2xa92023',
#  '.',
#  'All',
#  'Rights',
#  'Reserved',
#  '.',
#  'xc2xa9',
#  'Content',
#  'owned',
#  'by',
#  'G20',
#  'Secretariat',
#  ',',
#  'Ministry',
#  'of',
#  'External',
#  'Affairs',
#  ',',
#  'Government',
#  'of',
#  'India',
#  '.',
#  'Visitors',
#  ':',
#  'Page',
#  'last',
#  'updated',
#  'on',
#  ':',
#  '02/03/2023',
#  'r',
#  "'"]

# %%
sent_tokenize(pms2)
# Out:
# ["b' Video Message by Prime Minister Shri Narendra Modi to G20 Foreign Ministersxe2x80x99 Meeting r Skip to content Suggestions from Citizens A - A A + A English xe0xa4x85 Hindi Japanese French German Spanish Russian Registered on 14th Jan,2022 Profile Details Reset Password Logout Delete Account About G20 Overview G20 Members How G20 Works Previous Summits G20 India 2023 Logo & Theme New Delhi Summit Calendar Host Cities Visa Requirements G20 Secretariat Workstreams Sherpa Track Finance Track Engagement Groups Media & Resources Press Releases Documents Speeches Press Spotlight Peoplexe2x80x99s Connect Photo Gallery Social Media Videos Media Accreditation Tracker Explore India Incredible India Culture & Heritage Azadi Ka Amrit Mahotsav Indiaxe2x80x99s Achievements Registration & Accreditation My Dashboard Registered on 14th Jan, 2022 Profile Details Reset Password Logout Delete Account A - A A + A English xe0xa4x85 Hindi Japanese French German Spanish Russian Popular Keywords Calendar Workstreams Host Cities Visa Requirements Recent SearchesClear All Home Media & Resources Speeches Video Message by Prime Minister Shri Narendra Modi to G20 Foreign Ministersxe2x80x99 Meeting Speech PrintVideo Message by Prime Minister Shri Narendra Modi to G20 Foreign Ministersxe2x80x99 MeetingMarch 02, 2023Foreign ministers,Heads of international organizations,Excellencies,I welcome you to India for the G20 Foreign Ministers Meeting.India has selected the theme of xe2x80x98One Earth, One Family, One Futurexe2x80x99 for its G20 Presidency.It signals the need for unity of purpose and unity of action.I hope that your meeting today will reflect this spirit of coming together, for achieving common and concrete objectives.Excellencies,We must all acknowledge that multilateralism is in crisis today.The architecture of global governance, created after the Second World War, was to serve two functions.First, to prevent future wars by balancing competing interests.Second, to foster international cooperation on issues of common interests.The experience of the last few years xe2x80x93 financial crisis, climate change, pandemic, terrorism, and wars xe2x80x93 clearly shows that global governance has failed in both its mandates.We must also admit that the tragic consequences of this failure are being faced most of all by the developing countries.After years of progress, we are at risk today of moving back on the Sustainable Development Goals.Many developing countries are struggling with unsustainable debt, while trying to ensure food and energy security for their people.They are also the ones most affected by global warming caused by richer countries.This is why Indiaxe2x80x99s G20 Presidency has tried to give a voice to the Global South.No group can claim global leadership without listening to those most affected by its decisions.Excellencies,You are meeting at a time of deep global divisions.As Foreign Ministers, it is but natural that your discussions are affected by the geopolitical tensions of the day.We all have our positions and our perspectives on how these tensions should be resolved.However, as the leading economies of the world, we also have a responsibility towards those who are not in this room.The world looks upon the G20 to ease the challenges of growth; development; economic resilience; disaster resilience; financial stability; trans-national crime; corruption; terrorism; and food and energy security.In all these areas, the G20 has capacity to build consensus and deliver concrete results.We should not allow issues that we cannot resolve together to come in the way of those we can.As you meet in the land of Gandhi and the Buddha, I pray that you will draw inspiration from Indiaxe2x80x99s civilizational ethos - to focus not on what divides us, but on what unites us.Excellencies,In recent times, we have seen the most disastrous pandemic of a century.We have witnessed thousands of lives lost in natural disasters.We have seen global supply chains br ...
#  'That is why your meeting is important.I have full trust in your collective wisdom and ability.I am sure that todayxe2x80x99s meeting will be ambitious, inclusive, action-oriented, and will rise above differences.I thank you and wish you all the best for a productive meeting.New DelhiMarch 02, 2023 About G20 Overview G20 Members How G20 works Previous Summits G20 India 2023 Logo & Theme New Delhi Summit Calendar Host Cities Visa Requirements G20 Secretariat Workstreams Sherpa Track Finance Track Engagement Groups Media & Resources Press Releases Documents Speeches Press Spotlight Peoplexe2x80x99s Connect Photo Gallery Social Media Videos Media Accreditation Tracker Explore India Incredible India Culture & Heritage Azadi Ka Amrit Mahotsav Indiaxe2x80x99s Achievements G20 Secretariat Contact Us Privacy Policyxc2xa0 | xc2xa0Terms & Conditionsxc2xa0 | xc2xa0Copyright Policyxc2xa0 | xc2xa0Hyperlinking Policyxc2xa0 | xc2xa0Accessibility Statement xc2xa92023 .',
#  'All Rights Reserved.',
#  'xc2xa9 Content owned by G20 Secretariat, Ministry of External Affairs, Government of India.',
#  "Visitors:\xa0 \xa0 Page last updated on: 02/03/2023 r '"]

# %% [markdown]
# #from spacy.lang.en import English
# #!pip install keras
# #from keras.preprocessing.text import text_to_word_sequence
# #text_to_word_sequence(text)
# #from gensim.utils import tokenize

# %%
#word_tokenize
from collections import Counter
stop_words = stopwords.words('english')
stopwords_dict = Counter(stop_words)
text = ' '.join([word for word in text.split() if word not in stopwords_dict])
print(text)
# Out:
# Hello Mr Students, Welcome training Data Science Python. I hope enjoying classes. Please share feedback end classes. This class happening Noida, India

# %%
pms3 = ' '.join([word for word in pms2.split() if word not in stopwords_dict])
print(pms3)
# Out:
# b' Video Message Prime Minister Shri Narendra Modi G20 Foreign Ministersxe2x80x99 Meeting r Skip content Suggestions Citizens A - A A + A English xe0xa4x85 Hindi Japanese French German Spanish Russian Registered 14th Jan,2022 Profile Details Reset Password Logout Delete Account About G20 Overview G20 Members How G20 Works Previous Summits G20 India 2023 Logo & Theme New Delhi Summit Calendar Host Cities Visa Requirements G20 Secretariat Workstreams Sherpa Track Finance Track Engagement Groups Media & Resources Press Releases Documents Speeches Press Spotlight Peoplexe2x80x99s Connect Photo Gallery Social Media Videos Media Accreditation Tracker Explore India Incredible India Culture & Heritage Azadi Ka Amrit Mahotsav Indiaxe2x80x99s Achievements Registration & Accreditation My Dashboard Registered 14th Jan, 2022 Profile Details Reset Password Logout Delete Account A - A A + A English xe0xa4x85 Hindi Japanese French German Spanish Russian Popular Keywords Calendar Workstreams Host Cities Visa Requirements Recent SearchesClear All Home Media & Resources Speeches Video Message Prime Minister Shri Narendra Modi G20 Foreign Ministersxe2x80x99 Meeting Speech PrintVideo Message Prime Minister Shri Narendra Modi G20 Foreign Ministersxe2x80x99 MeetingMarch 02, 2023Foreign ministers,Heads international organizations,Excellencies,I welcome India G20 Foreign Ministers Meeting.India selected theme xe2x80x98One Earth, One Family, One Futurexe2x80x99 G20 Presidency.It signals need unity purpose unity action.I hope meeting today reflect spirit coming together, achieving common concrete objectives.Excellencies,We must acknowledge multilateralism crisis today.The architecture global governance, created Second World War, serve two functions.First, prevent future wars balancing competing interests.Second, foster international cooperation issues common interests.The experience last years xe2x80x93 financial crisis, climate change, pandemic, terrorism, wars xe2x80x93 clearly shows global governance failed mandates.We must also admit tragic consequences failure faced developing countries.After years progress, risk today moving back Sustainable Development Goals.Many developing countries struggling unsustainable debt, trying ensure food energy security people.They also ones affected global warming caused richer countries.This Indiaxe2x80x99s G20 Presidency tried give voice Global South.No group claim global leadership without listening affected decisions.Excellencies,You meeting time deep global divisions.As Foreign Ministers, natural discussions affected geopolitical tensions day.We positions perspectives tensions resolved.However, leading economies world, also responsibility towards room.The world looks upon G20 ease challenges growth; development; economic resilience; disaster resilience; financial stability; trans-national crime; corruption; terrorism; food energy security.In areas, G20 capacity build consensus deliver concrete results.We allow issues cannot resolve together come way can.As meet land Gandhi Buddha, I pray draw inspiration Indiaxe2x80x99s civilizational ethos - focus divides us, unites us.Excellencies,In recent times, seen disastrous pandemic century.We witnessed thousands lives lost natural disasters.We seen global supply chains break times stress.We seen stable economies suddenly overwhelmed debt financial crisis.These experiences clearly show need resilience xe2x80x93 societies, economies, healthcare systems, infrastructure.The G20 critical role play finding right balance growth efficiency one hand, resilience other.We reach balance easily working together. That meeting important.I full trust collective wisdom ability.I sure todayxe2x80x99s meeting ambitious, inclusive, action-oriented, rise differences.I thank wish best productive meeting.New DelhiMarch 02, 2023 About G20 Overview G20 Members How G20 works Previous Summits G20 India 2023 Logo & Theme New Delhi Summit Calendar Host Cities Visa Requirements G20 Secretariat Works ...

# %% [markdown]
# - import re
# - pattern = re.compile(r'\b(' + r'|'.join(stopwords.words('english')) + r')\b\s*')
# - text = pattern.sub('', text)

# %% [markdown]
# https://stackoverflow.com/questions/5486337/how-to-remove-stop-words-using-nltk-or-python
