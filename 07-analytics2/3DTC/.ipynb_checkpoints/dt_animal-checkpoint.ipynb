# %%
# Decision Tree

# %%
#libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#linkData =''
color = ['Grey','Yellow','Brown', 'Grey', 'Yellow']
height = [10,10,3,10,4]
label = ['Elephant', 'Giraffe','Monkey','Elephant', 'Tiger']
df = pd.DataFrame({'color':color, 'height':height, 'label':label})
#df.zipcode = df.zipcode.astype('category')
df.color = df.color.astype('category')
df.dtypes
# Out:
# color     category
# height       int64
# label       object
# dtype: object

# %%
df
# cluttered data with high entropy; What is entropy ?
# we have to determin which features split the date so that the info gain is highest
# we can do this by splitting data using each feature and checking the info gain
# the feature which returns the highest gain will be used for splitting at that node
# Out:
#     color  height     label
# 0    Grey      10  Elephant
# 1  Yellow      10   Giraffe
# 2   Brown       3    Monkey
# 3    Grey      10  Elephant
# 4  Yellow       4     Tiger

# %%
# Info gain

# %%
# feature columns and target columns
feature_columns = ['color', 'height' ]
X = df[feature_columns]
y = df.label
print(X, y)
# Out:
#     color  height
# 0    Grey      10
# 1  Yellow      10
# 2   Brown       3
# 3    Grey      10
# 4  Yellow       4 0    Elephant
# 1     Giraffe
# 2      Monkey
# 3    Elephant
# 4       Tiger
# Name: label, dtype: object

# %% [markdown]
# # character/ categorical columns have be encoded
# The recommended approach of using Label Encoding converts to integers which the DecisionTreeClassifier() will treat as numeric. If your categorical data is not ordinal, this is not good - you'll end up with splits that do not make sense.
#
# Using a OneHotEncoder is the only current valid way, allowing arbitrary splits not dependent on the label ordering, but is computationally expensive.

# %%
# Model
from sklearn.tree import DecisionTreeClassifier

# %%
print(pd.concat([X, y], axis=1))
# Out:
#     color  height     label
# 0    Grey      10  Elephant
# 1  Yellow      10   Giraffe
# 2   Brown       3    Monkey
# 3    Grey      10  Elephant
# 4  Yellow       4     Tiger

# %%
#clf = DecisionTreeClassifier()
clf1 = DecisionTreeClassifier(max_depth=3)
#clf1 = clf1.fit(X, y)
#print(clf1) 
#this will throw error

# %%
X_encoded = pd.get_dummies(X, drop_first = True)
y_encoded = pd.get_dummies(y, drop_first = True)
print(pd.concat([X_encoded, y_encoded], axis=1))
# Out:
#    height  color_Grey  color_Yellow  Giraffe  Monkey  Tiger
# 0      10           1             0        0       0      0
# 1      10           0             1        1       0      0
# 2       3           0             0        0       1      0
# 3      10           1             0        0       0      0
# 4       4           0             1        0       0      1

# %%
# Model
from sklearn.tree import DecisionTreeClassifier

dtree = DecisionTreeClassifier(max_depth=2)
dtree.fit(X_encoded, y_encoded)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

predictions = dtree.predict(X_encoded)
acc = accuracy_score(y_encoded, predictions)
print('Accuracy ', acc)
# Out:
# Accuracy  0.8

# %%
#y_pred = clf1.predict(X_encoded)
#print(y_pred)

# %% [markdown]
# https://scikit-learn.org/stable/auto_examples/tree/plot_unveil_tree_structure.html#sphx-glr-auto-examples-tree-plot-unveil-tree-structure-py
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.plot_tree.html

# %%
print(dtree.tree_.node_count, dtree.tree_.max_depth)
# Out:
# 5 2

# %%
# Visualise

from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

fig = plt.figure(figsize=((15,10)))
plot_tree(dtree,  feature_names = X_encoded.columns, node_ids=True, fontsize=20, filled=True,
            class_names=['Giraffe', 'Monkey', 'Tiger'], impurity=True,   proportion=False, label='all'  )
fig.savefig('test.png')
# node#0 =# all 100% samples(rows): 80% of them have height <= 3.5, 20% are others

# %%
# Accuracy/ Evaluate
from sklearn import metrics

# %%
#install this libraries for visualisation
#!pip install graphviz
#!pip install pydotplus
# install graphviz from http://www.graphviz.org/download/
import os
os.environ["PATH"] += os.pathsep + r'E:\analytics\Graphviz\bin'
#os.environ["PATH"] += os.pathsep + 'C:\Program Files (x86)\Graphviz2.38/bin/'

# %%
#Visualise
from sklearn.tree import export_graphviz
#from sklearn.externals.six import StringIO
from six import StringIO
from IPython.display import Image
import pydotplus
from sklearn import tree

# %%
dtree = DecisionTreeClassifier(max_depth=2)
dtree.fit(X_encoded, y_encoded)
feature_columns = ['color', 'height' ]
#print(dtree, feature_columns)
tree.plot_tree(dtree)
# Out:
# [Text(0.4, 0.8333333333333334, 'X[0] <= 3.5\ngini = 0.32\nsamples = 5\nvalue = [[4, 1]\n[4, 1]\n[4, 1]]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [[1, 0]\n[0, 1]\n[1, 0]]'),
#  Text(0.6, 0.5, 'X[0] <= 7.0\ngini = 0.25\nsamples = 4\nvalue = [[3, 1]\n[4, 0]\n[3, 1]]'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [[1, 0]\n[1, 0]\n[0, 1]]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.148\nsamples = 3\nvalue = [[2, 1]\n[3, 0]\n[3, 0]]')]

# %%
#export decision tree in DOT format
dot_data1 = StringIO()
export_graphviz(dtree, out_file=dot_data1, filled=True, rounded=True, special_characters=True, feature_names = feature_columns, class_names = ['0','1'])
#graph1 = pydotplus.graph_from_dot_data(dot_data1.getvalue())
#graph1.write_png('diabetes1.png')
#Image(graph1.create_png())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24952\2531589392.py in <module>
#       1 #export decision tree in DOT format
#       2 dot_data1 = StringIO()
# ----> 3 export_graphviz(dtree, out_file=dot_data1, filled=True, rounded=True, special_characters=True, feature_names = feature_columns, class_names = ['0','1'])
#       4 #graph1 = pydotplus.graph_from_dot_data(dot_data1.getvalue())
#       5 #graph1.write_png('diabetes1.png')
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_export.py in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision, fontname)
#     887             fontname=fontname,
#     888         )
# --> 889         exporter.export(decision_tree)
#     890
#     891         if return_string:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_export.py in export(self, decision_tree)
#     450         if self.feature_names is not None:
#     451             if len(self.feature_names) != decision_tree.n_features_in_:
# --> 452                 raise ValueError(
#     453                     "Length of feature_names, %d does not match number of features, %d"
#     454                     % (len(self.feature_names), decision_tree.n_features_in_)
#
# ValueError: Length of feature_names, 2 does not match number of features, 3

# %%
# optimising the tree : 2nd Model

# %%
clf2 = DecisionTreeClassifier(criterion = 'entropy', max_depth=2)
clf2 = clf2.fit(X_train, y_train)
print(clf2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24952\630970681.py in <module>
#       1 clf2 = DecisionTreeClassifier(criterion = 'entropy', max_depth=2)
# ----> 2 clf2 = clf2.fit(X_train, y_train)
#       3 print(clf2)
#
# NameError: name 'X_train' is not defined

# %%
y_pred2 = clf2.predict(X_test)
print( 'Accuracy-2', metrics.accuracy_score(y_test, y_pred2))
# .75
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24952\1957624285.py in <module>
# ----> 1 y_pred2 = clf2.predict(X_test)
#       2 print( 'Accuracy-2', metrics.accuracy_score(y_test, y_pred2))
#       3 # .75
#
# NameError: name 'X_test' is not defined

# %%
metrics.accuracy_score(y_test, y_pred1) < metrics.accuracy_score(y_test, y_pred2)
#2nd model is better if True
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24952\2696596327.py in <module>
# ----> 1 metrics.accuracy_score(y_test, y_pred1) < metrics.accuracy_score(y_test, y_pred2)
#       2 #2nd model is better if True
#
# NameError: name 'y_test' is not defined

# %%
dot_data2 = StringIO()
export_graphviz(clf2, out_file=dot_data2, filled=True, rounded=True, 
                special_characters=True, feature_names = feature_columns, 
                class_names = ['0','1'])
graph2 = pydotplus.graph_from_dot_data(dot_data2.getvalue())
graph2.write_png('diabetes2.png')
Image(graph2.create_png())
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24952\577880982.py in <module>
#       1 dot_data2 = StringIO()
# ----> 2 export_graphviz(clf2, out_file=dot_data2, filled=True, rounded=True,
#       3                 special_characters=True, feature_names = feature_columns,
#       4                 class_names = ['0','1'])
#       5 graph2 = pydotplus.graph_from_dot_data(dot_data2.getvalue())
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_export.py in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision, fontname)
#     858     """
#     859
# --> 860     check_is_fitted(decision_tree)
#     861     own_file = False
#     862     return_string = False
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1343
#    1344     if not fitted:
# -> 1345         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1346
#    1347
#
# NotFittedError: This DecisionTreeClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %% [markdown]
# ## Interpretation
# Pros
# DT are easy to interpret
# Requires fewer data pre-processing  (no need to normalise)
# Can be used for feature engineering (predicting missing values, variable selection)
# No assumption about distribution becoz of non-parametric nature of algo
#
# Cons
# Sensitive to noisy data. can overfit noisy data
# Small variations can result in different DT. Can be reduced by bagging & boosting
# DT are biased with imbalanced dataset. (so balance the dataset)
