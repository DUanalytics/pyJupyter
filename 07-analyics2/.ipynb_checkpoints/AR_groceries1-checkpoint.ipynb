# %%
# AR  Which items from Grocery are bought together

# %%
# Library
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

# %%
transactions = [['Bread','Butter','Jam'],
                ['Butter','Cheese'],
                ['Butter','Egg'] ,
                ['Bread','Butter','Cheese'],
                ['Bread','Egg'], 
                ['Butter','Egg'],
                ['Bread','Egg'], 
                ['Bread','Butter','Egg','Jam'],
                ['Bread','Butter','Egg']]
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
te_ary
te.columns_
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#    Bread  Butter  Cheese    Egg    Jam
# 0   True    True   False  False   True
# 1  False    True    True  False  False
# 2  False    True   False   True  False
# 3   True    True    True  False  False
# 4   True   False   False   True  False
# 5  False    True   False   True  False
# 6   True   False   False   True  False
# 7   True    True   False   True   True
# 8   True    True   False   True  False

# %%
# Library 
from apyori import apriori

# %%
association_rules = apriori(df, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)
association_results = list(association_rules)
association_results
# Out:
# [RelationRecord(items=frozenset({'C', 'h'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'C'}), items_add=frozenset({'h'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'h'}), items_add=frozenset({'C'}), confidence=1.0, lift=5.0)]),
#  RelationRecord(items=frozenset({'C', 's'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'C'}), items_add=frozenset({'s'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'s'}), items_add=frozenset({'C'}), confidence=1.0, lift=5.0)]),
#  RelationRecord(items=frozenset({'g', 'E'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'E'}), items_add=frozenset({'g'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'g'}), items_add=frozenset({'E'}), confidence=1.0, lift=5.0)]),
#  RelationRecord(items=frozenset({'J', 'm'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'J'}), items_add=frozenset({'m'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'m'}), items_add=frozenset({'J'}), confidence=1.0, lift=5.0)]),
#  RelationRecord(items=frozenset({'s', 'h'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'h'}), items_add=frozenset({'s'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'s'}), items_add=frozenset({'h'}), confidence=1.0, lift=5.0)]),
#  RelationRecord(items=frozenset({'t', 'u'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'t'}), items_add=frozenset({'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'u'}), items_add=frozenset({'t'}), confidence=1.0, lift=5.0)]),
#  RelationRecord(items=frozenset({'B', 'a', 'd'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'d'}), items_add=frozenset({'B', 'a'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 'a'}), items_add=frozenset({'d'}), confidence=1.0, lift=5.0)]),
#  RelationRecord(items=frozenset({'B', 't', 'u'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'t'}), items_add=frozenset({'B', 'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'u'}), items_add=frozenset({'B', 't'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 't'}), items_add=frozenset({'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 'u'}), items_add=frozenset({'t'}), confidence=1.0, lift=5.0)]),
#  RelationRecord(items=frozenset({'C', 'e', 'h'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'C'}), items_add=frozenset({'e', 'h'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'h'}), items_add=frozenset({'C', 'e'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'C', 'e'}), items_add=frozenset({'h'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 'h'}), items_add=frozenset({'C'}), confidence=1.0, lift=5.0)]),
#  RelationRecord(items=frozenset({'C', 'e', 's'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'C'}), items_add=frozenset({'e', 's'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'s'}), items_add=frozenset({'C', 'e'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'C', 'e'}), items_add=frozenset({'s'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 's'}), items_add=frozenset({'C'}), confidence=1.0, lift=5.0)]),
#  RelationRecord(items=frozenset({'C', 's', 'h'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'C'}), items_add=frozenset({'s', 'h'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'h'}), items_add=frozenset({'C', 's'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'s'}), items_add=frozenset({'C', 'h'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'C', 'h'}), items_add=frozenset({'s'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'C', 's'}), items_add=frozenset({'h'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'s', 'h'}), items_add=frozenset({'C'}), confidence=1.0, lift=5.0)]),
#  RelationRecord(items=frozenset({'a', 'J', 'm'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'J'}), items_add=frozenset({'a', 'm'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'m'}), items_add=frozenset({'a', 'J'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'a', 'J'}), items_add=frozenset({'m'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'a', 'm'}), items_add=frozenset({'J'}), confidence=1.0, lift=5.0)]),
#  RelationRecord(items=frozenset({'d', 'a', 'e'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'d'}), items_add=frozenset({'e', 'a'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 'a'}), items_add=frozenset({'d'}), confidence=1.0, lift=5.0)]),
#  RelationRecord(items=frozenset({'d', 'a', 'r'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'d'}), items_add=frozenset({'a', 'r'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'a', 'r'}), items_add=frozenset({'d'}), confidence=1.0, lift=5.0)]),
#  RelationRecord(items=frozenset({'e', 's', 'h'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'h'}), items_add=frozenset({'e', 's'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'s'}), items_add=frozenset({'e', 'h'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 'h'}), items_add=frozenset({'s'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 's'}), items_add=frozenset({'h'}), confidence=1.0, lift=5.0)]),
#  RelationRecord(items=frozenset({'e', 't', 'u'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'t'}), items_add=frozenset({'e', 'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'u'}), items_add=frozenset({'e', 't'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 't'}), items_add=frozenset({'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 'u'}), items_add=frozenset({'t'}), confidence=1.0, lift=5.0)]),
#  RelationRecord(items=frozenset({'t', 'r', 'u'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'t'}), items_add=frozenset({'r', 'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'u'}), items_add=frozenset({'t', 'r'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'t', 'r'}), items_add=frozenset({'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'r', 'u'}), items_add=frozenset({'t'}), confidence=1.0, lift=5.0)]),
#  RelationRecord(items=frozenset({'e', 'B', 'a', 'd'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'d'}), items_add=frozenset({'e', 'a', 'B'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 'a'}), items_add=frozenset({'e', 'd'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 'd'}), items_add=frozenset({'e', 'a'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 'a'}), items_add=frozenset({'B', 'd'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'d', 'e'}), items_add=frozenset({'B', 'a'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 'a', 'e'}), items_add=frozenset({'d'}), confidence=1.0, lift=5.0)]),
#  RelationRecord(items=frozenset({'B', 'a', 'd', 'r'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'d'}), items_add=frozenset({'B', 'a', 'r'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 'a'}), items_add=frozenset({'d', 'r'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 'd'}), items_add=frozenset({'a', 'r'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'a', 'r'}), items_add=frozenset({'B', 'd'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'d', 'r'}), items_add=frozenset({'B', 'a'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 'a', 'r'}), items_add=frozenset({'d'}), confidence=1.0, lift=5.0)]),
#  RelationRecord(items=frozenset({'B', 'e', 't', 'u'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'t'}), items_add=frozenset({'B', 'e', 'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'u'}), items_add=frozenset({'B', 'e', 't'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 't'}), items_add=frozenset({'e', 'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 'u'}), items_add=frozenset({'e', 't'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 't'}), items_add=frozenset({'B', 'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 'u'}), items_add=frozenset({'B', 't'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 'e', 't'}), items_add=frozenset({'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 'e', 'u'}), items_add=frozenset({'t'}), confidence=1.0, lift=5.0)]),
#  RelationRecord(items=frozenset({'B', 't', 'r', 'u'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'t'}), items_add=frozenset({'B', 'r', 'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'u'}), items_add=frozenset({'B', 't', 'r'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 't'}), items_add=frozenset({'r', 'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 'u'}), items_add=frozenset({'t', 'r'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'t', 'r'}), items_add=frozenset({'B', 'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'r', 'u'}), items_add=frozenset({'B', 't'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 't', 'r'}), items_add=frozenset({'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 'r', 'u'}), items_add=frozenset({'t'}), confidence=1.0, lift=5.0)]),
#  RelationRecord(items=frozenset({'C', 'e', 's', 'h'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'C'}), items_add=frozenset({'e', 's', 'h'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'h'}), items_add=frozenset({'C', 'e', 's'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'s'}), items_add=frozenset({'C', 'e', 'h'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'C', 'e'}), items_add=frozenset({'s', 'h'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'C', 'h'}), items_add=frozenset({'e', 's'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'C', 's'}), items_add=frozenset({'e', 'h'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 'h'}), items_add=frozenset({'C', 's'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 's'}), items_add=frozenset({'C', 'h'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'s', 'h'}), items_add=frozenset({'C', 'e'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'C', 'e', 'h'}), items_add=frozenset({'s'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'C', 'e', 's'}), items_add=frozenset({'h'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 's', 'h'}), items_add=frozenset({'C'}), confidence=1.0, lift=5.0)]),
#  RelationRecord(items=frozenset({'d', 'a', 'e', 'r'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'d'}), items_add=frozenset({'e', 'a', 'r'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 'a'}), items_add=frozenset({'d', 'r'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'a', 'r'}), items_add=frozenset({'d', 'e'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'d', 'e'}), items_add=frozenset({'a', 'r'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'d', 'r'}), items_add=frozenset({'e', 'a'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 'a', 'r'}), items_add=frozenset({'d'}), confidence=1.0, lift=5.0)]),
#  RelationRecord(items=frozenset({'e', 't', 'r', 'u'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'t'}), items_add=frozenset({'e', 'r', 'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'u'}), items_add=frozenset({'e', 't', 'r'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 't'}), items_add=frozenset({'r', 'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 'u'}), items_add=frozenset({'t', 'r'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'t', 'r'}), items_add=frozenset({'e', 'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'r', 'u'}), items_add=frozenset({'e', 't'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 't', 'r'}), items_add=frozenset({'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 'r', 'u'}), items_add=frozenset({'t'}), confidence=1.0, lift=5.0)]),
#  RelationRecord(items=frozenset({'e', 'r', 'B', 'd', 'a'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'d'}), items_add=frozenset({'e', 'a', 'B', 'r'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 'a'}), items_add=frozenset({'e', 'd', 'r'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 'd'}), items_add=frozenset({'e', 'a', 'r'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 'a'}), items_add=frozenset({'B', 'd', 'r'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'a', 'r'}), items_add=frozenset({'e', 'B', 'd'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'d', 'e'}), items_add=frozenset({'B', 'a', 'r'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'d', 'r'}), items_add=frozenset({'e', 'a', 'B'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 'a', 'e'}), items_add=frozenset({'d', 'r'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 'a', 'r'}), items_add=frozenset({'e', 'd'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 'B', 'd'}), items_add=frozenset({'a', 'r'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 'd', 'r'}), items_add=frozenset({'e', 'a'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 'a', 'r'}), items_add=frozenset({'B', 'd'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'d', 'e', 'r'}), items_add=frozenset({'B', 'a'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 'a', 'e', 'r'}), items_add=frozenset({'d'}), confidence=1.0, lift=5.0)]),
#  RelationRecord(items=frozenset({'e', 'u', 't', 'r', 'B'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'t'}), items_add=frozenset({'e', 'B', 'r', 'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'u'}), items_add=frozenset({'B', 'e', 't', 'r'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 't'}), items_add=frozenset({'e', 'r', 'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 'u'}), items_add=frozenset({'e', 't', 'r'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 't'}), items_add=frozenset({'B', 'r', 'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 'u'}), items_add=frozenset({'B', 't', 'r'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'t', 'r'}), items_add=frozenset({'e', 'B', 'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'r', 'u'}), items_add=frozenset({'B', 'e', 't'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 'e', 't'}), items_add=frozenset({'r', 'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 'e', 'u'}), items_add=frozenset({'t', 'r'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 't', 'r'}), items_add=frozenset({'e', 'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 'r', 'u'}), items_add=frozenset({'e', 't'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 't', 'r'}), items_add=frozenset({'B', 'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'e', 'r', 'u'}), items_add=frozenset({'B', 't'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'t', 'B', 'e', 'r'}), items_add=frozenset({'u'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'B', 'e', 'r', 'u'}), items_add=frozenset({'t'}), confidence=1.0, lift=5.0)])]

# %%
print(len(association_results))
# Out:
# 26

# %%
print(association_results[0])
# Out:
# RelationRecord(items=frozenset({'C', 'h'}), support=0.2, ordered_statistics=[OrderedStatistic(items_base=frozenset({'C'}), items_add=frozenset({'h'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'h'}), items_add=frozenset({'C'}), confidence=1.0, lift=5.0)])

# %%
for item in association_results:
    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    #second index of the inner list
    print("Support: " + str(item[1]))

    #third index of the list located at 0th
    #of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: C -> h
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
# Rule: C -> s
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
# Rule: g -> E
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
# Rule: J -> m
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
# Rule: s -> h
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
# Rule: t -> u
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
# Rule: B -> a
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
# Rule: B -> t
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
# Rule: C -> e
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
# Rule: C -> e
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
# Rule: C -> s
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
# Rule: a -> J
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
# Rule: d -> a
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
# Rule: d -> a
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
# Rule: e -> s
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
# Rule: e -> t
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
# Rule: t -> r
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
# Rule: e -> B
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
# Rule: B -> a
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
# Rule: B -> e
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
# Rule: B -> t
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
# Rule: C -> e
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
# Rule: d -> a
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
# Rule: e -> t
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
# Rule: e -> r
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
# Rule: e -> u
# Support: 0.2
# Confidence: 1.0
# Lift: 5.0
# =====================================
